# %% [markdown]
# # set up

# %%
import pandas as pd 
#df1 = pd.read_csv('df_featurized_us_french_no_entities.csv')

# %%
# Load both CSVs
csv1 = pd.read_csv("gemini_results_master.csv")
#csv2 = pd.read_csv("gemini_results_master2.csv")

# Concatenate them row-wise
combined_df = pd.concat([csv1], ignore_index=True)

# Optional: then merge with another df (if needed)
df = pd.merge(df1, combined_df, on="url", how="inner")

# %%
df = pd.read_csv("/Users/ghadena/Desktop/geopol/data/processed/entites_n_relationships.csv")

# %%
df.shape
# Out:
# (6250, 6)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'url', 'lang', 'extracted_entities',
#        'entity_relationships', 'relevant_to_german_or_french_elections'],
#       dtype='object')

# %%
df.relevance_text.value_counts()
df = df.loc[df.relevance_text == 1]

# %%
df["entity_relationships"].apply(type).value_counts()
# Out:
# entity_relationships
# <class 'str'>    607
# Name: count, dtype: int64

# %%
# import ast

# def parse_relationships(x):
#     if isinstance(x, str) and x.strip().startswith("["):
#         try:
#             parsed = ast.literal_eval(x)
#             return parsed if isinstance(parsed, list) else []
#         except Exception:
#             return []
#     return []

# df["entity_relationships"] = df["entity_relationships"].apply(parse_relationships)

import ast

def parse(val, expected_type):
    if isinstance(val, str) and val.strip().startswith(("[" if expected_type == list else "{")):
        try:
            parsed = ast.literal_eval(val)
            return parsed if isinstance(parsed, expected_type) else expected_type()
        except Exception:
            return expected_type()
    return val if isinstance(val, expected_type) else expected_type()

# Parse both columns at once
df["entity_relationships"] = df["entity_relationships"].apply(lambda x: parse(x, list))
df["extracted_entities"] = df["extracted_entities"].apply(lambda x: parse(x, dict))

# %%
df
# Out:
#       Unnamed: 0                                                url lang  \
# 0              0  https://www.rfi.fr/en/international/20250328-m...   en
# 1              1  https://www.rfi.fr/en/international-news/20250...   en
# 2              2  https://www.rfi.fr/en/international-news/20250...   en
# 3              3  https://www.rfi.fr/en/culture/20250112-philhar...   en
# 4              4  https://www.rfi.fr/en/middle-east/20250227-alg...   en
# ...          ...                                                ...  ...
# 6245        6245  https://www.euronews.com/my-europe/2024/11/21/...  NaN
# 6246        6246  https://www.euronews.com/green/2024/11/20/cop2...  NaN
# 6247        6247  https://www.euronews.com/business/2024/11/19/i...  NaN
# 6248        6248  https://www.euronews.com/next/2024/11/21/austr...  NaN
# 6249        6249  https://www.euronews.com/business/2024/11/19/e...  NaN
#
#                                      extracted_entities  \
# 0     {'people': ['Emmanuel Macron', 'Joseph Aoun'],...
# 1     {'people': ['Kyriakos Mitsotakis'], 'instituti...
# 2     {'people': [], 'institutions': ['International...
# 3     {'people': ['Jean Nouvel'], 'institutions': []...
# 4     {'people': [], 'institutions': [], 'political_...
# ...                                                 ...
# 6245  {'people': ['Elma Saiz', 'Pedro Sánchez'], 'in...
# 6246  {'people': ['Wopke Hoekstra', 'Yalchin Rafiyev...
# 6247  {'people': ['David Materazzi', 'Adam Ferrari',...
# 6248  {'people': ['Michelle Rowland', 'Anthony Alban...
# 6249  {'people': ['Piero Cingari'], 'institutions': ...
#
#                                    entity_relationships  \
# 0     [{'source': 'Emmanuel Macron', 'target': 'Leba...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4     [{'source': 'Algiers', 'target': 'French far r...
# ...                                                 ...
# 6245  [{'source': 'Elma Saiz', 'target': 'Spain', 'r...
# 6246  [{'source': 'Wopke Hoekstra', 'target': 'EU', ...
# 6247  [{'source': 'David Materazzi', 'target': 'stoc...
# 6248  [{'source': 'Michelle Rowland', 'target': 'par...
# 6249  [{'source': 'ECB', 'target': 'Piero Cingari', ...
#
#      relevant_to_german_or_french_elections
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 6245                                    NaN
# 6246                                    NaN
# 6247                                    NaN
# 6248                                    NaN
# 6249                                    NaN
#
# [6250 rows x 6 columns]

# %%
df_graph = df.loc[
    df["entity_relationships"].apply(lambda x: isinstance(x, list) and len(x) > 0) &
    df["extracted_entities"].apply(lambda x: isinstance(x, dict) and len(x) > 0),
    ["url","entity_relationships", "extracted_entities"]
].copy()

# %%
df_graph.shape
# Out:
# (4049, 3)

# %%
df_graph = df_graph.dropna(subset=["entity_relationships", "extracted_entities"])
df_graph = df_graph.drop_duplicates(subset=["url"])
df_graph.shape
# Out:
# (4049, 3)

# %%
records = []

for _, row in df_graph.iterrows():
    url = row["url"]
    #date = row["date"]
    relationships = row["entity_relationships"]

    if isinstance(relationships, list):
        for rel in relationships:
            if all(k in rel for k in ["source", "target", "relationship", "sentiment"]):
                records.append({
                    "source": rel["source"],
                    "target": rel["target"],
                    "relationship": rel["relationship"],
                    "sentiment": rel["sentiment"],
                    "url": url,
                    #"date": date
                })

edges_df = pd.DataFrame(records)
print(f"✅ Created edges_df with {len(edges_df)} rows.")
# Out:
# ✅ Created edges_df with 20098 rows.

# %%
print(edges_df["relationship"].value_counts(normalize = True))
print(edges_df["sentiment"].value_counts(normalize = True))
# Out:
# relationship
# supports            0.224500
# opposes             0.204199
# criticizes          0.175291
# partners with       0.117773
# accuses             0.072943
#                       ...
# in dialogue with    0.000050
# engaged with        0.000050
# flatters            0.000050
# bullies             0.000050
# foresees            0.000050
# Name: proportion, Length: 463, dtype: float64
# sentiment
# NEUTRAL     0.532640
# HOSTILE     0.365658
# FRIENDLY    0.101702
# Name: proportion, dtype: float64

# %%
ents = []

for _, row in df_graph.iterrows():
    url = row["url"]
    #date = row["date"]
    entities = row["extracted_entities"]

    if not isinstance(entities, dict) or not entities:
        continue

    for ent_type, names in entities.items():
        if not isinstance(names, list):
            continue
        for name in names:
            ents.append({
                "url": url,
                #"date": date,
                "entity": name,
                "entity_type": ent_type
            })

ents_long = pd.DataFrame(ents)
print(f"✅ Created ents_long with {len(ents_long)} rows.")
# Out:
# ✅ Created ents_long with 69372 rows.

# %%
ents_long.columns
# Out:
# Index(['url', 'entity', 'entity_type'], dtype='object')

# %% [markdown]
# # graph

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.40.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from plotly) (25.0)
# Downloading plotly-6.1.1-py3-none-any.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 2.4 MB/s eta 0:00:0000:0100:01
# Downloading narwhals-1.40.0-py3-none-any.whl (357 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.40.0 plotly-6.1.1

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import community.community_louvain as community_louvain  
#import community as community_louvain# pip install python-louvain
import numpy as np
from scipy.spatial import ConvexHull            # pip install scipy

# ─── 1. ASSUME edges_df & ents_long EXIST ───────────────────────────────────────
# edges_df columns: source, target, url, date (datetime), sentiment, source_type
# ents_long columns: url, date, entity, entity_type

# If your date column is still string, uncomment:
# edges_df['date'] = pd.to_datetime(edges_df['date'])

# ─── 2. BUILD WEIGHTED GRAPH FOR METRICS & CLUSTERING ────────────────────────────
# We'll ignore direction & sentiment here—just weight by co‐occurrence counts.
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _,r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# ─── 3. COMPUTE CENTRALITIES & COMMUNITIES ──────────────────────────────────────
deg_cent  = nx.degree_centrality(G)
pr        = nx.pagerank(G)
betw_cent = nx.betweenness_centrality(G, normalized=True)
partition = community_louvain.best_partition(G)

# ─── 4. LAYOUT & HULLS ───────────────────────────────────────────────────────────
pos = nx.spring_layout(G, k=0.15, iterations=20)

# Build convex‑hull shapes for each community
hull_shapes = []
for comm in set(partition.values()):
    members = [n for n,p in partition.items() if p==comm]
    if len(members) < 3: 
        continue
    pts = np.array([pos[n] for n in members])
    hull = ConvexHull(pts)
    path = "M " + " L ".join(f"{pts[v,0]},{pts[v,1]}" for v in hull.vertices) + " Z"
    hull_shapes.append(dict(
        type="path", path=path,
        fillcolor="rgba(200,200,200,0.15)", line=dict(width=0)
    ))

# ─── 5. SELECTIVE LABELS ─────────────────────────────────────────────────────────
# Top 10% by degree get fixed labels
deg_vals = np.array(list(deg_cent.values()))
thresh = np.percentile(deg_vals, 90)
label_nodes = {n for n,v in deg_cent.items() if v >= thresh}

# ─── 6. BUILD TRACES ─────────────────────────────────────────────────────────────
# 6A) Edge traces: one per sentiment + an “All”
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
edge_traces = []
color_map = {"positive":"green","negative":"red","neutral":"gray"}

for s in ["All"] + sentiments:
    xs, ys = [], []
    for u,v,d in G.edges(data=True):
        # pick “dominant” sentiment on that edge
        se = edges_df[
            (edges_df.source==u)&(edges_df.target==v)
        ]['sentiment'].mode()
        sent = se.iloc[0] if not se.empty else "neutral"
        if s!="All" and sent!=s:
            continue
        x0,y0 = pos[u]; x1,y1 = pos[v]
        xs += [x0,x1,None]; ys += [y0,y1,None]
    edge_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="lines",
            line=dict(color=color_map.get(s,"#888"), width=1),
            hoverinfo="none",
            visible=(s=="All"),
            name=(s if s!="All" else "All Sentiments")
        )
    )

# 6B) Node traces: one per entity type + an “All”
types = sorted(ents_long['entity_type'].unique().tolist())
type_colors = {"people":"blue","organizations":"orange","locations":"green","unknown":"gray"}

node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, cdata = [], [], [], [], []
    for n in G.nodes():
        et = ents_long.loc[ents_long.entity==n, "entity_type"]
        et0 = et.iloc[0] if not et.empty else "unknown"
        if t!="All" and et0!=t: 
            continue
        x,y = pos[n]
        xs.append(x); ys.append(y)
        txt.append(n if n in label_nodes else "")
        col.append(type_colors.get(et0,"gray"))
        cdata.append([et0, deg_cent[n], pr[n]])
    node_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="markers+text",
            text=txt, textposition="top center",
            marker=dict(size=10, color=col),
            customdata=cdata,
            hovertemplate=(
                "<b>%{text}</b><br>"
                "Type: %{customdata[0]}<br>"
                "Degree: %{customdata[1]:.3f}<br>"
                "PageRank: %{customdata[2]:.4f}<extra></extra>"
            ),
            visible=(t=="All"),
            name=(t if t!="All" else "All Types")
        )
    )

# ─── 7. ASSEMBLE FIGURE ──────────────────────────────────────────────────────────
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="Knowledge Graph Explorer",
        shapes=hull_shapes,
        hovermode="closest",
        legend=dict(itemsizing="constant"),
        margin=dict(l=20,r=20,b=20,t=40)
    )
)

# ─── 8. UPDATEMENUS FOR FILTERS ─────────────────────────────────────────────────
# Sentiment dropdown (single-select)
fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(label="All Sentiments",
                     method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title":"All Sentiments"}]),
                *[
                    dict(label=s.title(),
                         method="update",
                         args=[{"visible":[i==(idx+1) for i in range(len(edge_traces))] + [True]*len(node_traces)},
                               {"title":f"Sentiment: {s.title()}"}])
                    for idx,s in enumerate(sentiments)
                ]
            ],
            direction="down", x=0, y=1.15, showactive=True
        ),
        # Entity‑type dropdown
        dict(
            buttons=[
                dict(label="All Types",
                     method="update",
                     args=[{"visible":[True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title":"All Entity Types"}]),
                *[
                    dict(label=t.title(),
                         method="update",
                         args=[{"visible":[True]*len(edge_traces) + 
                                    [i==(idx+1) for i in range(len(node_traces))]},
                               {"title":f"Entity Type: {t.title()}"}])
                    for idx,t in enumerate(types)
                ]
            ],
            direction="down", x=0.25, y=1.15, showactive=True
        )
    ]
)

fig.show()

# ─── 9. PRINT TOP 5 BROKERS BY BETWEENNESS ───────────────────────────────────────
metrics = pd.DataFrame({
    "entity":       list(deg_cent.keys()),
    "degree":       list(deg_cent.values()),
    "pagerank":     [pr[n] for n in G.nodes()],
    "betweenness":  [betw_cent[n] for n in G.nodes()]
})
print("\nTop 5 brokers by betweenness:")
display(metrics.sort_values("betweenness", ascending=False).head(5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 4
#       2 import networkx as nx
#       3 import plotly.graph_objects as go
# ----> 4 import community.community_louvain as community_louvain
#       5 #import community as community_louvain# pip install python-louvain
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'community'

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import community.community_louvain as community_louvain
import numpy as np
from scipy.spatial import ConvexHull

# --- 1. Prepare data ---
ew = edges_df.groupby(['source', 'target']).size().reset_index(name='weight')
G = nx.Graph()
for _, r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# Optional: Filter nodes with low degree
G = G.subgraph([n for n, d in G.degree() if d > 2]).copy()

# --- 2. Compute graph metrics ---
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
betw_cent = nx.betweenness_centrality(G, normalized=True)
partition = community_louvain.best_partition(G)

# --- 3. Layout and community hulls ---
pos = nx.spring_layout(G, k=0.4, iterations=50)

hull_shapes = []
for comm in set(partition.values()):
    members = [n for n, p in partition.items() if p == comm]
    if len(members) < 3:
        continue
    pts = np.array([pos[n] for n in members])
    hull = ConvexHull(pts)
    path = "M " + " L ".join(f"{pts[v,0]},{pts[v,1]}" for v in hull.vertices) + " Z"
    hull_shapes.append(dict(
        type="path", path=path,
        fillcolor="rgba(200,200,200,0.15)", line=dict(width=0)
    ))

# --- 4. Label only most important nodes ---
thresh = np.percentile(list(deg_cent.values()), 97)
label_nodes = {n for n, v in deg_cent.items() if v >= thresh}

# --- 5A. Edge traces ---
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
edge_traces = []
color_map = {"positive": "green", "negative": "red", "neutral": "gray"}

for s in ["All"] + sentiments:
    xs, ys = [], []
    for u, v, d in G.edges(data=True):
        se = edges_df[
            (edges_df.source == u) & (edges_df.target == v)
        ]['sentiment'].mode()
        sent = se.iloc[0] if not se.empty else "neutral"
        if s != "All" and sent != s:
            continue
        x0, y0 = pos[u]; x1, y1 = pos[v]
        xs += [x0, x1, None]; ys += [y0, y1, None]
    edge_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="lines",
            line=dict(color=color_map.get(s, "#888"), width=1),
            hoverinfo="none",
            visible=(s == "All"),
            name=(s if s != "All" else "All Sentiments")
        )
    )

# --- 5B. Node traces ---
types = sorted(ents_long['entity_type'].unique().tolist())
type_colors = {"people": "blue", "organizations": "orange", "locations": "green", "unknown": "gray"}

node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, cdata = [], [], [], [], []
    for n in G.nodes():
        et = ents_long.loc[ents_long.entity == n, "entity_type"]
        et0 = et.iloc[0] if not et.empty else "unknown"
        if t != "All" and et0 != t:
            continue
        x, y = pos[n]
        xs.append(x); ys.append(y)
        txt.append(n if n in label_nodes else "")
        col.append(type_colors.get(et0, "gray"))
        cdata.append([et0, deg_cent[n], pr[n]])
    node_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="markers+text",
            text=txt, textposition="top center",
            marker=dict(size=6, color=col),
            customdata=cdata,
            hovertemplate=(
                "<b>%{text}</b><br>"
                "Type: %{customdata[0]}<br>"
                "Degree: %{customdata[1]:.3f}<br>"
                "PageRank: %{customdata[2]:.4f}<extra></extra>"
            ),
            visible=(t == "All"),
            name=(t if t != "All" else "All Types")
        )
    )

# --- 6. Assemble and show figure ---
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="Knowledge Graph Explorer",
        shapes=hull_shapes,
        hovermode="closest",
        legend=dict(itemsizing="constant"),
        margin=dict(l=20, r=20, b=20, t=40)
    )
)

fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(label="All Sentiments",
                     method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Sentiments"}]),
                *[
                    dict(label=s.title(),
                         method="update",
                         args=[{"visible": [i == (idx + 1) for i in range(len(edge_traces))] + [True]*len(node_traces)},
                               {"title": f"Sentiment: {s.title()}"}])
                    for idx, s in enumerate(sentiments)
                ]
            ],
            direction="down", x=0, y=1.15, showactive=True
        ),
        dict(
            buttons=[
                dict(label="All Types",
                     method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Entity Types"}]),
                *[
                    dict(label=t.title(),
                         method="update",
                         args=[{"visible": [True]*len(edge_traces) + 
                                    [i == (idx + 1) for i in range(len(node_traces))]},
                               {"title": f"Entity Type: {t.title()}"}])
                    for idx, t in enumerate(types)
                ]
            ],
            direction="down", x=0.25, y=1.15, showactive=True
        )
    ]
)

fig.show()

# --- 7. Print top brokers ---
metrics = pd.DataFrame({
    "entity": list(deg_cent.keys()),
    "degree": list(deg_cent.values()),
    "pagerank": [pr[n] for n in G.nodes()],
    "betweenness": [betw_cent[n] for n in G.nodes()]
})
print("\nTop 5 brokers by betweenness:")
display(metrics.sort_values("betweenness", ascending=False).head(5))
# Out:
# Top 5 brokers by betweenness:
#             entity    degree  pagerank  betweenness
# 282   Donald Trump  0.707602  0.170101     0.661879
# 89   Kamala Harris  0.321637  0.066263     0.107267
# 201          Trump  0.277778  0.033769     0.094263
# 147      Joe Biden  0.225146  0.037244     0.037754
# 181      Elon Musk  0.076023  0.013338     0.027518

# %% [markdown]
# # cleaning the edges_df
# dealing with entity resolutions, duplicates

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (4.46.3)
# Requirement already satisfied: tqdm in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (2.4.1)
# Requirement already satisfied: scikit-learn in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (1.3.2)
# Requirement already satisfied: scipy in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (0.31.4)
# Requirement already satisfied: Pillow in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sentence_transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from torch>=1.11.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: numpy>=1.17 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.24.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ghadena/miniconda3/envs/blink38/lib/python3.8/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-3.2.1

# %%
def stringify(val):
    return " ".join(val) if isinstance(val, list) else val

# Make sure all are strings
sources = edges_df["source"].apply(stringify)
targets = edges_df["target"].apply(stringify)
entities = ents_long["entity"].apply(stringify)

# # Now extract unique values safely
# unique_entities = pd.Series(pd.concat([sources, targets, entities])).dropna().unique().tolist()

# %%
print("Any lists in source?", edges_df["source"].apply(lambda x: isinstance(x, list)).any())
print("Any lists in target?", edges_df["target"].apply(lambda x: isinstance(x, list)).any())
print("Any lists in entity?", ents_long["entity"].apply(lambda x: isinstance(x, list)).any())
# Out:
# Any lists in source? False
# Any lists in target? True
# Any lists in entity? False

# %%
def force_string(val):
    if isinstance(val, list):
        return " ".join(map(str, val))  # flatten if list
    return str(val)  


sources = edges_df["source"].apply(force_string)
targets = edges_df["target"].apply(force_string)
entities = ents_long["entity"].apply(force_string)
unique_entities = pd.Series(pd.concat([sources, targets, entities])).dropna().unique().tolist()

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def normalize_title(name):
    return re.sub(r"\b(Mr|Ms|Mrs|Dr|Prof|President|Chancellor|Prime Minister)\.?\s+", "", name).strip()


# 1. Extract all unique entity names
#unique_entities = pd.Series(pd.concat([edges_df["source"], edges_df["target"], ents_long["entity"]])).dropna().unique().tolist()
unique_entities = [normalize_title(n) for n in unique_entities]

# 2. Load model & generate embeddings
#model = SentenceTransformer("all-MiniLM-L6-v2")
model = SentenceTransformer("all-roberta-large-v1")
embeddings = model.encode(unique_entities)

# 3. Compute cosine similarity
cos_sim = cosine_similarity(embeddings)

# 4. Group similar entities (threshold ~0.88 is good for names)
threshold = 0.88
visited = set()
clusters = {}

for i, name in enumerate(unique_entities):
    if name in visited:
        continue
    if name == "Landesumweltministerium":
        clusters[name] = [name]  # isolate it
        visited.add(name)
        continue
    cluster = [name]
    for j in range(i + 1, len(unique_entities)):
        if cos_sim[i][j] > threshold:
            cluster.append(unique_entities[j])
            visited.add(unique_entities[j])
    clusters[name] = cluster
    visited.update(cluster)

manual_resolutions = {
    "Zelenskyy": "Volodymyr Zelensky",
    "Vladimir Zelensky": "Volodymyr Zelensky",
    "Donald J. Trump": "Donald Trump",
    "Donald J Trump": "Donald Trump",
    "Donald Trump": "Donald Trump",
    "Trump": "Donald Trump",
    "Biden": "Joe Biden",
    "Musk": "Elon Musk",
    "Harris": "Kamala Harris",
    "House Republicans": "Republican Party",
    "Republicans": "Republican Party",
    "House Democrats": "Democratic Party",
    "Democrats": "Democratic Party",

    # Kennedy corrections
    "Robert F. Kennedy Jr.": "Robert F. Kennedy Jr.",
    "Robert F Kennedy Jr": "Robert F. Kennedy Jr.",
    "Robert Kennedy Jr": "Robert F. Kennedy Jr.",
    "Robert F. Kennedy, Jr.": "Robert F. Kennedy Jr.",
    "Robert F. Kennedy": "Robert F. Kennedy",  # keep Sr separate

    "John F. Kennedy": "John F. Kennedy",
    "John F Kennedy": "John F. Kennedy",
}
# Out:
# {'Emmanuel Macron': 'Emmanuel Macron',
#  'Macron': 'Emmanuel Macron',
#  'Emmanual Macron': 'Emmanuel Macron',
#  'Algiers': 'Algiers',
#  'Paris': 'Paris',
#  'Starmer': 'Starmer',
#  'Haiti': 'Haiti',
#  'M23': 'M23',
#  'Luc Remont': 'Luc Remont',
#  'Luc Rémont': 'Luc Remont',
#  'Israel': 'Israel',
#  'Donald Trump': 'Donald Trump',
#  'Trump': 'Donald Trump',
#  'Donald J. Trump': 'Donald Trump',
#  'Donald J Trump': 'Donald Trump',
#  'US border agents': 'US border agents',
#  'U.S. border officers': 'U.S. Border Patrol',
#  'France': 'France',
#  'Mali': 'Mali',
#  'Niger': 'Niger',
#  'Burkina Faso': 'Burkina Faso',
#  'Denmark': 'Denmark',
#  'National Rally': 'National Rally',
#  'National Rally (RN)': 'National Rally',
#  'National Rally (NR)': 'National Rally',
#  "Iran's foreign ministry": "Iran's foreign ministry",
#  "Iran's Foreign Ministry": "Iran's foreign ministry",
#  'Iranian foreign ministry': "Iran's foreign ministry",
#  'Iran’s foreign ministry': "Iran's foreign ministry",
#  'Marco Rubio': 'Marco Rubio',
#  'Rubio': 'Marco Rubio',
#  'European farmers': 'European farmers',
#  'Barnier': 'Barnier',
#  'George Simeon': 'George Simeon',
#  "France's government": "France's government",
#  'French government': "France's government",
#  'protestors': 'protestors',
#  'protesters': 'protestors',
#  'Protesters': 'protestors',
#  'French voters': 'French voters',
#  'leftist coalition': 'leftist coalition',
#  'Max Verstappen': 'Max Verstappen',
#  'Algeria': 'Algeria',
#  'Pakistan': 'Pakistan',
#  'Islamabad': 'Islamabad',
#  'Volodymyr Zelensky': 'Volodymyr Zelensky',
#  'Volodymyr Zelenskyy': 'Volodymyr Zelensky',
#  'Volodymr Zelenskyy': 'Volodymyr Zelensky',
#  'Volodymyr Zelenskiy': 'Volodymyr Zelensky',
#  'Volodymyr Zelynsky': 'Volodymyr Zelensky',
#  'PSV Eindhoven': 'PSV Eindhoven',
#  'Italian parliamentarians': 'Italian parliamentarians',
#  "Niger's junta": "Niger's junta",
#  'Wout van Aert': 'Wout van Aert',
#  'Isaac del Toro': 'Isaac del Toro',
#  'Qatar': 'Qatar',
#  'United States': 'United States',
#  'US': 'United States',
#  'USA': 'United States',
#  'U.S.': 'United States',
#  'United states': 'United States',
#  'Mark Rutte': 'Mark Rutte',
#  'Francesco Bagnaia': 'Francesco Bagnaia',
#  'Jensen Huang': 'Jensen Huang',
#  'JD Vance': 'JD Vance',
#  'European Union': 'European Union',
#  'European Union (EU)': 'European Union',
#  'Francois Bayrou': 'Francois Bayrou',
#  'François Bayrou': 'Francois Bayrou',
#  'Bayrou': 'Francois Bayrou',
#  'Francis Bayrou': 'Francois Bayrou',
#  'Argentina': 'Argentina',
#  'Argentin': 'Argentinien',
#  'Javier Milei': 'Javier Milei',
#  'Elon Musk': 'Elon Musk',
#  'Errol Musk': 'Elon Musk',
#  'Vladimir Putin': 'Vladimir Putin',
#  'Wladimir Putin': 'Vladimir Putin',
#  'Vladímir Putin': 'Vladimir Putin',
#  'Vladimir V. Putin': 'Vladimir Putin',
#  'Shigeru Ishiba': 'Shigeru Ishiba',
#  'Iran': 'Iran',
#  'Washington': 'Washington',
#  'Rwanda': 'Rwanda',
#  'Hamas': 'Hamas',
#  'British government': 'British government',
#  "Britain's government": 'British government',
#  'UK government': 'British government',
#  'U.K. government': 'British government',
#  'Brussels': 'Brussels',
#  'Jean-Noël Barrot': 'Jean-Noël Barrot',
#  'Jean-Noel Barrot': 'Jean-Noël Barrot',
#  'Imamoglu': 'Imamoglu',
#  'İmamoğlu': 'Imamoglu',
#  'Al-Shabaab': 'Al-Shabaab',
#  'Al-Shabab': 'Al-Shabaab',
#  'far right': 'far right',
#  'Viktor Orban': 'Viktor Orban',
#  'Viktor Orbán': 'Viktor Orban',
#  'Orban': 'Viktor Orban',
#  'Victor Orban': 'Viktor Orban',
#  'Geert Wilders': 'Geert Wilders',
#  'Gert Wilders': 'Geert Wilders',
#  'EU': 'EU',
#  'Kylian Mbappé': 'Kylian Mbappé',
#  'Kylian Mbappe': 'Kylian Mbappé',
#  'US Supreme Court': 'US Supreme Court',
#  'Supreme Court': 'US Supreme Court',
#  'U.S. Supreme Court': 'US Supreme Court',
#  'Supreme Courts': 'US Supreme Court',
#  'United States Supreme Court': 'US Supreme Court',
#  'Federal Supreme Court': 'US Supreme Court',
#  'Romania’s electoral bureau': 'Romania’s electoral bureau',
#  'Romania’s Central Electoral Commission': 'Romania’s electoral bureau',
#  'French antitrust authorities': 'French antitrust authorities',
#  'White House': 'White House',
#  'The White House': 'White House',
#  'the White House': 'White House',
#  'Whitehouse': 'White House',
#  'Zelensky': 'Zelensky',
#  'Zelenskyy': 'Volodymyr Zelensky',
#  'Bosnia': 'Bosnia',
#  'Serbia': 'Bosnia',
#  'Yugoslavia': 'Montenegro',
#  'G7': 'G7',
#  'Russia': 'Russia',
#  'US Treasury': 'US Treasury',
#  'U.S. Treasury': 'Treasury Department',
#  'Recep Tayyip Erdogan': 'Recep Tayyip Erdogan',
#  'Recep Tayyip Erdoğan': 'Recep Tayyip Erdogan',
#  'Tayyip Erdogan': 'Recep Tayyip Erdogan',
#  'Erdoğan': 'Recep Tayyip Erdogan',
#  'Erdogan': 'Recep Tayyip Erdogan',
#  'Tayyip Erdoğan': 'Recep Tayyip Erdogan',
#  'Turkey': 'Turkey',
#  'Ekrem Imamoglu': 'Ekrem Imamoglu',
#  'Ekrem İmamoğlu': 'Ekrem Imamoglu',
#  'Philippine': 'Philippine',
#  'Philippines': 'Philippine',
#  'Britain': 'Britain',
#  'Great Britain': 'Britain',
#  'the UK': 'Britain',
#  'Muhammad Ilyas': 'Muhammad Ilyas',
#  'Bundeswehr': 'Bundeswehr',
#  'Feuerwehr': 'Bundeswehr',
#  'Nato': 'Nato',
#  'NATO': 'Nato',
#  'Alexander Sollfrank': 'Alexander Sollfrank',
#  'Thomas Mann': 'Thomas Mann',
#  'Kritiker': 'Kritiker',
#  'Saúl Lliuya': 'Saúl Lliuya',
#  'Christian Tischner': 'Christian Tischner',
#  'Friedrich Merz': 'Friedrich Merz',
#  'Verein Aufarbeitung Kinderverschickungen NRW': 'Verein Aufarbeitung Kinderverschickungen NRW',
#  'Landesregierung': 'Landesregierung',
#  'CHP': 'CHP',
#  'Justiz': 'Justiz',
#  'Landesumweltministerium': 'Landesumweltministerium',
#  'Bernd Mettenleiter': 'Bernd Mettenleiter',
#  'Republikaner': 'Republikaner',
#  'Shen Xiaomeng': 'Shen Xiaomeng',
#  'Zhu Xiaoming': 'Shen Xiaomeng',
#  'Niko Kovac': 'Niko Kovac',
#  'Ursula von der Leyen': 'Ursula von der Leyen',
#  'Ursula Von der Leyen': 'Ursula von der Leyen',
#  'Maros Sefcovic': 'Maros Sefcovic',
#  'CDU Sachsen-Anhalt': 'CDU Sachsen-Anhalt',
#  'Berliner CDU': 'Berliner CDU',
#  'Bundes-CDU': 'CDU-Bundestagsabgeordneten',
#  'CSU': 'CSU',
#  'Winfried Hermann': 'Winfried Hermann',
#  'Verbände': 'Verbände',
#  'Sachverständigenrat der Landesregierung': 'Sachverständigenrat der Landesregierung',
#  'Domenico Tedesco': 'Domenico Tedesco',
#  'Matthias Tillmann': 'Matthias Tillmann',
#  'Raúl': 'Raúl',
#  'Peter Füssenich': 'Peter Füssenich',
#  'FC Bayern München': 'FC Bayern München',
#  'FC Bayern': 'FC Bayern München',
#  'Bayern Munich': 'Bayern',
#  'Bayern München': 'Bayern',
#  'Vincent Kompany': 'Vincent Kompany',
#  'US-Regierung': 'US-Regierung',
#  'US-Regierungsvertretern': 'US-Regierung',
#  'Joe Biden': 'Joe Biden',
#  'Joseph R. Biden Jr.': 'Joe Biden',
#  'Joseph R Biden Jr.': 'Joe Biden',
#  'Frederik Tiffels': 'Frederik Tiffels',
#  'Serge Aubin': 'Serge Aubin',
#  'Jusos': 'Jusos',
#  'Juso': 'Jusos',
#  'Benedict Lang': 'Benedict Lang',
#  'SPD': 'SPD',
#  'Achim Post': 'Achim Post',
#  'CDU': 'CDU',
#  'Christian Democratic Union (CDU)': 'CDU',
#  'Markus Söder': 'Markus Söder',
#  'Bayern': 'Bayern',
#  'Wolfsburg': 'VfL Wolfsburg',
#  'Bayerns': 'Bayern',
#  'Freistaat Bayern': 'Freistaat Bayern',
#  'Internationales Schifffahrtsbüro (IMB)': 'Internationales Schifffahrtsbüro (IMB)',
#  'Volker Waltmann': 'Volker Waltmann',
#  'DIHK': 'DIHK',
#  'Kai Seefried': 'Kai Seefried',
#  'Olaf Lies': 'Olaf Lies',
#  'HEH': 'HEH',
#  'Friedemann Hanke': 'Friedemann Hanke',
#  'Annalena Baerbock': 'Annalena Baerbock',
#  'Bundes': 'Bundes',
#  'Peking': 'Peking',
#  'Lars Klingbeil': 'Lars Klingbeil',
#  'Sean "Diddy" Combs': 'Sean "Diddy" Combs',
#  "Sean 'Diddy' Combs": 'Sean "Diddy" Combs',
#  'Sean “Diddy” Combs': 'Sean "Diddy" Combs',
#  'Casandra "Cassie" Ventura': 'Casandra "Cassie" Ventura',
#  'Casandra “Cassie” Ventura': 'Casandra "Cassie" Ventura',
#  'Harvey Weinstein': 'Harvey Weinstein',
#  'Arnd Franz': 'Arnd Franz',
#  'Mahle': 'Mahle',
#  'André Olveira-Lenz': 'André Olveira-Lenz',
#  'Björn Sucher': 'Björn Sucher',
#  'Gabriele Terland': 'Gabriele Terland',
#  'Niko Bungert': 'Niko Bungert',
#  'Fridays for Future': 'Fridays for Future',
#  'Fabian Leendertz': 'Fabian Leendertz',
#  'Yap Boum': 'Yap Boum',
#  'Alexandre Hassanin': 'Alexandre Hassanin',
#  'Kristian Andersen': 'Kristian Andersen',
#  'Leendertz': 'Leendertz',
#  'Robert F. Kennedy Jr.': 'Robert F. Kennedy Jr.',
#  'Robert F Kennedy Jr': 'Robert F. Kennedy Jr.',
#  'John Kennedy': 'Robert F. Kennedy Jr.',
#  'John F. Kennedy': 'John F. Kennedy',
#  'John F Kennedy': 'John F. Kennedy',
#  'Robert Kennedy': 'Robert F. Kennedy Jr.',
#  'Robert Kennedy Jr': 'Robert F. Kennedy Jr.',
#  'Robert F. Kennedy, Jr.': 'Robert F. Kennedy Jr.',
#  'Robert F. Kennedy': 'Robert F. Kennedy',
#  'Robert Kennedy Sr': 'Robert F. Kennedy Jr.',
#  'Kanada': 'Kanada',
#  'Alexander Schweitzer': 'Alexander Schweitzer',
#  'Ägypten': 'Ägypten',
#  'Katar': 'Katar',
#  'Parlament': 'Parlament',
#  'Mats Hummels': 'Mats Hummels',
#  'Melissa Butt': 'Melissa Butt',
#  'Philipp Türmer': 'Philipp Türmer',
#  'Thüringer Jusos': 'Thüringer Jusos',
#  'Céline Dion': 'Céline Dion',
#  'Paola': 'Paola',
#  'Luca Hänni': 'Luca Hänni',
#  'Dino Toppmöller': 'Dino Toppmöller',
#  'Axel Hellmann': 'Axel Hellmann',
#  'Anke Rehlinger': 'Anke Rehlinger',
#  'Janet Mills': 'Janet Mills',
#  'Jürgen Klopp': 'Jürgen Klopp',
#  'Robert Lehmann': 'Robert Lehmann',
#  'britische Regierung': 'britische Regierung',
#  'B.H. Holding GmbH': 'B.H. Holding GmbH',
#  'Landgericht Stuttgart': 'Landgericht Stuttgart',
#  'Klingbeil': 'Klingbeil',
#  'Saskia Esken': 'Saskia Esken',
#  'Union': 'Union',
#  'Staatsanwaltschaft': 'Staatsanwaltschaft',
#  'Nürnberger Zentralstelle zur Bekämpfung von Betrug und Korruption im Gesundheitswesen (ZKG)': 'Nürnberger Zentralstelle zur Bekämpfung von Betrug und Korruption im Gesundheitswesen (ZKG)',
#  'Generalstaatsanwaltschaft Nürnberg': 'Generalstaatsanwaltschaft Nürnberg',
#  'der 43-jährige deutsche Tatverdächtige': 'der 43-jährige deutsche Tatverdächtige',
#  'Generalstaatsanwaltschaft Stuttgart': 'Generalstaatsanwaltschaft Stuttgart',
#  'Luigi Brugnaro': 'Luigi Brugnaro',
#  'Unbekannten': 'Unbekannten',
#  'Polizei': 'Polizei',
#  'AfD-Landtagsfraktion': 'AfD-Landtagsfraktion',
#  'AfD-Fraktion': 'AfD-Landtagsfraktion',
#  'Dmitri Medwedew': 'Dmitri Medwedew',
#  'Dmitri Peskow': 'Dmitri Peskow',
#  'Dmitri Peskov': 'Dmitri Peskow',
#  'Olaf Scholz': 'Olaf Scholz',
#  'Nordkorea': 'Nordkorea',
#  'Yoon Suk Yeol': 'Yoon Suk Yeol',
#  'Yoon Suk-yeol': 'Yoon Suk Yeol',
#  'Leon Ziegler': 'Leon Ziegler',
#  'Alex Müller': 'Alex Müller',
#  'Thomas Müller': 'Gerd Müller',
#  'Iris Spranger': 'Iris Spranger',
#  'Gewerkschaft der Polizei (GdP)': 'Gewerkschaft der Polizei (GdP)',
#  'Jesuiten-Flüchtlingsdienst': 'Jesuiten-Flüchtlingsdienst',
#  'Obama': 'Obama',
#  'Barack Obama': 'Obama',
#  'Biden': 'Joe Biden',
#  'Jörg Urban': 'Jörg Urban',
#  'VfL Wolfsburg': 'VfL Wolfsburg',
#  'VfB Stuttgart': 'VfL Wolfsburg',
#  'SC Freiburg': 'VfL Wolfsburg',
#  'VfL Bochum': 'VfL Osnabrück',
#  'Herbert Reul': 'Herbert Reul',
#  'Stephanie Thien': 'Stephanie Thien',
#  'Alexander Kekulè': 'Alexander Kekulè',
#  'Detlev Krüger': 'Detlev Krüger',
#  'EZB': 'EZB',
#  'Putin': 'Putin',
#  'SoVD': 'SoVD',
#  'Engelmeier': 'Engelmeier',
#  'Merz': 'Merz',
#  'Körzell': 'Körzell',
#  'Esdar': 'Esdar',
#  'Wiese': 'Wiese',
#  'Büdenbender': 'Büdenbender',
#  'Langkamp': 'Langkamp',
#  'Maier': 'Maier',
#  'Wirtschaft': 'Wirtschaft',
#  'Erding': 'Erding',
#  'Fischedick': 'Fischedick',
#  'Türmer': 'Türmer',
#  'Günther': 'Günther',
#  'Rehlinger': 'Rehlinger',
#  'Heil': 'Heil',
#  'Pfeiffer': 'Pfeiffer',
#  'Klüssendorf': 'Klüssendorf',
#  'Karin Prien': 'Karin Prien',
#  'Dorothee Bär': 'Dorothee Bär',
#  'Armin Laschet': 'Armin Laschet',
#  'Jens Spahn': 'Jens Spahn',
#  'Bundestages': 'Bundestages',
#  'Alexander Dobrindt': 'Alexander Dobrindt',
#  'Peter Altmaier': 'Peter Altmaier',
#  'Gerd Müller': 'Gerd Müller',
#  'Norbert Lammert': 'Norbert Lammert',
#  'Konstantin von Notz': 'Konstantin von Notz',
#  'Michael Kretschmer': 'Michael Kretschmer',
#  'Volker Wissing': 'Volker Wissing',
#  'EU-Kommission': 'EU-Kommission',
#  'Henna Virkkunen': 'Henna Virkkunen',
#  'Holger Münch': 'Holger Münch',
#  'Peter Münch': 'Holger Münch',
#  'Robert Rethfeld': 'Robert Rethfeld',
#  'Kemal Irmal': 'Kemal Irmal',
#  'Yusuf Tekin': 'Yusuf Tekin',
#  'Wagenknecht': 'Wagenknecht',
#  'BSW': 'BSW',
#  'Mohamed Ali': 'Mohamed Ali',
#  'AfD': 'AfD',
#  'Bianca Radlbeck': 'Bianca Radlbeck',
#  'Mein Grundeinkommen': 'Mein Grundeinkommen',
#  'Howard Lutnick': 'Howard Lutnick',
#  'Howard Lutnic': 'Howard Lutnick',
#  'Adam Schiff': 'Adam Schiff',
#  'Oman': 'Oman',
#  'John Kerry': 'John Kerry',
#  'John F. Kerry': 'John Kerry',
#  'Bärbel Bas': 'Bärbel Bas',
#  'Nancy Faeser': 'Nancy Faeser',
#  'Matthias Miersch': 'Matthias Miersch',
#  'Katja Mast': 'Katja Mast',
#  'Roderich Kiesewetter': 'Roderich Kiesewetter',
#  'Manuela Schwesig': 'Manuela Schwesig',
#  'Palästinenser': 'Palästinenser',
#  'israelische Regierung': 'israelische Regierung',
#  'israelischen Regierung': 'israelische Regierung',
#  'Sigmar Gabriel': 'Sigmar Gabriel',
#  'Bundesverfassungsgericht': 'Bundesverfassungsgericht',
#  'Verfassungsgericht': 'Bundesverfassungsgericht',
#  'Bundesgericht': 'Bundesverfassungsgericht',
#  'Bundesverwaltungsgericht': 'Bundesverfassungsgericht',
#  'Bundesverfassungsgerichts': 'Bundesverfassungsgericht',
#  'Karl Lauterbach': 'Karl Lauterbach',
#  'Lauterbach': 'Karl Lauterbach',
#  'Susanne Meunier': 'Susanne Meunier',
#  'Bastian Kunkel': 'Bastian Kunkel',
#  'Henriette Neubert': 'Henriette Neubert',
#  'Amnesty International': 'Amnesty International',
#  'Julia Duchrow': 'Julia Duchrow',
#  'Taha al-Haji': 'Taha al-Haji',
#  'Mohammed bin Salman': 'Mohammed bin Salman',
#  'Bundesregierung': 'Bundesregierung',
#  'Staatsregierung': 'Bundesregierung',
#  'Regierungsbildung': 'Regierung',
#  'Polen': 'Polen',
#  'BR': 'BR',
#  'Bundesgesellschaft für Endlagerung': 'Bundesgesellschaft für Endlagerung',
#  'Bruno Thomauske': 'Bruno Thomauske',
#  'Iris Graffunder': 'Iris Graffunder',
#  'Christian Kühn': 'Christian Kühn',
#  'BASE': 'BASE',
#  'Pia Lamberty': 'Pia Lamberty',
#  'Claudia Kemfert': 'Claudia Kemfert',
#  'Julia Wandt': 'Julia Wandt',
#  'Eva Högl': 'Eva Högl',
#  'Boris Pistorius': 'Boris Pistorius',
#  'Josefine Königbauer': 'Josefine Königbauer',
#  'Deutsche Gesellschaft für Gynäkologie und Geburtshilfe': 'Deutsche Gesellschaft für Gynäkologie und Geburtshilfe',
#  'J.K. Rowling': 'J.K. Rowling',
#  'Daniel Radcliffe': 'Daniel Radcliffe',
#  'Emma Watson': 'Emma Watson',
#  'Iordanis Georgiadis': 'Iordanis Georgiadis',
#  'Taxizentrale': 'Taxizentrale',
#  'Taxifahrer': 'Taxifahrer',
#  'Harvard': 'Harvard',
#  'Harvard University': 'Harvard',
#  'Alan Garber': 'Alan Garber',
#  'Micheál Martin': 'Micheál Martin',
#  'Lloyd Austin': 'Lloyd Austin',
#  'Agnès Callamard': 'Agnès Callamard',
#  'Keir Starmer': 'Keir Starmer',
#  'Sir Keir Starmer': 'Keir Starmer',
#  'Ukraine': 'Ukraine',
#  'Australian think tank': 'Australian think tank',
#  'Georgescu': 'Georgescu',
#  'Lucian Georgescu': 'Georgescu',
#  'Rima Hassan': 'Rima Hassan',
#  'David Lisnard': 'David Lisnard',
#  'Mark Carney': 'Mark Carney',
#  'Amir Boukhors': 'Amir Boukhors',
#  'Algérie': 'Algérie',
#  'Algérien': 'Algérie',
#  'Algerien': 'Algérie',
#  'Julie': 'Julie',
#  'Julia': 'Julie',
#  'Gérard Depardieu': 'Gérard Depardieu',
#  'Gerard Depardieu': 'Gérard Depardieu',
#  'Jérémie Assous': 'Jérémie Assous',
#  'Jeremie Assous': 'Jérémie Assous',
#  'SNCF Voyageurs': 'SNCF Voyageurs',
#  'Alstom': 'Alstom',
#  'Île-de-France Mobilités (IDFM)': 'Île-de-France Mobilités (IDFM)',
#  'Steve Witkoff': 'Steve Witkoff',
#  'Steven Witkoff': 'Steve Witkoff',
#  'Steve Wittkoff': 'Steve Witkoff',
#  'Mike Waltz': 'Mike Waltz',
#  'Michael Waltz': 'Mike Waltz',
#  'Sergej Lawrow': 'Sergej Lawrow',
#  'Jurij Uschakow': 'Jurij Uschakow',
#  'Matthias Quent': 'Matthias Quent',
#  'Brexit': 'Brexit',
#  'Brexit vote': 'Brexit',
#  'Russlands': 'Russlands',
#  'Radfahrer': 'Radfahrer',
#  'Musk': 'Elon Musk',
#  'Jan Philipp Burgard': 'Jan Philipp Burgard',
#  'FPÖ': 'FPÖ',
#  'ÖVP': 'ÖVP',
#  'Neos': 'Neos',
#  'Grünen': 'Grünen',
#  'Grüne': 'Grünen',
#  'Hisbollah-Miliz': 'Hisbollah-Miliz',
#  'Demonstranten': 'Demonstranten',
#  'Hind Kabawat': 'Hind Kabawat',
#  'Hooters': 'Hooters',
#  'US-Präsident': 'US-Präsident',
#  'US-Präsidenten': 'US-Präsident',
#  'Ralf Eckert': 'Ralf Eckert',
#  'US-Banken': 'US-Banken',
#  'europäischen Großbanken': 'europäischen Großbanken',
#  'BMW': 'BMW',
#  'Arias': 'Arias',
#  'Betonblock': 'Betonblock',
#  'US-Justiz': 'US-Justiz',
#  'Obersten Gerichtshof': 'Obersten Gerichtshof',
#  'Regina Steffens': 'Regina Steffens',
#  'Maximilian Sepp': 'Maximilian Sepp',
#  'Sahra Wagenknecht': 'Sahra Wagenknecht',
#  'Dovile Sakaliene': 'Dovile Sakaliene',
#  'Oppositionsparteien': 'Oppositionsparteien',
#  'FDP': 'FDP',
#  'Linken': 'Linken',
#  'Vatikan': 'Vatikan',
#  'Görke': 'Görke',
#  'Unternehmensverbände': 'Unternehmensverbände',
#  'Branchenverbänden': 'Branchenverbänden',
#  'Kreml': 'Kreml',
#  'Pete Hegseth': 'Pete Hegseth',
#  'Jill Biden': 'Jill Biden',
#  'China': 'China',
#  'Söder': 'Söder',
#  'Thomas': 'Thomas',
#  'Siemens AG': 'Siemens AG',
#  'Siemens': 'Siemens AG',
#  'Siemens Energy AG': 'Siemens Energy',
#  'Rutte': 'Rutte',
#  'bayerische SPD': 'bayerische SPD',
#  'Marvin Gaye': 'Marvin Gaye',
#  'Stiftung': 'Stiftung',
#  'Bill Ackman': 'Bill Ackman',
#  'Christian Dirschauer': 'Christian Dirschauer',
#  'Menschen': 'Menschen',
#  'Nietzard': 'Nietzard',
#  'Poschardt': 'Poschardt',
#  'Tischner': 'Tischner',
#  'Bain Capital': 'Bain Capital',
#  'Cinven': 'Cinven',
#  'Frauke Böger': 'Frauke Böger',
#  'Dilek Kalayci': 'Dilek Kalayci',
#  'GTAI': 'GTAI',
#  'Deutschland': 'Deutschland',
#  'Germany': 'Deutschland',
#  'Disney': 'Disney',
#  'Wolodymyr Selenskyj': 'Wolodymyr Selenskyj',
#  'Wolodimir Selenskij': 'Wolodymyr Selenskyj',
#  'Deepam Seth': 'Deepam Seth',
#  'Lynn Song': 'Lynn Song',
#  'Bezirksregierung': 'Bezirksregierung',
#  'Bund': 'Bund',
#  'Christian Lindner': 'Christian Lindner',
#  'Mariam Lau': 'Mariam Lau',
#  'Winfried Kretschmann': 'Winfried Kretschmann',
#  'Enzo Weber': 'Enzo Weber',
#  'Holger Schäfer': 'Holger Schäfer',
#  'Thomas Schäfer': 'Holger Schäfer',
#  'chinesische Regierung': 'chinesische Regierung',
#  'deutsche Wirtschaft': 'deutsche Wirtschaft',
#  'Sven Giegold': 'Sven Giegold',
#  'Lars Feld': 'Lars Feld',
#  'Daniel Ziblatt': 'Daniel Ziblatt',
#  'Johannes Vogel': 'Johannes Vogel',
#  'Christian Dürr': 'Christian Dürr',
#  'Marie-Agnes Strack-Zimmermann': 'Marie-Agnes Strack-Zimmermann',
#  'Marie-Agnes Strack Zimmerman': 'Marie-Agnes Strack-Zimmermann',
#  'Wolfgang Kubicki': 'Wolfgang Kubicki',
#  'Thomas Kemmerich': 'Thomas Kemmerich',
#  'Julian Nagelsmann': 'Julian Nagelsmann',
#  'Bo Henriksen': 'Bo Henriksen',
#  'Boris Johnson': 'Boris Johnson',
#  'Dorothee Feller': 'Dorothee Feller',
#  'Verlag': 'Verlag',
#  'Mareike Engel': 'Mareike Engel',
#  'Amtsgericht Pforzheim': 'Amtsgericht Pforzheim',
#  '21-Jähriger': '21-Jähriger',
#  'Robert Lewandowski': 'Robert Lewandowski',
#  'Dieter Nuhr': 'Dieter Nuhr',
#  'Katharina Dröge': 'Katharina Dröge',
#  'CDU/CSU': 'CDU/CSU',
#  'Ingrid Alexandra': 'Ingrid Alexandra',
#  'Mette-Marit': 'Mette-Marit',
#  'Leonor': 'Leonor',
#  'Isabella von Dänemark': 'Isabella von Dänemark',
#  'Charlotte Casiraghi': 'Charlotte Casiraghi',
#  'Kate': 'Kate',
#  'Prinz Harry': 'Prinz Harry',
#  'Kjetil Knutsen': 'Kjetil Knutsen',
#  'Patrick Berg': 'Patrick Berg',
#  'Oliver Mintzlaff': 'Oliver Mintzlaff',
#  'Marco Rose': 'Marco Rose',
#  'Zsolt Löw': 'Zsolt Löw',
#  'Teddy de Beer': 'Teddy de Beer',
#  'Giorgia Meloni': 'Giorgia Meloni',
#  'Georgia Meloni': 'Giorgia Meloni',
#  'Daniel Brinkmann': 'Daniel Brinkmann',
#  'Ahmet Gürleyen': 'Ahmet Gürleyen',
#  'ADAC': 'ADAC',
#  'BILD': 'BILD',
#  'Benjamin Netanyahu': 'Benjamin Netanyahu',
#  'Netanyahu': 'Benjamin Netanyahu',
#  'Benyamin Netanyahu': 'Benjamin Netanyahu',
#  "Gideon Sa'ar": "Gideon Sa'ar",
#  'International Criminal Court': 'International Criminal Court',
#  'International Criminal Court (ICC)': 'International Criminal Court',
#  'Liz Truss': 'Liz Truss',
#  'Yvette Cooper': 'Yvette Cooper',
#  'Israel Defense Forces (IDF)': 'Israel Defense Forces (IDF)',
#  'Israel Defense Forces': 'Israel Defense Forces (IDF)',
#  'Israeli Defence Forces': 'Israel Defense Forces (IDF)',
#  'Israel Defence Forces (IDF)': 'Israel Defense Forces (IDF)',
#  'Gideon Saar': 'Gideon Saar',
#  'Palestine Red Crescent Society (PRCS)': 'Palestine Red Crescent Society (PRCS)',
#  'Palestine Red Crescent Society': 'Palestine Red Crescent Society (PRCS)',
#  'Israeli military': 'Israeli military',
#  'Israeli army': 'Israeli military',
#  'Israeli defense forces': 'Israeli forces',
#  'The Israeli military': 'Israeli military',
#  "UN's human rights office": "UN's human rights office",
#  'UN rights office': "UN's human rights office",
#  'Human Rights Council (UNHRC)': "UN's human rights office",
#  'UN Office for the High Commissioner for Human Rights': "UN's human rights office",
#  'UN Office of the High Commissioner for Human Rights': "UN's human rights office",
#  'United Nations Office of the High Commissioner for Human Rights': "UN's human rights office",
#  'UN Human Rights Office': 'UN Human Rights',
#  'Office of the UN High Commissioner for Human Rights (OHCHR)': 'Office of the High Commissioner for Human Rights (OHCHR)',
#  'Office of the UN High Commissioner for Human Rights': 'Office of the High Commissioner for Human Rights (OHCHR)',
#  'Hostages and Missing Families Forum': 'Hostages and Missing Families Forum',
#  'The Hostages and Missing Families Forum': 'Hostages and Missing Families Forum',
#  'Jonathan Reynolds': 'Jonathan Reynolds',
#  'Jingye': 'Jingye',
#  'Bashar al-Assad': 'Bashar al-Assad',
#  'Assad': 'Bashar al-Assad',
#  'Maher al-Assad': 'Bashar al-Assad',
#  'Bachar al-Assad': 'Baschar al-Assad',
#  'Bashar Assad': 'Bashar al-Assad',
#  'Bashar Al-Assad': 'Bashar al-Assad',
#  'Norwich City Council': 'Norwich City Council',
#  'Carli Harper': 'Carli Harper',
#  'Samantha Power': 'Samantha Power',
#  'Students Against Discrimination': 'Students Against Discrimination',
#  'Citibank': 'Citibank',
#  'Citigroup': 'Citibank',
#  'Israel Katz': 'Israel Katz',
#  'Israel Yoav Katz': 'Israel Katz',
#  'Scott Bessent': 'Scott Bessent',
#  'Karoline Leavitt': 'Karoline Leavitt',
#  'Mike Johnson': 'Mike Johnson',
#  'Min Aung Hlaing': 'Min Aung Hlaing',
#  'Keith Kellogg': 'Keith Kellogg',
#  'Mute Egede': 'Mute Egede',
#  'Kuno Fencker': 'Kuno Fencker',
#  'Apple': 'Apple',
#  'Google': 'Google',
#  'West Midlands Police': 'West Midlands Police',
#  'Crimestoppers': 'Crimestoppers',
#  'Justin Baldoni': 'Justin Baldoni',
#  'Blake Lively': 'Blake Lively',
#  'America Ferrera': 'America Ferrera',
#  'Amber Tamblyn': 'Amber Tamblyn',
#  'Alexis Bledel': 'Alexis Bledel',
#  'Colleen Hoover': 'Colleen Hoover',
#  'Jens-Frederik Nielsen': 'Jens-Frederik Nielsen',
#  'Democrats': 'Democratic Party',
#  'Naleraq': 'Naleraq',
#  'Greenland': 'Greenland',
#  'Liam Payne': 'Liam Payne',
#  'Ezequiel Pereyra': 'Ezequiel Pereyra',
#  'Braian Paiz': 'Braian Paiz',
#  'Nores': 'Nores',
#  'Gilda Martin': 'Gilda Martin',
#  'Grassi': 'Grassi',
#  'Maggie Chapman': 'Maggie Chapman',
#  'Miles Briggs': 'Miles Briggs',
#  'Michael Marra': 'Michael Marra',
#  'Mary Senior': 'Mary Senior',
#  'Beyond Paradise': 'Beyond Paradise',
#  'Ben Palmer': 'Ben Palmer',
#  'Adam Hackett': 'Adam Hackett',
#  'Rachel Lee': 'Rachel Lee',
#  'Maree Todd': 'Maree Todd',
#  'Scottish government': 'Scottish government',
#  'Charles Edward Stuart': 'Charles Edward Stuart',
#  'Highland Council': 'Highland Council',
#  'Mark Card': 'Mark Card',
#  'Culloden Community Council': 'Culloden Community Council',
#  'King Charles': 'King Charles',
#  'King Charles III': 'King Charles',
#  'Craig Browne': 'Craig Browne',
#  'Cheshire East': 'Cheshire East',
#  'Cheshire West and Chester': 'Cheshire East',
#  'Nick Mannion': 'Nick Mannion',
#  'Michael Gorman': 'Michael Gorman',
#  'Conservative group': 'Conservative group',
#  'Fidesz': 'Fidesz',
#  'SSEN': 'SSEN',
#  'Keith Brown': 'Keith Brown',
#  "Siobhan's Trust": "Siobhan's Trust",
#  'Nigel Porter': 'Nigel Porter',
#  'Labour': 'Labour',
#  'Labour party': 'Labour Party',
#  'Conservative': 'Conservative',
#  'Esme Moore': 'Esme Moore',
#  'Abdulkadir Ozkan': 'Abdulkadir Ozkan',
#  'fans': 'fans',
#  'Gaye Su Akyol': 'Gaye Su Akyol',
#  'BluSmart': 'BluSmart',
#  'Anmol Singh Jaggi': 'Anmol Singh Jaggi',
#  'Puneet Singh Jaggi': 'Anmol Singh Jaggi',
#  'GEL': 'GEL',
#  'Sebi': 'Sebi',
#  'UK': 'UK',
#  'United Kingdom': 'UK',
#  'U.K.': 'UK',
#  'Jewish people': 'Jewish people',
#  'Arab population': 'Arab population',
#  'UN': 'UN',
#  'United Nations': 'UN',
#  'United Nations (UN)': 'UN',
#  'U.N.': 'UN',
#  'Arab nations': 'Arab nations',
#  'Palestinians': 'Palestinians',
#  'Palestinian people': 'Palestinians',
#  'Palestiniens': 'Palestinians',
#  'Agustín Escobar': 'Agustín Escobar',
#  'Mercè Camprubí Montal': 'Mercè Camprubí Montal',
#  'El Economista': 'El Economista',
#  'Emiliano García-Page': 'Emiliano García-Page',
#  'Tom Cunningham': 'Tom Cunningham',
#  'Phil Morris': 'Phil Morris',
#  'Bradford Council': 'Bradford Council',
#  'Wilkinson': 'Wilkinson',
#  'John Isaacs': 'John Isaacs',
#  'Newcastle University': 'Newcastle University',
#  'Sarah Hanson-Young': 'Sarah Hanson-Young',
#  'Anthony Albanese': 'Anthony Albanese',
#  'United States of America': 'United States of America',
#  'the United States': 'United States of America',
#  'The United States': 'United States of America',
#  'Thames Water': 'Thames Water',
#  'Macquarie': 'Macquarie',
#  'Sir Adrian Montague': 'Sir Adrian Montague',
#  'ACLU': 'ACLU',
#  'American Civil Liberties Union (ACLU)': 'American Civil Liberties Union',
#  'Trump administration': 'Trump administration',
#  'administration Trump': 'Trump administration',
#  'Trump Administration': 'Administration Trump',
#  'Senator Chris Van Hollen': 'Senator Chris Van Hollen',
#  'Chris Van Hollen': 'Senator Chris Van Hollen',
#  'Pete Navarro': 'Pete Navarro',
#  'Peter Navarro': 'Pete Navarro',
#  'William Alan Reinsch': 'William Alan Reinsch',
#  'Johnny Finch': 'Johnny Finch',
#  'Leanne Baister': 'Leanne Baister',
#  'Fiona Conor': 'Fiona Conor',
#  'Trust Electric Heating': 'Trust Electric Heating',
#  'Trevor Muten': 'Trevor Muten',
#  'Brighton & Hove City Council': 'Brighton & Hove City Council',
#  'Heidi Alexander': 'Heidi Alexander',
#  'CPRE': 'CPRE',
#  'LADACAN': 'LADACAN',
#  'Chad': 'Chad',
#  'Lt-Gen Yasir al-Atta': 'Lt-Gen Yasir al-Atta',
#  'Sudan': 'Sudan',
#  'Narendra Modi': 'Narendra Modi',
#  'India': 'India',
#  'Steven Paisley': 'Steven Paisley',
#  'Care Quality Commission': 'Care Quality Commission',
#  'Southern Housing': 'Southern Housing',
#  'Kim Leadbeater': 'Kim Leadbeater',
#  'Eluned Morgan': 'Eluned Morgan',
#  'Jeremy Miles': 'Jeremy Miles',
#  'Sarah Olney': 'Sarah Olney',
#  'Stephen Kinnock': 'Stephen Kinnock',
#  'Sarah Sackman': 'Sarah Sackman',
#  'Irish Writers Union (IWU)': 'Irish Writers Union (IWU)',
#  'Audrey Magee': 'Audrey Magee',
#  'Zulaikha Zeb': 'Zulaikha Zeb',
#  'Zainab Nabeel': 'Zainab Nabeel',
#  'Green Party': 'Green Party',
#  'European Green Party': 'Green Party',
#  'Ecologist Green Party': 'Green Party',
#  'Green Party of England and Wales': 'Green Party',
#  'Reform': 'Reform',
#  'reform': 'Reform',
#  'Adrian Ramsay': 'Adrian Ramsay',
#  'White Helmets': 'White Helmets',
#  'Ahmed al-Sharaa': 'Ahmed al-Sharaa',
#  'Ahmed al-Scharaa': 'Ahmed al-Sharaa',
#  'Ahmed al-Fara': 'Ahmed al-Sharaa',
#  'Ahmad al-Sharaa': 'Ahmed al-Sharaa',
#  'David Lammy': 'David Lammy',
#  'Radek Sikorski': 'Radek Sikorski',
#  'Senate': 'Senate',
#  'U.S. Senate': 'Senate',
#  'Doug Burgum': 'Doug Burgum',
#  'Doug Collins': 'Doug Collins',
#  'Linda McMahon': 'Linda McMahon',
#  'Police Scotland': 'Police Scotland',
#  'Torbian Dennis': 'Torbian Dennis',
#  'Daniel Heath': 'Daniel Heath',
#  'William Lawrence': 'William Lawrence',
#  'Anthony George': 'Anthony George',
#  'Newbury': 'Newbury',
#  'Crown Prosecution Service (CPS)': 'Crown Prosecution Service (CPS)',
#  'Layden': 'Layden',
#  'Lord Hamblen': 'Lord Hamblen',
#  'Kristi Noem': 'Kristi Noem',
#  'Tricia Bey': 'Tricia Bey',
#  "Shane O'Neill": "Shane O'Neill",
#  'Iain Gillespie': 'Iain Gillespie',
#  'Sergee Kelly': 'Sergee Kelly',
#  'Stephen MacAuley': 'Stephen MacAuley',
#  'Dean Wilson': 'Dean Wilson',
#  'Emma Wilson': 'Emma Wilson',
#  'Swissport': 'Swissport',
#  'BA': 'BA',
#  'Gavin Newsom': 'Gavin Newsom',
#  'Karen Bass': 'Karen Bass',
#  'Southern California Edison Company (SCE)': 'Southern California Edison Company (SCE)',
#  'Piers Corbyn': 'Piers Corbyn',
#  'Royal Oldham Hospital': 'Royal Oldham Hospital',
#  'Royal Stoke University Hospital': 'Royal Oldham Hospital',
#  'Great Ormond Street Hospital': 'Royal Oldham Hospital',
#  'Wrightington, Wigan, and Leigh NHS Foundation Trust': 'Wrightington, Wigan, and Leigh NHS Foundation Trust',
#  'Stewart Hutton': 'Stewart Hutton',
#  'Andrew Tate': 'Andrew Tate',
#  'Newsmax': 'Newsmax',
#  'Lesley Manville': 'Lesley Manville',
#  'James Brining': 'James Brining',
#  'Carl Woodward': 'Carl Woodward',
#  'Rachael Thomas': 'Rachael Thomas',
#  'Gareth Machin': 'Gareth Machin',
#  'Stephanie Sirr': 'Stephanie Sirr',
#  'Chris Stafford': 'Chris Stafford',
#  'Paul Carey Jones': 'Paul Carey Jones',
#  'Margaret Aspinall': 'Margaret Aspinall',
#  'military': 'military',
#  'US military': 'military',
#  'Volker Türk': 'Volker Türk',
#  'Volker Turk': 'Volker Türk',
#  'WWF': 'WWF',
#  'Zlatan Milišić': 'Zlatan Milišić',
#  'World Food Programme': 'World Food Programme',
#  'World Food Programme (WFP)': 'World Food Programme',
#  'UN World Food Programme': 'World Food Programme',
#  'Irish government': 'Irish government',
#  'Stormont': 'Stormont',
#  'Dara Calleary': 'Dara Calleary',
#  'Sinn Féin': 'Sinn Féin',
#  'John Gilhooly': 'John Gilhooly',
#  'Wigmore Hall': 'Wigmore Hall',
#  'Sam Jones': 'Sam Jones',
#  'Sally Gunnell': 'Sally Gunnell',
#  'John Marshall': 'John Marshall',
#  'PK Mishra': 'PK Mishra',
#  'Nayanjot Lahiri': 'Nayanjot Lahiri',
#  'Rakhaldas Banerjee': 'Rakhaldas Banerjee',
#  'Nicola Sturgeon': 'Nicola Sturgeon',
#  'Val McDermid': 'Val McDermid',
#  'Nina Barough': 'Nina Barough',
#  'Samina Hussain': 'Samina Hussain',
#  'Samira Hussain': 'Samina Hussain',
#  'Julian Smith': 'Julian Smith',
#  'Justin Smith': 'Julian Smith',
#  'GMB': 'GMB',
#  'Sam Nujoma': 'Sam Nujoma',
#  'Nangolo Mbumba': 'Nangolo Mbumba',
#  'Netumbo Nandi-Ndaitwah': 'Netumbo Nandi-Ndaitwah',
#  'Moussa Faki Mahamat': 'Moussa Faki Mahamat',
#  'Cyril Ramaphosa': 'Cyril Ramaphosa',
#  'William Ruto': 'William Ruto',
#  'Cassandra Ventura': 'Cassandra Ventura',
#  'Casandra Ventura': 'Cassandra Ventura',
#  'Rodney Jones Jr': 'Rodney Jones Jr',
#  'Rodney Jones': 'Rodney Jones Jr',
#  'Tony Buzbee': 'Tony Buzbee',
#  'Jay-Z': 'Jay-Z',
#  'Shawn Holley': 'Shawn Holley',
#  'Marc Agnifilo': 'Marc Agnifilo',
#  'Jonathan Davis': 'Jonathan Davis',
#  'Arlo Lambie': 'Arlo Lambie',
#  'Gloucestershire County Council': 'Gloucestershire County Council',
#  'Bibury Parish Council': 'Bibury Parish Council',
#  'Brice Oligui Nguema': 'Brice Oligui Nguema',
#  'Gen Brice Oligui Nguema': 'Brice Oligui Nguema',
#  'Landry Obame-Mezui': 'Landry Obame-Mezui',
#  'Alain Claude Bilie-by-Nze': 'Alain Claude Bilie-by-Nze',
#  'Alain Claude Bilie-By-Nze': 'Alain Claude Bilie-by-Nze',
#  'Alain-Claude Bilie By Nze': 'Alain Claude Bilie-by-Nze',
#  'Victoria Chapman': 'Victoria Chapman',
#  'Natural Resources Wales': 'Natural Resources Wales',
#  'Italy': 'Italy',
#  'Dina Boluarte': 'Dina Boluarte',
#  'Wood Group': 'Wood Group',
#  'Jim Fairlie': 'Jim Fairlie',
#  'NatureScot': 'NatureScot',
#  'Stephanie Grisham': 'Stephanie Grisham',
#  'Elise Stefanik': 'Elise Stefanik',
#  'Pierre Poilievre': 'Pierre Poilievre',
#  'Jagmeet Singh': 'Jagmeet Singh',
#  'Yves-François Blanchet': 'Yves-François Blanchet',
#  'ruling military junta': 'ruling military junta',
#  'Pete Hoekstra': 'Pete Hoekstra',
#  'Israeli forces': 'Israeli forces',
#  'civil defence': 'civil defence',
#  'Antonio Guterres': 'Antonio Guterres',
#  'António Guterres': 'Antonio Guterres',
#  'Sa’ar': 'Sa’ar',
#  'WHO': 'WHO',
#  'Tedros Adhanom Ghebreyesus': 'Tedros Adhanom Ghebreyesus',
#  'Michael Martin': 'Michael Martin',
#  'Nuri Aslan': 'Nuri Aslan',
#  'Ozgur Ozel': 'Ozgur Ozel',
#  'Justin Trudeau': 'Justin Trudeau',
#  'Pierre Trudeau': 'Justin Trudeau',
#  'Chrystia Freeland': 'Chrystia Freeland',
#  'Melanie Joly': 'Melanie Joly',
#  'Lai Ching-te': 'Lai Ching-te',
#  'Lai-Ching-te': 'Lai Ching-te',
#  'Prince Khalid bin Salman': 'Prince Khalid bin Salman',
#  'Prince Khalid bin Bandar Al Saud': 'Prince Khalid bin Salman',
#  'Saudi Arabia': 'Saudi Arabia',
#  'Houthis': 'Houthis',
#  'Abu Obeida': 'Abu Obeida',
#  'Abou Obeida': 'Abu Obeida',
#  'Pope Francis': 'Pope Francis',
#  'Mitri Raheb': 'Mitri Raheb',
#  'Pope Tawadros II': 'Pope Tawadros II',
#  'Finland': 'Finland',
#  'Finnland': 'Finland',
#  'Estonia': 'Estonia',
#  'Latvia': 'Latvia',
#  'Lithuania': 'Lithuania',
#  'Poland': 'Poland',
#  'Petteri Orpo': 'Petteri Orpo',
#  'Alexander Stubb': 'Alexander Stubb',
#  'Philippe Vedovini': 'Philippe Vedovini',
#  "Moody's": "Moody's",
#  'Moody’s': "Moody's",
#  'Gabriel Attal': 'Gabriel Attal',
#  'Cyril Hanouna': 'Cyril Hanouna',
#  'LFI': 'LFI',
#  'M6': 'M6',
#  'Brice Cardi': 'Brice Cardi',
#  'Francis Szpiner': 'Francis Szpiner',
#  'Rassemblement national': 'Rassemblement national',
#  'Assemblée nationale': 'Rassemblement national',
#  'Rassemblement National': 'Rassemblement national',
#  'Rassemblement national (RN)': 'Rassemblement national',
#  'Manuel Bompard': 'Manuel Bompard',
#  'Denis Scherrer': 'Denis Scherrer',
#  'Guillaume Sommerer': 'Guillaume Sommerer',
#  'Bruno Bonnell': 'Bruno Bonnell',
#  'Jonathann Daval': 'Jonathann Daval',
#  'Alexia Fouillot': 'Alexia Fouillot',
#  'Martine Henry': 'Martine Henry',
#  'Les Républicains': 'Les Républicains',
#  'Gérald Darmanin': 'Gérald Darmanin',
#  'Xi Jinping': 'Xi Jinping',
#  'Éric Lombard': 'Éric Lombard',
#  'Olympique Lyonnais': 'Olympique Lyonnais',
#  'Olympique Lyon': 'Olympique Lyonnais',
#  'Donatella Versace': 'Donatella Versace',
#  'Sylvain Maillard': 'Sylvain Maillard',
#  'Anne Hidalgo': 'Anne Hidalgo',
#  'Emmanuel Grégoire': 'Emmanuel Grégoire',
#  'Renaud Muselier': 'Renaud Muselier',
#  'Olivier Marleix': 'Olivier Marleix',
#  'Franck Allissio': 'Franck Allissio',
#  'Bastien Lachaud': 'Bastien Lachaud',
#  'Patrick Mignola': 'Patrick Mignola',
#  'Benoît Payan': 'Benoît Payan',
#  'Chine': 'Chine',
#  'Lin Jian': 'Lin Jian',
#  'Li Tian': 'Lin Jian',
#  'Eline Gastaud': 'Eline Gastaud',
#  'direction interrégionale des services pénitentiaires de Marseille': 'direction interrégionale des services pénitentiaires de Marseille',
#  'Bruno Retailleau': 'Bruno Retailleau',
#  'Mehdi Nemmouche': 'Mehdi Nemmouche',
#  "cour d'assises spéciales de Paris": "cour d'assises spéciales de Paris",
#  'Beaujolais': 'Beaujolais',
#  'Olivier Besancenot': 'Olivier Besancenot',
#  'Renaissance': 'Renaissance',
#  'Telegram': 'Telegram',
#  'Laure Beccuau': 'Laure Beccuau',
#  'Israël Katz': 'Israël Katz',
#  'Israël': 'Israël',
#  'Sébastien Cauwel': 'Sébastien Cauwel',
#  'Matignon': 'Matignon',
#  'gouvernement': 'gouvernement',
#  'Le gouvernement': 'gouvernement',
#  'RN': 'RN',
#  'UDR': 'UDR',
#  'Droite Républicaine': 'Droite Républicaine',
#  'Droite républicaine': 'Droite Républicaine',
#  'France insoumise': 'France insoumise',
#  'La France insoumise': 'France insoumise',
#  'la France insoumise': 'France insoumise',
#  'Thomas Ménagé': 'Thomas Ménagé',
#  '84% des Français': '84% des Français',
#  '60% des Français': '84% des Français',
#  '75% des personnes interrogées': '75% des personnes interrogées',
#  'Airbus': 'Airbus',
#  'Pologne': 'Pologne',
#  'Cologne': 'Pologne',
#  'États-Unis': 'États-Unis',
#  'Guillaume Faury': 'Guillaume Faury',
#  'Donald Tusk': 'Donald Tusk',
#  'Allemagne': 'Allemagne',
#  'Espagne': 'Espagne',
#  'Sofia Benlemmane': 'Sofia Benlemmane',
#  'procureur': 'procureur',
#  'Zazou Youssef': 'Zazou Youssef',
#  'Doualemn': 'Doualemn',
#  'Imad Tintin': 'Imad Tintin',
#  'Raphaël Legendre': 'Raphaël Legendre',
#  'Rose-Marie Bertaud': 'Rose-Marie Bertaud',
#  'Bernard Guetta': 'Bernard Guetta',
#  'Vladimir Poutine': 'Vladimir Poutine',
#  'Kiev': 'Kiev',
#  'Kyiv': 'Kiev',
#  'Jean-François Huchet': 'Jean-François Huchet',
#  'Lior Raz': 'Lior Raz',
#  'Alain Duhamel': 'Alain Duhamel',
#  'high ambition coalition': 'high ambition coalition',
#  'Rachida Dati': 'Rachida Dati',
#  'Alassane Ouattara': 'Alassane Ouattara',
#  'SNCF': 'SNCF',
#  'Transilien SNCF': 'SNCF',
#  'Police': 'Police',
#  'police': 'Police',
#  'Jean-Marie Le Pen': 'Jean-Marie Le Pen',
#  'Marine Le Pen': 'Jean-Marie Le Pen',
#  'Le Pen': 'Jean-Marie Le Pen',
#  'Marie Le Pen': 'Jean-Marie Le Pen',
#  'Meloni': 'Meloni',
#  'Orano': 'Orano',
#  'Greve feministe': 'Greve feministe',
#  'Milorad Dodik': 'Milorad Dodik',
#  'DRC': 'DRC',
#  'Antony Blinken': 'Antony Blinken',
#  'Anthony Blinken': 'Antony Blinken',
#  'Constitutional Council': 'Constitutional Council',
#  '9 October election': '9 October election',
#  '4 July elections': '9 October election',
#  '5 November election': '5 November vote',
#  'Emmanuel': 'Emmanuel',
#  'Council of State': 'Council of State',
#  ...}

# %%
# Drop over-clustered entries
bad_cluster_keys = ["Bundesgesundheitsministerium", "ministère français des Affaires étrangères"]
for key in bad_cluster_keys:
    if key in clusters:
        del clusters[key]

# 5. Create resolution map
resolution_map = {alias: canon for canon, aliases in clusters.items() for alias in aliases}
resolution_map.update(manual_resolutions)
resolution_map
# Out:
# {'Emmanuel Macron': 'Emmanuel Macron',
#  'Macron': 'Emmanuel Macron',
#  'Emmanual Macron': 'Emmanuel Macron',
#  'Algiers': 'Algiers',
#  'Paris': 'Paris',
#  'Starmer': 'Starmer',
#  'Haiti': 'Haiti',
#  'M23': 'M23',
#  'Luc Remont': 'Luc Remont',
#  'Luc Rémont': 'Luc Remont',
#  'Israel': 'Israel',
#  'Donald Trump': 'Donald Trump',
#  'Trump': 'Donald Trump',
#  'Donald J. Trump': 'Donald Trump',
#  'Donald J Trump': 'Donald Trump',
#  'US border agents': 'US border agents',
#  'U.S. border officers': 'U.S. Border Patrol',
#  'France': 'France',
#  'Mali': 'Mali',
#  'Niger': 'Niger',
#  'Burkina Faso': 'Burkina Faso',
#  'Denmark': 'Denmark',
#  'National Rally': 'National Rally',
#  'National Rally (RN)': 'National Rally',
#  'National Rally (NR)': 'National Rally',
#  "Iran's foreign ministry": "Iran's foreign ministry",
#  "Iran's Foreign Ministry": "Iran's foreign ministry",
#  'Iranian foreign ministry': "Iran's foreign ministry",
#  'Iran’s foreign ministry': "Iran's foreign ministry",
#  'Marco Rubio': 'Marco Rubio',
#  'Rubio': 'Marco Rubio',
#  'European farmers': 'European farmers',
#  'Barnier': 'Barnier',
#  'George Simeon': 'George Simeon',
#  "France's government": "France's government",
#  'French government': "France's government",
#  'protestors': 'protestors',
#  'protesters': 'protestors',
#  'Protesters': 'protestors',
#  'French voters': 'French voters',
#  'leftist coalition': 'leftist coalition',
#  'Max Verstappen': 'Max Verstappen',
#  'Algeria': 'Algeria',
#  'Pakistan': 'Pakistan',
#  'Islamabad': 'Islamabad',
#  'Volodymyr Zelensky': 'Volodymyr Zelensky',
#  'Volodymyr Zelenskyy': 'Volodymyr Zelensky',
#  'Volodymr Zelenskyy': 'Volodymyr Zelensky',
#  'Volodymyr Zelenskiy': 'Volodymyr Zelensky',
#  'Volodymyr Zelynsky': 'Volodymyr Zelensky',
#  'PSV Eindhoven': 'PSV Eindhoven',
#  'Italian parliamentarians': 'Italian parliamentarians',
#  "Niger's junta": "Niger's junta",
#  'Wout van Aert': 'Wout van Aert',
#  'Isaac del Toro': 'Isaac del Toro',
#  'Qatar': 'Qatar',
#  'United States': 'United States',
#  'US': 'United States',
#  'USA': 'United States',
#  'U.S.': 'United States',
#  'United states': 'United States',
#  'Mark Rutte': 'Mark Rutte',
#  'Francesco Bagnaia': 'Francesco Bagnaia',
#  'Jensen Huang': 'Jensen Huang',
#  'JD Vance': 'JD Vance',
#  'European Union': 'European Union',
#  'European Union (EU)': 'European Union',
#  'Francois Bayrou': 'Francois Bayrou',
#  'François Bayrou': 'Francois Bayrou',
#  'Bayrou': 'Francois Bayrou',
#  'Francis Bayrou': 'Francois Bayrou',
#  'Argentina': 'Argentina',
#  'Argentin': 'Argentinien',
#  'Javier Milei': 'Javier Milei',
#  'Elon Musk': 'Elon Musk',
#  'Errol Musk': 'Elon Musk',
#  'Vladimir Putin': 'Vladimir Putin',
#  'Wladimir Putin': 'Vladimir Putin',
#  'Vladímir Putin': 'Vladimir Putin',
#  'Vladimir V. Putin': 'Vladimir Putin',
#  'Shigeru Ishiba': 'Shigeru Ishiba',
#  'Iran': 'Iran',
#  'Washington': 'Washington',
#  'Rwanda': 'Rwanda',
#  'Hamas': 'Hamas',
#  'British government': 'British government',
#  "Britain's government": 'British government',
#  'UK government': 'British government',
#  'U.K. government': 'British government',
#  'Brussels': 'Brussels',
#  'Jean-Noël Barrot': 'Jean-Noël Barrot',
#  'Jean-Noel Barrot': 'Jean-Noël Barrot',
#  'Imamoglu': 'Imamoglu',
#  'İmamoğlu': 'Imamoglu',
#  'Al-Shabaab': 'Al-Shabaab',
#  'Al-Shabab': 'Al-Shabaab',
#  'far right': 'far right',
#  'Viktor Orban': 'Viktor Orban',
#  'Viktor Orbán': 'Viktor Orban',
#  'Orban': 'Viktor Orban',
#  'Victor Orban': 'Viktor Orban',
#  'Geert Wilders': 'Geert Wilders',
#  'Gert Wilders': 'Geert Wilders',
#  'EU': 'EU',
#  'Kylian Mbappé': 'Kylian Mbappé',
#  'Kylian Mbappe': 'Kylian Mbappé',
#  'US Supreme Court': 'US Supreme Court',
#  'Supreme Court': 'US Supreme Court',
#  'U.S. Supreme Court': 'US Supreme Court',
#  'Supreme Courts': 'US Supreme Court',
#  'United States Supreme Court': 'US Supreme Court',
#  'Federal Supreme Court': 'US Supreme Court',
#  'Romania’s electoral bureau': 'Romania’s electoral bureau',
#  'Romania’s Central Electoral Commission': 'Romania’s electoral bureau',
#  'French antitrust authorities': 'French antitrust authorities',
#  'White House': 'White House',
#  'The White House': 'White House',
#  'the White House': 'White House',
#  'Whitehouse': 'White House',
#  'Zelensky': 'Zelensky',
#  'Zelenskyy': 'Volodymyr Zelensky',
#  'Bosnia': 'Bosnia',
#  'Serbia': 'Bosnia',
#  'Yugoslavia': 'Montenegro',
#  'G7': 'G7',
#  'Russia': 'Russia',
#  'US Treasury': 'US Treasury',
#  'U.S. Treasury': 'Treasury Department',
#  'Recep Tayyip Erdogan': 'Recep Tayyip Erdogan',
#  'Recep Tayyip Erdoğan': 'Recep Tayyip Erdogan',
#  'Tayyip Erdogan': 'Recep Tayyip Erdogan',
#  'Erdoğan': 'Recep Tayyip Erdogan',
#  'Erdogan': 'Recep Tayyip Erdogan',
#  'Tayyip Erdoğan': 'Recep Tayyip Erdogan',
#  'Turkey': 'Turkey',
#  'Ekrem Imamoglu': 'Ekrem Imamoglu',
#  'Ekrem İmamoğlu': 'Ekrem Imamoglu',
#  'Philippine': 'Philippine',
#  'Philippines': 'Philippine',
#  'Britain': 'Britain',
#  'Great Britain': 'Britain',
#  'the UK': 'Britain',
#  'Muhammad Ilyas': 'Muhammad Ilyas',
#  'Bundeswehr': 'Bundeswehr',
#  'Feuerwehr': 'Bundeswehr',
#  'Nato': 'Nato',
#  'NATO': 'Nato',
#  'Alexander Sollfrank': 'Alexander Sollfrank',
#  'Thomas Mann': 'Thomas Mann',
#  'Kritiker': 'Kritiker',
#  'Saúl Lliuya': 'Saúl Lliuya',
#  'Christian Tischner': 'Christian Tischner',
#  'Friedrich Merz': 'Friedrich Merz',
#  'Verein Aufarbeitung Kinderverschickungen NRW': 'Verein Aufarbeitung Kinderverschickungen NRW',
#  'Landesregierung': 'Landesregierung',
#  'CHP': 'CHP',
#  'Justiz': 'Justiz',
#  'Landesumweltministerium': 'Landesumweltministerium',
#  'Bernd Mettenleiter': 'Bernd Mettenleiter',
#  'Republikaner': 'Republikaner',
#  'Shen Xiaomeng': 'Shen Xiaomeng',
#  'Zhu Xiaoming': 'Shen Xiaomeng',
#  'Niko Kovac': 'Niko Kovac',
#  'Ursula von der Leyen': 'Ursula von der Leyen',
#  'Ursula Von der Leyen': 'Ursula von der Leyen',
#  'Maros Sefcovic': 'Maros Sefcovic',
#  'CDU Sachsen-Anhalt': 'CDU Sachsen-Anhalt',
#  'Berliner CDU': 'Berliner CDU',
#  'Bundes-CDU': 'CDU-Bundestagsabgeordneten',
#  'CSU': 'CSU',
#  'Winfried Hermann': 'Winfried Hermann',
#  'Verbände': 'Verbände',
#  'Sachverständigenrat der Landesregierung': 'Sachverständigenrat der Landesregierung',
#  'Domenico Tedesco': 'Domenico Tedesco',
#  'Matthias Tillmann': 'Matthias Tillmann',
#  'Raúl': 'Raúl',
#  'Peter Füssenich': 'Peter Füssenich',
#  'FC Bayern München': 'FC Bayern München',
#  'FC Bayern': 'FC Bayern München',
#  'Bayern Munich': 'Bayern',
#  'Bayern München': 'Bayern',
#  'Vincent Kompany': 'Vincent Kompany',
#  'US-Regierung': 'US-Regierung',
#  'US-Regierungsvertretern': 'US-Regierung',
#  'Joe Biden': 'Joe Biden',
#  'Joseph R. Biden Jr.': 'Joe Biden',
#  'Joseph R Biden Jr.': 'Joe Biden',
#  'Frederik Tiffels': 'Frederik Tiffels',
#  'Serge Aubin': 'Serge Aubin',
#  'Jusos': 'Jusos',
#  'Juso': 'Jusos',
#  'Benedict Lang': 'Benedict Lang',
#  'SPD': 'SPD',
#  'Achim Post': 'Achim Post',
#  'CDU': 'CDU',
#  'Christian Democratic Union (CDU)': 'CDU',
#  'Markus Söder': 'Markus Söder',
#  'Bayern': 'Bayern',
#  'Wolfsburg': 'VfL Wolfsburg',
#  'Bayerns': 'Bayern',
#  'Freistaat Bayern': 'Freistaat Bayern',
#  'Internationales Schifffahrtsbüro (IMB)': 'Internationales Schifffahrtsbüro (IMB)',
#  'Volker Waltmann': 'Volker Waltmann',
#  'DIHK': 'DIHK',
#  'Kai Seefried': 'Kai Seefried',
#  'Olaf Lies': 'Olaf Lies',
#  'HEH': 'HEH',
#  'Friedemann Hanke': 'Friedemann Hanke',
#  'Annalena Baerbock': 'Annalena Baerbock',
#  'Bundes': 'Bundes',
#  'Peking': 'Peking',
#  'Lars Klingbeil': 'Lars Klingbeil',
#  'Sean "Diddy" Combs': 'Sean "Diddy" Combs',
#  "Sean 'Diddy' Combs": 'Sean "Diddy" Combs',
#  'Sean “Diddy” Combs': 'Sean "Diddy" Combs',
#  'Casandra "Cassie" Ventura': 'Casandra "Cassie" Ventura',
#  'Casandra “Cassie” Ventura': 'Casandra "Cassie" Ventura',
#  'Harvey Weinstein': 'Harvey Weinstein',
#  'Arnd Franz': 'Arnd Franz',
#  'Mahle': 'Mahle',
#  'André Olveira-Lenz': 'André Olveira-Lenz',
#  'Björn Sucher': 'Björn Sucher',
#  'Gabriele Terland': 'Gabriele Terland',
#  'Niko Bungert': 'Niko Bungert',
#  'Fridays for Future': 'Fridays for Future',
#  'Fabian Leendertz': 'Fabian Leendertz',
#  'Yap Boum': 'Yap Boum',
#  'Alexandre Hassanin': 'Alexandre Hassanin',
#  'Kristian Andersen': 'Kristian Andersen',
#  'Leendertz': 'Leendertz',
#  'Robert F. Kennedy Jr.': 'Robert F. Kennedy Jr.',
#  'Robert F Kennedy Jr': 'Robert F. Kennedy Jr.',
#  'John Kennedy': 'Robert F. Kennedy Jr.',
#  'John F. Kennedy': 'John F. Kennedy',
#  'John F Kennedy': 'John F. Kennedy',
#  'Robert Kennedy': 'Robert F. Kennedy Jr.',
#  'Robert Kennedy Jr': 'Robert F. Kennedy Jr.',
#  'Robert F. Kennedy, Jr.': 'Robert F. Kennedy Jr.',
#  'Robert F. Kennedy': 'Robert F. Kennedy',
#  'Robert Kennedy Sr': 'Robert F. Kennedy Jr.',
#  'Kanada': 'Kanada',
#  'Alexander Schweitzer': 'Alexander Schweitzer',
#  'Ägypten': 'Ägypten',
#  'Katar': 'Katar',
#  'Parlament': 'Parlament',
#  'Mats Hummels': 'Mats Hummels',
#  'Melissa Butt': 'Melissa Butt',
#  'Philipp Türmer': 'Philipp Türmer',
#  'Thüringer Jusos': 'Thüringer Jusos',
#  'Céline Dion': 'Céline Dion',
#  'Paola': 'Paola',
#  'Luca Hänni': 'Luca Hänni',
#  'Dino Toppmöller': 'Dino Toppmöller',
#  'Axel Hellmann': 'Axel Hellmann',
#  'Anke Rehlinger': 'Anke Rehlinger',
#  'Janet Mills': 'Janet Mills',
#  'Jürgen Klopp': 'Jürgen Klopp',
#  'Robert Lehmann': 'Robert Lehmann',
#  'britische Regierung': 'britische Regierung',
#  'B.H. Holding GmbH': 'B.H. Holding GmbH',
#  'Landgericht Stuttgart': 'Landgericht Stuttgart',
#  'Klingbeil': 'Klingbeil',
#  'Saskia Esken': 'Saskia Esken',
#  'Union': 'Union',
#  'Staatsanwaltschaft': 'Staatsanwaltschaft',
#  'Nürnberger Zentralstelle zur Bekämpfung von Betrug und Korruption im Gesundheitswesen (ZKG)': 'Nürnberger Zentralstelle zur Bekämpfung von Betrug und Korruption im Gesundheitswesen (ZKG)',
#  'Generalstaatsanwaltschaft Nürnberg': 'Generalstaatsanwaltschaft Nürnberg',
#  'der 43-jährige deutsche Tatverdächtige': 'der 43-jährige deutsche Tatverdächtige',
#  'Generalstaatsanwaltschaft Stuttgart': 'Generalstaatsanwaltschaft Stuttgart',
#  'Luigi Brugnaro': 'Luigi Brugnaro',
#  'Unbekannten': 'Unbekannten',
#  'Polizei': 'Polizei',
#  'AfD-Landtagsfraktion': 'AfD-Landtagsfraktion',
#  'AfD-Fraktion': 'AfD-Landtagsfraktion',
#  'Dmitri Medwedew': 'Dmitri Medwedew',
#  'Dmitri Peskow': 'Dmitri Peskow',
#  'Dmitri Peskov': 'Dmitri Peskow',
#  'Olaf Scholz': 'Olaf Scholz',
#  'Nordkorea': 'Nordkorea',
#  'Yoon Suk Yeol': 'Yoon Suk Yeol',
#  'Yoon Suk-yeol': 'Yoon Suk Yeol',
#  'Leon Ziegler': 'Leon Ziegler',
#  'Alex Müller': 'Alex Müller',
#  'Thomas Müller': 'Gerd Müller',
#  'Iris Spranger': 'Iris Spranger',
#  'Gewerkschaft der Polizei (GdP)': 'Gewerkschaft der Polizei (GdP)',
#  'Jesuiten-Flüchtlingsdienst': 'Jesuiten-Flüchtlingsdienst',
#  'Obama': 'Obama',
#  'Barack Obama': 'Obama',
#  'Biden': 'Joe Biden',
#  'Jörg Urban': 'Jörg Urban',
#  'VfL Wolfsburg': 'VfL Wolfsburg',
#  'VfB Stuttgart': 'VfL Wolfsburg',
#  'SC Freiburg': 'VfL Wolfsburg',
#  'VfL Bochum': 'VfL Osnabrück',
#  'Herbert Reul': 'Herbert Reul',
#  'Stephanie Thien': 'Stephanie Thien',
#  'Alexander Kekulè': 'Alexander Kekulè',
#  'Detlev Krüger': 'Detlev Krüger',
#  'EZB': 'EZB',
#  'Putin': 'Putin',
#  'SoVD': 'SoVD',
#  'Engelmeier': 'Engelmeier',
#  'Merz': 'Merz',
#  'Körzell': 'Körzell',
#  'Esdar': 'Esdar',
#  'Wiese': 'Wiese',
#  'Büdenbender': 'Büdenbender',
#  'Langkamp': 'Langkamp',
#  'Maier': 'Maier',
#  'Wirtschaft': 'Wirtschaft',
#  'Erding': 'Erding',
#  'Fischedick': 'Fischedick',
#  'Türmer': 'Türmer',
#  'Günther': 'Günther',
#  'Rehlinger': 'Rehlinger',
#  'Heil': 'Heil',
#  'Pfeiffer': 'Pfeiffer',
#  'Klüssendorf': 'Klüssendorf',
#  'Karin Prien': 'Karin Prien',
#  'Dorothee Bär': 'Dorothee Bär',
#  'Armin Laschet': 'Armin Laschet',
#  'Jens Spahn': 'Jens Spahn',
#  'Bundestages': 'Bundestages',
#  'Alexander Dobrindt': 'Alexander Dobrindt',
#  'Peter Altmaier': 'Peter Altmaier',
#  'Gerd Müller': 'Gerd Müller',
#  'Norbert Lammert': 'Norbert Lammert',
#  'Konstantin von Notz': 'Konstantin von Notz',
#  'Michael Kretschmer': 'Michael Kretschmer',
#  'Volker Wissing': 'Volker Wissing',
#  'EU-Kommission': 'EU-Kommission',
#  'Henna Virkkunen': 'Henna Virkkunen',
#  'Holger Münch': 'Holger Münch',
#  'Peter Münch': 'Holger Münch',
#  'Robert Rethfeld': 'Robert Rethfeld',
#  'Kemal Irmal': 'Kemal Irmal',
#  'Yusuf Tekin': 'Yusuf Tekin',
#  'Wagenknecht': 'Wagenknecht',
#  'BSW': 'BSW',
#  'Mohamed Ali': 'Mohamed Ali',
#  'AfD': 'AfD',
#  'Bianca Radlbeck': 'Bianca Radlbeck',
#  'Mein Grundeinkommen': 'Mein Grundeinkommen',
#  'Howard Lutnick': 'Howard Lutnick',
#  'Howard Lutnic': 'Howard Lutnick',
#  'Adam Schiff': 'Adam Schiff',
#  'Oman': 'Oman',
#  'John Kerry': 'John Kerry',
#  'John F. Kerry': 'John Kerry',
#  'Bärbel Bas': 'Bärbel Bas',
#  'Nancy Faeser': 'Nancy Faeser',
#  'Matthias Miersch': 'Matthias Miersch',
#  'Katja Mast': 'Katja Mast',
#  'Roderich Kiesewetter': 'Roderich Kiesewetter',
#  'Manuela Schwesig': 'Manuela Schwesig',
#  'Palästinenser': 'Palästinenser',
#  'israelische Regierung': 'israelische Regierung',
#  'israelischen Regierung': 'israelische Regierung',
#  'Sigmar Gabriel': 'Sigmar Gabriel',
#  'Bundesverfassungsgericht': 'Bundesverfassungsgericht',
#  'Verfassungsgericht': 'Bundesverfassungsgericht',
#  'Bundesgericht': 'Bundesverfassungsgericht',
#  'Bundesverwaltungsgericht': 'Bundesverfassungsgericht',
#  'Bundesverfassungsgerichts': 'Bundesverfassungsgericht',
#  'Karl Lauterbach': 'Karl Lauterbach',
#  'Lauterbach': 'Karl Lauterbach',
#  'Susanne Meunier': 'Susanne Meunier',
#  'Bastian Kunkel': 'Bastian Kunkel',
#  'Henriette Neubert': 'Henriette Neubert',
#  'Amnesty International': 'Amnesty International',
#  'Julia Duchrow': 'Julia Duchrow',
#  'Taha al-Haji': 'Taha al-Haji',
#  'Mohammed bin Salman': 'Mohammed bin Salman',
#  'Bundesregierung': 'Bundesregierung',
#  'Staatsregierung': 'Bundesregierung',
#  'Regierungsbildung': 'Regierung',
#  'Polen': 'Polen',
#  'BR': 'BR',
#  'Bundesgesellschaft für Endlagerung': 'Bundesgesellschaft für Endlagerung',
#  'Bruno Thomauske': 'Bruno Thomauske',
#  'Iris Graffunder': 'Iris Graffunder',
#  'Christian Kühn': 'Christian Kühn',
#  'BASE': 'BASE',
#  'Pia Lamberty': 'Pia Lamberty',
#  'Claudia Kemfert': 'Claudia Kemfert',
#  'Julia Wandt': 'Julia Wandt',
#  'Eva Högl': 'Eva Högl',
#  'Boris Pistorius': 'Boris Pistorius',
#  'Josefine Königbauer': 'Josefine Königbauer',
#  'Deutsche Gesellschaft für Gynäkologie und Geburtshilfe': 'Deutsche Gesellschaft für Gynäkologie und Geburtshilfe',
#  'J.K. Rowling': 'J.K. Rowling',
#  'Daniel Radcliffe': 'Daniel Radcliffe',
#  'Emma Watson': 'Emma Watson',
#  'Iordanis Georgiadis': 'Iordanis Georgiadis',
#  'Taxizentrale': 'Taxizentrale',
#  'Taxifahrer': 'Taxifahrer',
#  'Harvard': 'Harvard',
#  'Harvard University': 'Harvard',
#  'Alan Garber': 'Alan Garber',
#  'Micheál Martin': 'Micheál Martin',
#  'Lloyd Austin': 'Lloyd Austin',
#  'Agnès Callamard': 'Agnès Callamard',
#  'Keir Starmer': 'Keir Starmer',
#  'Sir Keir Starmer': 'Keir Starmer',
#  'Ukraine': 'Ukraine',
#  'Australian think tank': 'Australian think tank',
#  'Georgescu': 'Georgescu',
#  'Lucian Georgescu': 'Georgescu',
#  'Rima Hassan': 'Rima Hassan',
#  'David Lisnard': 'David Lisnard',
#  'Mark Carney': 'Mark Carney',
#  'Amir Boukhors': 'Amir Boukhors',
#  'Algérie': 'Algérie',
#  'Algérien': 'Algérie',
#  'Algerien': 'Algérie',
#  'Julie': 'Julie',
#  'Julia': 'Julie',
#  'Gérard Depardieu': 'Gérard Depardieu',
#  'Gerard Depardieu': 'Gérard Depardieu',
#  'Jérémie Assous': 'Jérémie Assous',
#  'Jeremie Assous': 'Jérémie Assous',
#  'SNCF Voyageurs': 'SNCF Voyageurs',
#  'Alstom': 'Alstom',
#  'Île-de-France Mobilités (IDFM)': 'Île-de-France Mobilités (IDFM)',
#  'Steve Witkoff': 'Steve Witkoff',
#  'Steven Witkoff': 'Steve Witkoff',
#  'Steve Wittkoff': 'Steve Witkoff',
#  'Mike Waltz': 'Mike Waltz',
#  'Michael Waltz': 'Mike Waltz',
#  'Sergej Lawrow': 'Sergej Lawrow',
#  'Jurij Uschakow': 'Jurij Uschakow',
#  'Matthias Quent': 'Matthias Quent',
#  'Brexit': 'Brexit',
#  'Brexit vote': 'Brexit',
#  'Russlands': 'Russlands',
#  'Radfahrer': 'Radfahrer',
#  'Musk': 'Elon Musk',
#  'Jan Philipp Burgard': 'Jan Philipp Burgard',
#  'FPÖ': 'FPÖ',
#  'ÖVP': 'ÖVP',
#  'Neos': 'Neos',
#  'Grünen': 'Grünen',
#  'Grüne': 'Grünen',
#  'Hisbollah-Miliz': 'Hisbollah-Miliz',
#  'Demonstranten': 'Demonstranten',
#  'Hind Kabawat': 'Hind Kabawat',
#  'Hooters': 'Hooters',
#  'US-Präsident': 'US-Präsident',
#  'US-Präsidenten': 'US-Präsident',
#  'Ralf Eckert': 'Ralf Eckert',
#  'US-Banken': 'US-Banken',
#  'europäischen Großbanken': 'europäischen Großbanken',
#  'BMW': 'BMW',
#  'Arias': 'Arias',
#  'Betonblock': 'Betonblock',
#  'US-Justiz': 'US-Justiz',
#  'Obersten Gerichtshof': 'Obersten Gerichtshof',
#  'Regina Steffens': 'Regina Steffens',
#  'Maximilian Sepp': 'Maximilian Sepp',
#  'Sahra Wagenknecht': 'Sahra Wagenknecht',
#  'Dovile Sakaliene': 'Dovile Sakaliene',
#  'Oppositionsparteien': 'Oppositionsparteien',
#  'FDP': 'FDP',
#  'Linken': 'Linken',
#  'Vatikan': 'Vatikan',
#  'Görke': 'Görke',
#  'Unternehmensverbände': 'Unternehmensverbände',
#  'Branchenverbänden': 'Branchenverbänden',
#  'Kreml': 'Kreml',
#  'Pete Hegseth': 'Pete Hegseth',
#  'Jill Biden': 'Jill Biden',
#  'China': 'China',
#  'Söder': 'Söder',
#  'Thomas': 'Thomas',
#  'Siemens AG': 'Siemens AG',
#  'Siemens': 'Siemens AG',
#  'Siemens Energy AG': 'Siemens Energy',
#  'Rutte': 'Rutte',
#  'bayerische SPD': 'bayerische SPD',
#  'Marvin Gaye': 'Marvin Gaye',
#  'Stiftung': 'Stiftung',
#  'Bill Ackman': 'Bill Ackman',
#  'Christian Dirschauer': 'Christian Dirschauer',
#  'Menschen': 'Menschen',
#  'Nietzard': 'Nietzard',
#  'Poschardt': 'Poschardt',
#  'Tischner': 'Tischner',
#  'Bain Capital': 'Bain Capital',
#  'Cinven': 'Cinven',
#  'Frauke Böger': 'Frauke Böger',
#  'Dilek Kalayci': 'Dilek Kalayci',
#  'GTAI': 'GTAI',
#  'Deutschland': 'Deutschland',
#  'Germany': 'Deutschland',
#  'Disney': 'Disney',
#  'Wolodymyr Selenskyj': 'Wolodymyr Selenskyj',
#  'Wolodimir Selenskij': 'Wolodymyr Selenskyj',
#  'Deepam Seth': 'Deepam Seth',
#  'Lynn Song': 'Lynn Song',
#  'Bezirksregierung': 'Bezirksregierung',
#  'Bund': 'Bund',
#  'Christian Lindner': 'Christian Lindner',
#  'Mariam Lau': 'Mariam Lau',
#  'Winfried Kretschmann': 'Winfried Kretschmann',
#  'Enzo Weber': 'Enzo Weber',
#  'Holger Schäfer': 'Holger Schäfer',
#  'Thomas Schäfer': 'Holger Schäfer',
#  'chinesische Regierung': 'chinesische Regierung',
#  'deutsche Wirtschaft': 'deutsche Wirtschaft',
#  'Sven Giegold': 'Sven Giegold',
#  'Lars Feld': 'Lars Feld',
#  'Daniel Ziblatt': 'Daniel Ziblatt',
#  'Johannes Vogel': 'Johannes Vogel',
#  'Christian Dürr': 'Christian Dürr',
#  'Marie-Agnes Strack-Zimmermann': 'Marie-Agnes Strack-Zimmermann',
#  'Marie-Agnes Strack Zimmerman': 'Marie-Agnes Strack-Zimmermann',
#  'Wolfgang Kubicki': 'Wolfgang Kubicki',
#  'Thomas Kemmerich': 'Thomas Kemmerich',
#  'Julian Nagelsmann': 'Julian Nagelsmann',
#  'Bo Henriksen': 'Bo Henriksen',
#  'Boris Johnson': 'Boris Johnson',
#  'Dorothee Feller': 'Dorothee Feller',
#  'Verlag': 'Verlag',
#  'Mareike Engel': 'Mareike Engel',
#  'Amtsgericht Pforzheim': 'Amtsgericht Pforzheim',
#  '21-Jähriger': '21-Jähriger',
#  'Robert Lewandowski': 'Robert Lewandowski',
#  'Dieter Nuhr': 'Dieter Nuhr',
#  'Katharina Dröge': 'Katharina Dröge',
#  'CDU/CSU': 'CDU/CSU',
#  'Ingrid Alexandra': 'Ingrid Alexandra',
#  'Mette-Marit': 'Mette-Marit',
#  'Leonor': 'Leonor',
#  'Isabella von Dänemark': 'Isabella von Dänemark',
#  'Charlotte Casiraghi': 'Charlotte Casiraghi',
#  'Kate': 'Kate',
#  'Prinz Harry': 'Prinz Harry',
#  'Kjetil Knutsen': 'Kjetil Knutsen',
#  'Patrick Berg': 'Patrick Berg',
#  'Oliver Mintzlaff': 'Oliver Mintzlaff',
#  'Marco Rose': 'Marco Rose',
#  'Zsolt Löw': 'Zsolt Löw',
#  'Teddy de Beer': 'Teddy de Beer',
#  'Giorgia Meloni': 'Giorgia Meloni',
#  'Georgia Meloni': 'Giorgia Meloni',
#  'Daniel Brinkmann': 'Daniel Brinkmann',
#  'Ahmet Gürleyen': 'Ahmet Gürleyen',
#  'ADAC': 'ADAC',
#  'BILD': 'BILD',
#  'Benjamin Netanyahu': 'Benjamin Netanyahu',
#  'Netanyahu': 'Benjamin Netanyahu',
#  'Benyamin Netanyahu': 'Benjamin Netanyahu',
#  "Gideon Sa'ar": "Gideon Sa'ar",
#  'International Criminal Court': 'International Criminal Court',
#  'International Criminal Court (ICC)': 'International Criminal Court',
#  'Liz Truss': 'Liz Truss',
#  'Yvette Cooper': 'Yvette Cooper',
#  'Israel Defense Forces (IDF)': 'Israel Defense Forces (IDF)',
#  'Israel Defense Forces': 'Israel Defense Forces (IDF)',
#  'Israeli Defence Forces': 'Israel Defense Forces (IDF)',
#  'Israel Defence Forces (IDF)': 'Israel Defense Forces (IDF)',
#  'Gideon Saar': 'Gideon Saar',
#  'Palestine Red Crescent Society (PRCS)': 'Palestine Red Crescent Society (PRCS)',
#  'Palestine Red Crescent Society': 'Palestine Red Crescent Society (PRCS)',
#  'Israeli military': 'Israeli military',
#  'Israeli army': 'Israeli military',
#  'Israeli defense forces': 'Israeli forces',
#  'The Israeli military': 'Israeli military',
#  "UN's human rights office": "UN's human rights office",
#  'UN rights office': "UN's human rights office",
#  'Human Rights Council (UNHRC)': "UN's human rights office",
#  'UN Office for the High Commissioner for Human Rights': "UN's human rights office",
#  'UN Office of the High Commissioner for Human Rights': "UN's human rights office",
#  'United Nations Office of the High Commissioner for Human Rights': "UN's human rights office",
#  'UN Human Rights Office': 'UN Human Rights',
#  'Office of the UN High Commissioner for Human Rights (OHCHR)': 'Office of the High Commissioner for Human Rights (OHCHR)',
#  'Office of the UN High Commissioner for Human Rights': 'Office of the High Commissioner for Human Rights (OHCHR)',
#  'Hostages and Missing Families Forum': 'Hostages and Missing Families Forum',
#  'The Hostages and Missing Families Forum': 'Hostages and Missing Families Forum',
#  'Jonathan Reynolds': 'Jonathan Reynolds',
#  'Jingye': 'Jingye',
#  'Bashar al-Assad': 'Bashar al-Assad',
#  'Assad': 'Bashar al-Assad',
#  'Maher al-Assad': 'Bashar al-Assad',
#  'Bachar al-Assad': 'Baschar al-Assad',
#  'Bashar Assad': 'Bashar al-Assad',
#  'Bashar Al-Assad': 'Bashar al-Assad',
#  'Norwich City Council': 'Norwich City Council',
#  'Carli Harper': 'Carli Harper',
#  'Samantha Power': 'Samantha Power',
#  'Students Against Discrimination': 'Students Against Discrimination',
#  'Citibank': 'Citibank',
#  'Citigroup': 'Citibank',
#  'Israel Katz': 'Israel Katz',
#  'Israel Yoav Katz': 'Israel Katz',
#  'Scott Bessent': 'Scott Bessent',
#  'Karoline Leavitt': 'Karoline Leavitt',
#  'Mike Johnson': 'Mike Johnson',
#  'Min Aung Hlaing': 'Min Aung Hlaing',
#  'Keith Kellogg': 'Keith Kellogg',
#  'Mute Egede': 'Mute Egede',
#  'Kuno Fencker': 'Kuno Fencker',
#  'Apple': 'Apple',
#  'Google': 'Google',
#  'West Midlands Police': 'West Midlands Police',
#  'Crimestoppers': 'Crimestoppers',
#  'Justin Baldoni': 'Justin Baldoni',
#  'Blake Lively': 'Blake Lively',
#  'America Ferrera': 'America Ferrera',
#  'Amber Tamblyn': 'Amber Tamblyn',
#  'Alexis Bledel': 'Alexis Bledel',
#  'Colleen Hoover': 'Colleen Hoover',
#  'Jens-Frederik Nielsen': 'Jens-Frederik Nielsen',
#  'Democrats': 'Democratic Party',
#  'Naleraq': 'Naleraq',
#  'Greenland': 'Greenland',
#  'Liam Payne': 'Liam Payne',
#  'Ezequiel Pereyra': 'Ezequiel Pereyra',
#  'Braian Paiz': 'Braian Paiz',
#  'Nores': 'Nores',
#  'Gilda Martin': 'Gilda Martin',
#  'Grassi': 'Grassi',
#  'Maggie Chapman': 'Maggie Chapman',
#  'Miles Briggs': 'Miles Briggs',
#  'Michael Marra': 'Michael Marra',
#  'Mary Senior': 'Mary Senior',
#  'Beyond Paradise': 'Beyond Paradise',
#  'Ben Palmer': 'Ben Palmer',
#  'Adam Hackett': 'Adam Hackett',
#  'Rachel Lee': 'Rachel Lee',
#  'Maree Todd': 'Maree Todd',
#  'Scottish government': 'Scottish government',
#  'Charles Edward Stuart': 'Charles Edward Stuart',
#  'Highland Council': 'Highland Council',
#  'Mark Card': 'Mark Card',
#  'Culloden Community Council': 'Culloden Community Council',
#  'King Charles': 'King Charles',
#  'King Charles III': 'King Charles',
#  'Craig Browne': 'Craig Browne',
#  'Cheshire East': 'Cheshire East',
#  'Cheshire West and Chester': 'Cheshire East',
#  'Nick Mannion': 'Nick Mannion',
#  'Michael Gorman': 'Michael Gorman',
#  'Conservative group': 'Conservative group',
#  'Fidesz': 'Fidesz',
#  'SSEN': 'SSEN',
#  'Keith Brown': 'Keith Brown',
#  "Siobhan's Trust": "Siobhan's Trust",
#  'Nigel Porter': 'Nigel Porter',
#  'Labour': 'Labour',
#  'Labour party': 'Labour Party',
#  'Conservative': 'Conservative',
#  'Esme Moore': 'Esme Moore',
#  'Abdulkadir Ozkan': 'Abdulkadir Ozkan',
#  'fans': 'fans',
#  'Gaye Su Akyol': 'Gaye Su Akyol',
#  'BluSmart': 'BluSmart',
#  'Anmol Singh Jaggi': 'Anmol Singh Jaggi',
#  'Puneet Singh Jaggi': 'Anmol Singh Jaggi',
#  'GEL': 'GEL',
#  'Sebi': 'Sebi',
#  'UK': 'UK',
#  'United Kingdom': 'UK',
#  'U.K.': 'UK',
#  'Jewish people': 'Jewish people',
#  'Arab population': 'Arab population',
#  'UN': 'UN',
#  'United Nations': 'UN',
#  'United Nations (UN)': 'UN',
#  'U.N.': 'UN',
#  'Arab nations': 'Arab nations',
#  'Palestinians': 'Palestinians',
#  'Palestinian people': 'Palestinians',
#  'Palestiniens': 'Palestinians',
#  'Agustín Escobar': 'Agustín Escobar',
#  'Mercè Camprubí Montal': 'Mercè Camprubí Montal',
#  'El Economista': 'El Economista',
#  'Emiliano García-Page': 'Emiliano García-Page',
#  'Tom Cunningham': 'Tom Cunningham',
#  'Phil Morris': 'Phil Morris',
#  'Bradford Council': 'Bradford Council',
#  'Wilkinson': 'Wilkinson',
#  'John Isaacs': 'John Isaacs',
#  'Newcastle University': 'Newcastle University',
#  'Sarah Hanson-Young': 'Sarah Hanson-Young',
#  'Anthony Albanese': 'Anthony Albanese',
#  'United States of America': 'United States of America',
#  'the United States': 'United States of America',
#  'The United States': 'United States of America',
#  'Thames Water': 'Thames Water',
#  'Macquarie': 'Macquarie',
#  'Sir Adrian Montague': 'Sir Adrian Montague',
#  'ACLU': 'ACLU',
#  'American Civil Liberties Union (ACLU)': 'American Civil Liberties Union',
#  'Trump administration': 'Trump administration',
#  'administration Trump': 'Trump administration',
#  'Trump Administration': 'Administration Trump',
#  'Senator Chris Van Hollen': 'Senator Chris Van Hollen',
#  'Chris Van Hollen': 'Senator Chris Van Hollen',
#  'Pete Navarro': 'Pete Navarro',
#  'Peter Navarro': 'Pete Navarro',
#  'William Alan Reinsch': 'William Alan Reinsch',
#  'Johnny Finch': 'Johnny Finch',
#  'Leanne Baister': 'Leanne Baister',
#  'Fiona Conor': 'Fiona Conor',
#  'Trust Electric Heating': 'Trust Electric Heating',
#  'Trevor Muten': 'Trevor Muten',
#  'Brighton & Hove City Council': 'Brighton & Hove City Council',
#  'Heidi Alexander': 'Heidi Alexander',
#  'CPRE': 'CPRE',
#  'LADACAN': 'LADACAN',
#  'Chad': 'Chad',
#  'Lt-Gen Yasir al-Atta': 'Lt-Gen Yasir al-Atta',
#  'Sudan': 'Sudan',
#  'Narendra Modi': 'Narendra Modi',
#  'India': 'India',
#  'Steven Paisley': 'Steven Paisley',
#  'Care Quality Commission': 'Care Quality Commission',
#  'Southern Housing': 'Southern Housing',
#  'Kim Leadbeater': 'Kim Leadbeater',
#  'Eluned Morgan': 'Eluned Morgan',
#  'Jeremy Miles': 'Jeremy Miles',
#  'Sarah Olney': 'Sarah Olney',
#  'Stephen Kinnock': 'Stephen Kinnock',
#  'Sarah Sackman': 'Sarah Sackman',
#  'Irish Writers Union (IWU)': 'Irish Writers Union (IWU)',
#  'Audrey Magee': 'Audrey Magee',
#  'Zulaikha Zeb': 'Zulaikha Zeb',
#  'Zainab Nabeel': 'Zainab Nabeel',
#  'Green Party': 'Green Party',
#  'European Green Party': 'Green Party',
#  'Ecologist Green Party': 'Green Party',
#  'Green Party of England and Wales': 'Green Party',
#  'Reform': 'Reform',
#  'reform': 'Reform',
#  'Adrian Ramsay': 'Adrian Ramsay',
#  'White Helmets': 'White Helmets',
#  'Ahmed al-Sharaa': 'Ahmed al-Sharaa',
#  'Ahmed al-Scharaa': 'Ahmed al-Sharaa',
#  'Ahmed al-Fara': 'Ahmed al-Sharaa',
#  'Ahmad al-Sharaa': 'Ahmed al-Sharaa',
#  'David Lammy': 'David Lammy',
#  'Radek Sikorski': 'Radek Sikorski',
#  'Senate': 'Senate',
#  'U.S. Senate': 'Senate',
#  'Doug Burgum': 'Doug Burgum',
#  'Doug Collins': 'Doug Collins',
#  'Linda McMahon': 'Linda McMahon',
#  'Police Scotland': 'Police Scotland',
#  'Torbian Dennis': 'Torbian Dennis',
#  'Daniel Heath': 'Daniel Heath',
#  'William Lawrence': 'William Lawrence',
#  'Anthony George': 'Anthony George',
#  'Newbury': 'Newbury',
#  'Crown Prosecution Service (CPS)': 'Crown Prosecution Service (CPS)',
#  'Layden': 'Layden',
#  'Lord Hamblen': 'Lord Hamblen',
#  'Kristi Noem': 'Kristi Noem',
#  'Tricia Bey': 'Tricia Bey',
#  "Shane O'Neill": "Shane O'Neill",
#  'Iain Gillespie': 'Iain Gillespie',
#  'Sergee Kelly': 'Sergee Kelly',
#  'Stephen MacAuley': 'Stephen MacAuley',
#  'Dean Wilson': 'Dean Wilson',
#  'Emma Wilson': 'Emma Wilson',
#  'Swissport': 'Swissport',
#  'BA': 'BA',
#  'Gavin Newsom': 'Gavin Newsom',
#  'Karen Bass': 'Karen Bass',
#  'Southern California Edison Company (SCE)': 'Southern California Edison Company (SCE)',
#  'Piers Corbyn': 'Piers Corbyn',
#  'Royal Oldham Hospital': 'Royal Oldham Hospital',
#  'Royal Stoke University Hospital': 'Royal Oldham Hospital',
#  'Great Ormond Street Hospital': 'Royal Oldham Hospital',
#  'Wrightington, Wigan, and Leigh NHS Foundation Trust': 'Wrightington, Wigan, and Leigh NHS Foundation Trust',
#  'Stewart Hutton': 'Stewart Hutton',
#  'Andrew Tate': 'Andrew Tate',
#  'Newsmax': 'Newsmax',
#  'Lesley Manville': 'Lesley Manville',
#  'James Brining': 'James Brining',
#  'Carl Woodward': 'Carl Woodward',
#  'Rachael Thomas': 'Rachael Thomas',
#  'Gareth Machin': 'Gareth Machin',
#  'Stephanie Sirr': 'Stephanie Sirr',
#  'Chris Stafford': 'Chris Stafford',
#  'Paul Carey Jones': 'Paul Carey Jones',
#  'Margaret Aspinall': 'Margaret Aspinall',
#  'military': 'military',
#  'US military': 'military',
#  'Volker Türk': 'Volker Türk',
#  'Volker Turk': 'Volker Türk',
#  'WWF': 'WWF',
#  'Zlatan Milišić': 'Zlatan Milišić',
#  'World Food Programme': 'World Food Programme',
#  'World Food Programme (WFP)': 'World Food Programme',
#  'UN World Food Programme': 'World Food Programme',
#  'Irish government': 'Irish government',
#  'Stormont': 'Stormont',
#  'Dara Calleary': 'Dara Calleary',
#  'Sinn Féin': 'Sinn Féin',
#  'John Gilhooly': 'John Gilhooly',
#  'Wigmore Hall': 'Wigmore Hall',
#  'Sam Jones': 'Sam Jones',
#  'Sally Gunnell': 'Sally Gunnell',
#  'John Marshall': 'John Marshall',
#  'PK Mishra': 'PK Mishra',
#  'Nayanjot Lahiri': 'Nayanjot Lahiri',
#  'Rakhaldas Banerjee': 'Rakhaldas Banerjee',
#  'Nicola Sturgeon': 'Nicola Sturgeon',
#  'Val McDermid': 'Val McDermid',
#  'Nina Barough': 'Nina Barough',
#  'Samina Hussain': 'Samina Hussain',
#  'Samira Hussain': 'Samina Hussain',
#  'Julian Smith': 'Julian Smith',
#  'Justin Smith': 'Julian Smith',
#  'GMB': 'GMB',
#  'Sam Nujoma': 'Sam Nujoma',
#  'Nangolo Mbumba': 'Nangolo Mbumba',
#  'Netumbo Nandi-Ndaitwah': 'Netumbo Nandi-Ndaitwah',
#  'Moussa Faki Mahamat': 'Moussa Faki Mahamat',
#  'Cyril Ramaphosa': 'Cyril Ramaphosa',
#  'William Ruto': 'William Ruto',
#  'Cassandra Ventura': 'Cassandra Ventura',
#  'Casandra Ventura': 'Cassandra Ventura',
#  'Rodney Jones Jr': 'Rodney Jones Jr',
#  'Rodney Jones': 'Rodney Jones Jr',
#  'Tony Buzbee': 'Tony Buzbee',
#  'Jay-Z': 'Jay-Z',
#  'Shawn Holley': 'Shawn Holley',
#  'Marc Agnifilo': 'Marc Agnifilo',
#  'Jonathan Davis': 'Jonathan Davis',
#  'Arlo Lambie': 'Arlo Lambie',
#  'Gloucestershire County Council': 'Gloucestershire County Council',
#  'Bibury Parish Council': 'Bibury Parish Council',
#  'Brice Oligui Nguema': 'Brice Oligui Nguema',
#  'Gen Brice Oligui Nguema': 'Brice Oligui Nguema',
#  'Landry Obame-Mezui': 'Landry Obame-Mezui',
#  'Alain Claude Bilie-by-Nze': 'Alain Claude Bilie-by-Nze',
#  'Alain Claude Bilie-By-Nze': 'Alain Claude Bilie-by-Nze',
#  'Alain-Claude Bilie By Nze': 'Alain Claude Bilie-by-Nze',
#  'Victoria Chapman': 'Victoria Chapman',
#  'Natural Resources Wales': 'Natural Resources Wales',
#  'Italy': 'Italy',
#  'Dina Boluarte': 'Dina Boluarte',
#  'Wood Group': 'Wood Group',
#  'Jim Fairlie': 'Jim Fairlie',
#  'NatureScot': 'NatureScot',
#  'Stephanie Grisham': 'Stephanie Grisham',
#  'Elise Stefanik': 'Elise Stefanik',
#  'Pierre Poilievre': 'Pierre Poilievre',
#  'Jagmeet Singh': 'Jagmeet Singh',
#  'Yves-François Blanchet': 'Yves-François Blanchet',
#  'ruling military junta': 'ruling military junta',
#  'Pete Hoekstra': 'Pete Hoekstra',
#  'Israeli forces': 'Israeli forces',
#  'civil defence': 'civil defence',
#  'Antonio Guterres': 'Antonio Guterres',
#  'António Guterres': 'Antonio Guterres',
#  'Sa’ar': 'Sa’ar',
#  'WHO': 'WHO',
#  'Tedros Adhanom Ghebreyesus': 'Tedros Adhanom Ghebreyesus',
#  'Michael Martin': 'Michael Martin',
#  'Nuri Aslan': 'Nuri Aslan',
#  'Ozgur Ozel': 'Ozgur Ozel',
#  'Justin Trudeau': 'Justin Trudeau',
#  'Pierre Trudeau': 'Justin Trudeau',
#  'Chrystia Freeland': 'Chrystia Freeland',
#  'Melanie Joly': 'Melanie Joly',
#  'Lai Ching-te': 'Lai Ching-te',
#  'Lai-Ching-te': 'Lai Ching-te',
#  'Prince Khalid bin Salman': 'Prince Khalid bin Salman',
#  'Prince Khalid bin Bandar Al Saud': 'Prince Khalid bin Salman',
#  'Saudi Arabia': 'Saudi Arabia',
#  'Houthis': 'Houthis',
#  'Abu Obeida': 'Abu Obeida',
#  'Abou Obeida': 'Abu Obeida',
#  'Pope Francis': 'Pope Francis',
#  'Mitri Raheb': 'Mitri Raheb',
#  'Pope Tawadros II': 'Pope Tawadros II',
#  'Finland': 'Finland',
#  'Finnland': 'Finland',
#  'Estonia': 'Estonia',
#  'Latvia': 'Latvia',
#  'Lithuania': 'Lithuania',
#  'Poland': 'Poland',
#  'Petteri Orpo': 'Petteri Orpo',
#  'Alexander Stubb': 'Alexander Stubb',
#  'Philippe Vedovini': 'Philippe Vedovini',
#  "Moody's": "Moody's",
#  'Moody’s': "Moody's",
#  'Gabriel Attal': 'Gabriel Attal',
#  'Cyril Hanouna': 'Cyril Hanouna',
#  'LFI': 'LFI',
#  'M6': 'M6',
#  'Brice Cardi': 'Brice Cardi',
#  'Francis Szpiner': 'Francis Szpiner',
#  'Rassemblement national': 'Rassemblement national',
#  'Assemblée nationale': 'Rassemblement national',
#  'Rassemblement National': 'Rassemblement national',
#  'Rassemblement national (RN)': 'Rassemblement national',
#  'Manuel Bompard': 'Manuel Bompard',
#  'Denis Scherrer': 'Denis Scherrer',
#  'Guillaume Sommerer': 'Guillaume Sommerer',
#  'Bruno Bonnell': 'Bruno Bonnell',
#  'Jonathann Daval': 'Jonathann Daval',
#  'Alexia Fouillot': 'Alexia Fouillot',
#  'Martine Henry': 'Martine Henry',
#  'Les Républicains': 'Les Républicains',
#  'Gérald Darmanin': 'Gérald Darmanin',
#  'Xi Jinping': 'Xi Jinping',
#  'Éric Lombard': 'Éric Lombard',
#  'Olympique Lyonnais': 'Olympique Lyonnais',
#  'Olympique Lyon': 'Olympique Lyonnais',
#  'Donatella Versace': 'Donatella Versace',
#  'Sylvain Maillard': 'Sylvain Maillard',
#  'Anne Hidalgo': 'Anne Hidalgo',
#  'Emmanuel Grégoire': 'Emmanuel Grégoire',
#  'Renaud Muselier': 'Renaud Muselier',
#  'Olivier Marleix': 'Olivier Marleix',
#  'Franck Allissio': 'Franck Allissio',
#  'Bastien Lachaud': 'Bastien Lachaud',
#  'Patrick Mignola': 'Patrick Mignola',
#  'Benoît Payan': 'Benoît Payan',
#  'Chine': 'Chine',
#  'Lin Jian': 'Lin Jian',
#  'Li Tian': 'Lin Jian',
#  'Eline Gastaud': 'Eline Gastaud',
#  'direction interrégionale des services pénitentiaires de Marseille': 'direction interrégionale des services pénitentiaires de Marseille',
#  'Bruno Retailleau': 'Bruno Retailleau',
#  'Mehdi Nemmouche': 'Mehdi Nemmouche',
#  "cour d'assises spéciales de Paris": "cour d'assises spéciales de Paris",
#  'Beaujolais': 'Beaujolais',
#  'Olivier Besancenot': 'Olivier Besancenot',
#  'Renaissance': 'Renaissance',
#  'Telegram': 'Telegram',
#  'Laure Beccuau': 'Laure Beccuau',
#  'Israël Katz': 'Israël Katz',
#  'Israël': 'Israël',
#  'Sébastien Cauwel': 'Sébastien Cauwel',
#  'Matignon': 'Matignon',
#  'gouvernement': 'gouvernement',
#  'Le gouvernement': 'gouvernement',
#  'RN': 'RN',
#  'UDR': 'UDR',
#  'Droite Républicaine': 'Droite Républicaine',
#  'Droite républicaine': 'Droite Républicaine',
#  'France insoumise': 'France insoumise',
#  'La France insoumise': 'France insoumise',
#  'la France insoumise': 'France insoumise',
#  'Thomas Ménagé': 'Thomas Ménagé',
#  '84% des Français': '84% des Français',
#  '60% des Français': '84% des Français',
#  '75% des personnes interrogées': '75% des personnes interrogées',
#  'Airbus': 'Airbus',
#  'Pologne': 'Pologne',
#  'Cologne': 'Pologne',
#  'États-Unis': 'États-Unis',
#  'Guillaume Faury': 'Guillaume Faury',
#  'Donald Tusk': 'Donald Tusk',
#  'Allemagne': 'Allemagne',
#  'Espagne': 'Espagne',
#  'Sofia Benlemmane': 'Sofia Benlemmane',
#  'procureur': 'procureur',
#  'Zazou Youssef': 'Zazou Youssef',
#  'Doualemn': 'Doualemn',
#  'Imad Tintin': 'Imad Tintin',
#  'Raphaël Legendre': 'Raphaël Legendre',
#  'Rose-Marie Bertaud': 'Rose-Marie Bertaud',
#  'Bernard Guetta': 'Bernard Guetta',
#  'Vladimir Poutine': 'Vladimir Poutine',
#  'Kiev': 'Kiev',
#  'Kyiv': 'Kiev',
#  'Jean-François Huchet': 'Jean-François Huchet',
#  'Lior Raz': 'Lior Raz',
#  'Alain Duhamel': 'Alain Duhamel',
#  'high ambition coalition': 'high ambition coalition',
#  'Rachida Dati': 'Rachida Dati',
#  'Alassane Ouattara': 'Alassane Ouattara',
#  'SNCF': 'SNCF',
#  'Transilien SNCF': 'SNCF',
#  'Police': 'Police',
#  'police': 'Police',
#  'Jean-Marie Le Pen': 'Jean-Marie Le Pen',
#  'Marine Le Pen': 'Jean-Marie Le Pen',
#  'Le Pen': 'Jean-Marie Le Pen',
#  'Marie Le Pen': 'Jean-Marie Le Pen',
#  'Meloni': 'Meloni',
#  'Orano': 'Orano',
#  'Greve feministe': 'Greve feministe',
#  'Milorad Dodik': 'Milorad Dodik',
#  'DRC': 'DRC',
#  'Antony Blinken': 'Antony Blinken',
#  'Anthony Blinken': 'Antony Blinken',
#  'Constitutional Council': 'Constitutional Council',
#  '9 October election': '9 October election',
#  '4 July elections': '9 October election',
#  '5 November election': '5 November vote',
#  'Emmanuel': 'Emmanuel',
#  'Council of State': 'Council of State',
#  ...}

# %%
import pandas as pd
from collections import defaultdict

# Step 1: Invert the resolution map to get clusters
inverse_clusters = defaultdict(list)
for alias, canonical in resolution_map.items():
    inverse_clusters[canonical].append(alias)

# Step 2: Convert to DataFrame
cluster_df = pd.DataFrame([
    {"canonical": canon, "aliases": aliases, "number_of_names_in_cluster": len(aliases)}
    for canon, aliases in inverse_clusters.items()
])

# Step 3: Filter for clusters with >1 name
cluster_df_filtered = cluster_df[cluster_df["number_of_names_in_cluster"] > 1]
cluster_df_filtered = cluster_df_filtered.sort_values("number_of_names_in_cluster", ascending=False)

# Step 4: Summary table of cluster sizes
summary = cluster_df_filtered["number_of_names_in_cluster"].value_counts().sort_index().reset_index()
summary.columns = ["number_of_names_in_cluster", "number_of_clusters"]

# %%
summary
# Out:
#    number_of_names_in_cluster  number_of_clusters
# 0                           2                1373
# 1                           3                 225
# 2                           4                  82
# 3                           5                  36
# 4                           6                  17
# 5                           7                   6
# 6                           8                   6
# 7                           9                   1
# 8                          10                   1
# 9                          13                   1

# %%
cluster_df_filtered.head(10)
# Out:
#                            canonical  \
# 8601                  war in Ukraine
# 7914          2024 presidential race
# 4081                   northern Gaza
# 7913                   2024 election
# 2589                State Department
# 9258            COP29 climate summit
# 6244         war on Gaza and Lebanon
# 7508                BBC Radio Sussex
# 4874  Palestinian Ministry of Health
# 820             south-eastern Europe
#
#                                                 aliases  \
# 8601  [war in Ukraine, Ukraine war, Russia's war in ...
# 7914  [2024 US presidential election, 2024 president...
# 4081  [North Gaza, northern Gaza, north Gaza, centra...
# 7913  [2024 presidential election, 2024 election, 20...
# 2589  [State Department, US State Department, United...
# 9258  [COP29 climate summit, COP26 climate summit, C...
# 6244  [war in Gaza, war on the Gaza strip, war on Ga...
# 7508  [BBC Radio Manchester, BBC Radio 2, BBC Radio ...
# 4874  [Palestinian Ministry of Health, Ministry of H...
# 820   [north Europe, eastern Europe, Southeastern Eu...
#
#       number_of_names_in_cluster
# 8601                          13
# 7914                          10
# 4081                           9
# 7913                           8
# 2589                           8
# 9258                           8
# 6244                           8
# 7508                           8
# 4874                           8
# 820                            7

# %%
cluster_df_filtered[cluster_df_filtered['canonical'] == "Palestinian Ministry of Health"].aliases.to_list()
# Out:
# [['Palestinian Ministry of Health',
#   'Ministry of Health in Gaza',
#   'Gaza Health Ministry',
#   'Gaza’s Ministry of Health',
#   'Gaza Ministry of Health',
#   "Gaza's health ministry",
#   'Palestinian health ministry',
#   'Gaza’s Health Ministry']]

# %%
# Helper function to resolve either a string or a list of strings
def resolve_value(val):
    if isinstance(val, list):
        return [resolution_map.get(v, v) for v in val]
    else:
        return resolution_map.get(val, val)

# Apply to both source and target columns
edges_df["source"] = edges_df["source"].map(resolve_value)
edges_df["target"] = edges_df["target"].map(resolve_value)

# %%
edges_df[edges_df["target"].apply(lambda x: isinstance(x, list))]
# Out:
# Empty DataFrame
# Columns: [source, target, relationship, sentiment, url]
# Index: []

# %%
# Normalize: if it's a list, keep the first item; otherwise leave as is
edges_df["target"] = edges_df["target"].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x
)

# %%
def resolve_entry(value):
    if isinstance(value, list):
        return [resolution_map.get(v, v) for v in value]
    else:
        return resolution_map.get(value, value)

# 6. Apply to edges_df
edges_df["source"] = edges_df["source"].apply(resolve_entry)
edges_df["target"] = edges_df["target"].apply(resolve_entry)

# 7. Apply to ents_long
ents_long["entity"] = ents_long["entity"].apply(resolve_entry)

# 8. Optional: Remove duplicates
edges_df.drop_duplicates(inplace=True)
ents_long.drop_duplicates(subset=["url", "entity"], inplace=True)

# 9. Print resolution summary
print(f"🔁 Resolved {len(unique_entities)} entities into {len(clusters)} canonical names.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 15
#      12 ents_long["entity"] = ents_long["entity"].apply(resolve_entry)
#      14 # 8. Optional: Remove duplicates
# ---> 15 edges_df.drop_duplicates(inplace=True)
#      16 ents_long.drop_duplicates(subset=["url", "entity"], inplace=True)
#      18 # 9. Print resolution summary
#
# File ~/miniconda3/envs/blink38/lib/python3.8/site-packages/pandas/core/frame.py:6522, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6519 inplace = validate_bool_kwarg(inplace, "inplace")
#    6520 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6522 result = self[-self.duplicated(subset, keep=keep)]
#    6523 if ignore_index:
#    6524     result.index = default_index(len(result))
#
# File ~/miniconda3/envs/blink38/lib/python3.8/site-packages/pandas/core/frame.py:6662, in DataFrame.duplicated(self, subset, keep)
#    6660 else:
#    6661     vals = (col.values for name, col in self.items() if name in subset)
# -> 6662     labels, shape = map(list, zip(*map(f, vals)))
#    6664     ids = get_group_index(
#    6665         labels,
#    6666         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6670         xnull=False,
#    6671     )
#    6672     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/miniconda3/envs/blink38/lib/python3.8/site-packages/pandas/core/frame.py:6630, in DataFrame.duplicated.<locals>.f(vals)
#    6629 def f(vals) -> tuple[np.ndarray, int]:
# -> 6630     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6631     return labels.astype("i8", copy=False), len(shape)
#
# File ~/miniconda3/envs/blink38/lib/python3.8/site-packages/pandas/core/algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File ~/miniconda3/envs/blink38/lib/python3.8/site-packages/pandas/core/algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# 6. Apply to edges_df
edges_df["source"] = edges_df["source"].map(lambda x: resolution_map.get(x, x))
edges_df["target"] = edges_df["target"].map(lambda x: resolution_map.get(x, x))

# 7. Apply to ents_long
ents_long["entity"] = ents_long["entity"].map(lambda x: resolution_map.get(x, x))

# 8. Optional: Remove duplicates
edges_df.drop_duplicates(inplace=True)
ents_long.drop_duplicates(subset=["url", "entity"], inplace=True)

# 9. Print resolution summary
print(f"🔁 Resolved {len(unique_entities)} entities into {len(clusters)} canonical names.")
# Out:
# 🔁 Resolved 27852 entities into 25412 canonical names.

# %% [markdown]
# dropped duplicates, na and self loops

# %%
edges_df = edges_df[edges_df["source"] != edges_df["target"]]
edges_df.dropna(subset=["source", "target"], inplace=True)
# Out:
# /var/folders/nx/lwphb_yx3312gqm2v4zgwnr00000gn/T/ipykernel_22463/2339418153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edges_df.dropna(subset=["source", "target"], inplace=True)

# %%
edges_df.to_csv("edges.csv", index=False)
ents_long.to_csv("ents_long.csv", index=False)

# %%
ents_long.shape
# Out:
# (67435, 3)

# %% [markdown]
# # fuzzy search
# tried that but decided this semantic sentence transformers were better - with manual override for edge cases
# alternative - facebook's blink model

# %% [markdown]
# # redo graph

# %%
import pandas as pd
import networkx as nx
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
from community import community_louvain
from scipy.spatial import ConvexHull

# Ensure date column is datetime
edges_df['date'] = pd.to_datetime(edges_df['date'])

# Build graph
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _, r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# Centrality & communities
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
betw_cent = nx.betweenness_centrality(G, normalized=True)
partition = community_louvain.best_partition(G)
pos = nx.spring_layout(G, k=0.15, iterations=20)

# Convex hulls for clusters
hull_shapes = []
for comm in set(partition.values()):
    members = [n for n, p in partition.items() if p == comm]
    if len(members) < 3:
        continue
    pts = np.array([pos[n] for n in members])
    hull = ConvexHull(pts)
    path = "M " + " L ".join(f"{pts[v,0]},{pts[v,1]}" for v in hull.vertices) + " Z"
    hull_shapes.append(dict(type="path", path=path, fillcolor="rgba(200,200,200,0.15)", line=dict(width=0)))

# Selective node labels
deg_vals = np.array(list(deg_cent.values()))
thresh = np.percentile(deg_vals, 90)
label_nodes = {n for n, v in deg_cent.items() if v >= thresh}

# Build edge traces by relationship
relationship_types = sorted(edges_df['relationship'].dropna().unique())
edge_traces = []
rel_colors = {r: c for r, c in zip(relationship_types, px.colors.qualitative.Bold)}

for rel in relationship_types:
    xs, ys = [], []
    for _, row in edges_df[edges_df['relationship'] == rel].iterrows():
        if row.source in pos and row.target in pos:
            x0, y0 = pos[row.source]
            x1, y1 = pos[row.target]
            xs += [x0, x1, None]
            ys += [y0, y1, None]
    edge_traces.append(go.Scatter(
        x=xs, y=ys, mode="lines",
        line=dict(color=rel_colors.get(rel, "gray"), width=1),
        name=rel,
        hoverinfo="none",
        visible=True
    ))

# Node traces by type
type_colors = {"people": "blue", "institutions": "orange", "locations": "green", "political_events": "purple", "political_parties": "red", "unknown": "gray"}
entity_types = sorted(ents_long['entity_type'].unique())
node_traces = []

for t in entity_types:
    xs, ys, txt, col, cdata = [], [], [], [], []
    for node in G.nodes():
        et = ents_long[ents_long.entity == node]["entity_type"]
        et = et.iloc[0] if not et.empty else "unknown"
        if et != t:
            continue
        x, y = pos[node]
        xs.append(x); ys.append(y)
        txt.append(node if node in label_nodes else "")
        col.append(type_colors.get(et, "gray"))
        cdata.append([et, deg_cent[node], pr[node]])
    node_traces.append(go.Scatter(
        x=xs, y=ys, mode="markers+text",
        text=txt, textposition="top center",
        marker=dict(size=10, color=col),
        customdata=cdata,
        hovertemplate="<b>%{text}</b><br>Type: %{customdata[0]}<br>Degree: %{customdata[1]:.3f}<br>PageRank: %{customdata[2]:.4f}<extra></extra>",
        visible=True,
        name=t
    ))

# Build slider frames by date
dates = sorted(edges_df['date'].dt.date.unique())
frames = []

for d in dates:
    day_edges = edges_df[edges_df['date'].dt.date == d]
    day_trace = []
    for rel in relationship_types:
        xs, ys = [], []
        for _, row in day_edges[day_edges['relationship'] == rel].iterrows():
            if row.source in pos and row.target in pos:
                x0, y0 = pos[row.source]
                x1, y1 = pos[row.target]
                xs += [x0, x1, None]
                ys += [y0, y1, None]
        day_trace.append(go.Scatter(x=xs, y=ys, mode="lines", line=dict(color=rel_colors.get(rel, "gray"), width=1), name=rel, hoverinfo="none"))
    frames.append(go.Frame(data=day_trace + node_traces, name=str(d)))

# Create figure
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="📅 Knowledge Graph Explorer",
        shapes=hull_shapes,
        hovermode="closest",
        margin=dict(l=20, r=20, t=40, b=20),
        updatemenus=[
            dict(type="buttons", showactive=False, x=0, y=1.15,
                 buttons=[
                     dict(label="▶️ Play", method="animate", args=[None]),
                     dict(label="⏸ Pause", method="animate", args=[[None], {"frame": {"duration": 0}, "mode": "immediate"}])
                 ])
        ],
        sliders=[dict(
            active=0,
            steps=[dict(method="animate", label=str(d), args=[[str(d)], {"frame": {"duration": 0, "redraw": True}, "mode": "immediate"}]) for d in dates],
            x=0.1, y=0, len=0.9
        )]
    ),
    frames=frames
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import numpy as np

# Build weighted graph (assumes edges_df exists with 'source', 'target', 'sentiment', 'relationship')
G = nx.Graph()
for _, row in edges_df.iterrows():
    G.add_edge(row['source'], row['target'], sentiment=row['sentiment'], relationship=row['relationship'], date=row['date'])

# Compute centrality scores
pos = nx.spring_layout(G, k=0.15, iterations=20)
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)

# Normalize node sizes
node_sizes = {n: 10 + 30 * deg_cent[n] for n in G.nodes()}

# Build edge traces
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
edge_traces = []
color_map = {"positive": "green", "negative": "red", "neutral": "gray"}

for s in ["All"] + sentiments:
    xs, ys = [], []
    for u, v, d in G.edges(data=True):
        sent = d.get('sentiment', 'neutral')
        if s != "All" and sent != s:
            continue
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        xs += [x0, x1, None]
        ys += [y0, y1, None]
    edge_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="lines",
            line=dict(color=color_map.get(s, "#888"), width=1),
            hoverinfo="none",
            visible=(s == "All"),
            name=(s if s != "All" else "All Sentiments")
        )
    )

# Create ents_long mapping if not already filtered
entity_types = ents_long.drop_duplicates("entity")[["entity", "entity_type"]].set_index("entity").to_dict()['entity_type']
type_colors = {"people": "blue", "organizations": "orange", "locations": "green", "unknown": "gray"}

# Build node traces
types = sorted(set(entity_types.values()))
node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, size, cdata = [], [], [], [], [], []
    for n in G.nodes():
        et0 = entity_types.get(n, "unknown")
        if t != "All" and et0 != t:
            continue
        x, y = pos[n]
        xs.append(x)
        ys.append(y)
        txt.append(n)
        col.append(type_colors.get(et0, "gray"))
        size.append(node_sizes[n])
        cdata.append([et0, deg_cent[n], pr[n]])
    node_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="markers+text",
            text=txt, textposition="top center",
            marker=dict(size=size, color=col),
            customdata=cdata,
            hovertemplate=(
                "<b>%{text}</b><br>Type: %{customdata[0]}<br>Degree: %{customdata[1]:.3f}<br>PageRank: %{customdata[2]:.4f}<extra></extra>"
            ),
            visible=(t == "All"),
            name=(t if t != "All" else "All Types")
        )
    )

# Assemble figure
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="Knowledge Graph Explorer",
        hovermode="closest",
        legend=dict(itemsizing="constant"),
        margin=dict(l=20, r=20, b=20, t=40)
    )
)

# Add dropdown filters
fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(label="All Sentiments", method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Sentiments"}])
            ] + [
                dict(label=s.title(), method="update",
                     args=[{"visible": [i == (idx+1) for i in range(len(edge_traces))] + [True]*len(node_traces)},
                           {"title": f"Sentiment: {s.title()}"}])
                for idx, s in enumerate(sentiments)
            ],
            direction="down", x=0, y=1.15, showactive=True
        ),
        dict(
            buttons=[
                dict(label="All Types", method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Entity Types"}])
            ] + [
                dict(label=t.title(), method="update",
                     args=[{"visible": [True]*len(edge_traces) + [i == (idx+1) for i in range(len(node_traces))]},
                           {"title": f"Entity Type: {t.title()}"}])
                for idx, t in enumerate(types)
            ],
            direction="down", x=0.25, y=1.15, showactive=True
        )
    ]
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler

# --- PREP WORK ---
# Create graph and compute centrality
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _,r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# Metrics and community
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
pos = nx.spring_layout(G, k=0.15)

# --- NORMALIZE DEGREE CENTRALITY FOR SCALING NODE SIZES ---
scaler = MinMaxScaler(feature_range=(10, 30))
deg_values = scaler.fit_transform(pd.DataFrame(deg_cent.values()))
node_sizes = {n: deg_values[i][0] for i, n in enumerate(deg_cent)}

# --- BUILD FILTERABLE GRAPH ---
sentiments = sorted(edges_df['sentiment'].dropna().unique())
relationships = sorted(edges_df['relationship'].dropna().unique())
types = ents_long['entity_type'].dropna().unique().tolist()

# Edge traces with sentiment and relationship metadata
edge_traces = []
for s in sentiments:
    for rel in relationships:
        xs, ys, texts = [], [], []
        for _, row in edges_df[(edges_df.sentiment==s)&(edges_df.relationship==rel)].iterrows():
            u, v = row['source'], row['target']
            if u not in pos or v not in pos: continue
            x0,y0 = pos[u]; x1,y1 = pos[v]
            xs += [x0,x1,None]; ys += [y0,y1,None]
            texts.append(f"{u} {rel} {v}<br>Sentiment: {s}")
        edge_traces.append(go.Scatter(
            x=xs, y=ys, mode='lines', line=dict(width=1, color='gray'),
            hoverinfo='text', text=texts,
            name=f"{s} / {rel}", visible=(s=='NEUTRAL' and rel==relationships[0])
        ))

# Node traces
color_map = {'people':'gold', 'institutions':'orange', 'locations':'orchid',
             'political_events':'gray', 'political_parties':'lightgray'}
node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, size, custom = [], [], [], [], [], []
    for n in G.nodes():
        match = ents_long.loc[ents_long.entity==n, 'entity_type']
        et = match.iloc[0] if not match.empty else 'unknown'
        if t!='All' and et!=t: continue
        x,y = pos[n]
        xs.append(x); ys.append(y); txt.append(n)
        col.append(color_map.get(et, 'lightgray'))
        size.append(node_sizes.get(n, 10))
        custom.append(f"{n} ({et})")
    node_traces.append(go.Scatter(
        x=xs, y=ys, mode='markers+text', textposition='top center',
        text=txt, marker=dict(size=size, color=col, line=dict(width=0.5, color='black')),
        hovertext=custom, hoverinfo='text', visible=(t=='All'), name=t
    ))

# --- BUILD FIGURE ---
fig = go.Figure(data=edge_traces + node_traces)

# Sentiment / relationship dropdown
fig.update_layout(updatemenus=[
    dict(buttons=[
        dict(label='All', method='update', args=[
            {'visible': [True]*len(edge_traces) + [True]*len(node_traces)},
            {'title': 'All relationships'}]),
        *[dict(label=f"{s} / {r}", method='update', args=[
            {'visible': [i==idx for i in range(len(edge_traces))] + [True]*len(node_traces)},
            {'title': f"{s} / {r}"}])
          for idx, (s, r) in enumerate([(s,r) for s in sentiments for r in relationships])]
    ], x=0, y=1.15),
    dict(buttons=[
        dict(label='All Types', method='update', args=[
            {'visible': [True]*len(edge_traces) + [i==0 for i in range(len(node_traces))]},
            {'title': 'All Entity Types'}]),
        *[dict(label=t, method='update', args=[
            {'visible': [True]*len(edge_traces) + [i==(idx+1) for i in range(len(node_traces))]},
            {'title': f"Type: {t}"}]) for idx, t in enumerate(types)]
    ], x=0.3, y=1.15)
])

fig.update_layout(
    title="📊 Filterable Political Knowledge Graph",
    margin=dict(l=20,r=20,b=20,t=50),
    hovermode='closest',
    showlegend=True
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler

# --- PREP WORK ---
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _,r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
pos = nx.spring_layout(G, k=0.15)

scaler = MinMaxScaler(feature_range=(10, 30))
deg_values = scaler.fit_transform(pd.DataFrame(deg_cent.values()))
node_sizes = {n: deg_values[i][0] for i, n in enumerate(deg_cent)}

sentiments = sorted(edges_df['sentiment'].dropna().unique())
relationships = sorted(edges_df['relationship'].dropna().unique())
types = ents_long['entity_type'].dropna().unique().tolist()

edge_traces = []
for s in sentiments:
    for rel in relationships:
        xs, ys, texts = [], [], []
        for _, row in edges_df[(edges_df.sentiment==s)&(edges_df.relationship==rel)].iterrows():
            u, v = row['source'], row['target']
            if u not in pos or v not in pos: continue
            x0,y0 = pos[u]; x1,y1 = pos[v]
            xs += [x0,x1,None]; ys += [y0,y1,None]
            texts.append(f"{u} {rel} {v}<br>Sentiment: {s}")
        edge_traces.append(go.Scatter(
            x=xs, y=ys, mode='lines', line=dict(width=1, color='gray'),
            hoverinfo='text', text=texts,
            name=f"{s} / {rel}", visible=(s=='NEUTRAL' and rel==relationships[0])
        ))

color_map = {'people':'gold', 'institutions':'orange', 'locations':'orchid',
             'political_events':'gray', 'political_parties':'lightgray'}
node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, size, custom = [], [], [], [], [], []
    for n in G.nodes():
        match = ents_long.loc[ents_long.entity==n, 'entity_type']
        et = match.iloc[0] if not match.empty else 'unknown'
        if t!='All' and et!=t: continue
        x,y = pos[n]
        xs.append(x); ys.append(y); txt.append(n)
        col.append(color_map.get(et, 'lightgray'))
        size.append(node_sizes.get(n, 10))
        custom.append(f"{n} ({et})")
    node_traces.append(go.Scatter(
        x=xs, y=ys, mode='markers+text', textposition='top center',
        text=txt, marker=dict(size=size, color=col, line=dict(width=0.5, color='black')),
        hovertext=custom, hoverinfo='text', visible=(t=='All'), name=t
    ))

fig = go.Figure(data=edge_traces + node_traces)

# Separate sentiment and relationship dropdowns
fig.update_layout(updatemenus=[
    dict(
        buttons=[dict(label='All Sentiments', method='update', args=[
            {'visible': [True]*len(edge_traces) + [True]*len(node_traces)},
            {'title': 'All Sentiments'}
        ])] + [
            dict(label=s, method='update', args=[
                {'visible': [s in trace.name for trace in edge_traces] + [True]*len(node_traces)},
                {'title': f"Sentiment: {s}"}
            ]) for s in sentiments
        ],
        direction='down', x=0, y=1.15
    ),
    dict(
        buttons=[dict(label='All Relationships', method='update', args=[
            {'visible': [True]*len(edge_traces) + [True]*len(node_traces)},
            {'title': 'All Relationships'}
        ])] + [
            dict(label=r, method='update', args=[
                {'visible': [r in trace.name for trace in edge_traces] + [True]*len(node_traces)},
                {'title': f"Relationship: {r}"}
            ]) for r in relationships
        ],
        direction='down', x=0.25, y=1.15
    ),
    dict(
        buttons=[
            dict(label='All Types', method='update', args=[
                {'visible': [True]*len(edge_traces) + [i==0 for i in range(len(node_traces))]},
                {'title': 'All Entity Types'}]),
            *[dict(label=t, method='update', args=[
                {'visible': [True]*len(edge_traces) + [i==(idx+1) for i in range(len(node_traces))]},
                {'title': f"Type: {t}"}]) for idx, t in enumerate(types)]
        ],
        direction='down', x=0.5, y=1.15
    )
])

# Search box placeholder
fig.update_layout(
    title="\U0001F4CA Interactive Political Knowledge Graph",
    margin=dict(l=20,r=20,b=20,t=60),
    hovermode='closest',
    showlegend=True,
    annotations=[
        dict(text="Search functionality for a person/node can be implemented in Dash for full interactivity.",
             showarrow=False, x=0.5, y=-0.15, xref='paper', yref='paper', align='center')
    ]
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import numpy as np

# Assume edges_df and ents_long already exist
# edges_df columns: source, target, relationship, sentiment, date, url
# ents_long columns: url, date, entity, entity_type

# ─── Graph Construction ─────────────────────────────────────────
G = nx.Graph()
for _, row in edges_df.iterrows():
    G.add_edge(row['source'], row['target'], 
               relationship=row['relationship'], 
               sentiment=row['sentiment'], 
               date=row['date'])

# ─── Centralities and Layout ───────────────────────────────────
degree_centrality = nx.degree_centrality(G)
pos = nx.spring_layout(G, k=0.15, iterations=50)

# ─── Node Trace Construction ───────────────────────────────────
node_trace = go.Scatter(
    x=[], y=[],
    text=[],
    textposition="top center",
    mode='markers',
    hoverinfo='text',
    marker=dict(size=[], color=[], sizemode='diameter', sizeref=0.05, showscale=False),
)

# Entity type color map
entity_colors = {
    "people": "yellow",
    "institutions": "orange",
    "locations": "violet",
    "political_events": "gray",
    "political_parties": "lightblue",
    "unknown": "lightgray"
}

for node in G.nodes():
    x, y = pos[node]
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    deg = degree_centrality.get(node, 0)
    label = node if deg >= 0.01 else ""  # only label high-centrality nodes
    node_trace['text'] += tuple([node])
    node_type = ents_long.loc[ents_long.entity == node, "entity_type"].values
    color = entity_colors.get(node_type[0], "lightgray") if len(node_type) else "lightgray"
    node_trace['marker']['color'] += tuple([color])
    node_trace['marker']['size'] += tuple([10 + 30 * deg])

# ─── Edge Traces by Sentiment ───────────────────────────────────
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
sentiment_colors = {
    "FRIENDLY": "green",
    "HOSTILE": "red",
    "NEUTRAL": "gray"
}

edge_traces = []
for sentiment in sentiments:
    edge_x = []
    edge_y = []
    for u, v, d in G.edges(data=True):
        if d.get("sentiment") != sentiment:
            continue
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_x += [x0, x1, None]
        edge_y += [y0, y1, None]
    edge_traces.append(go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color=sentiment_colors.get(sentiment, "#888")),
        hoverinfo='none',
        mode='lines',
        name=sentiment
    ))

# ─── Dropdown Filters ───────────────────────────────────────────
# Unique relationships
relationships = sorted(edges_df['relationship'].dropna().unique().tolist())
entity_types = sorted(ents_long['entity_type'].dropna().unique().tolist())

updatemenus = [
    dict(
        buttons=[
            dict(label="All Sentiments", method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": "All Sentiments"}])
        ] + [
            dict(label=s, method="update",
                 args=[{"visible": [i==j for i in range(len(edge_traces))] + [True]},
                       {"title": f"Sentiment: {s}"}])
            for j, s in enumerate(sentiments)
        ],
        direction="down",
        showactive=True,
        x=0.1, y=1.1
    ),
    dict(
        buttons=[
            dict(label="All Relationships", method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": "All Relationships"}])
        ] + [
            dict(label=r, method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": f"Relationship: {r}"}])
            for r in relationships
        ],
        direction="down",
        showactive=True,
        x=0.3, y=1.1
    ),
    dict(
        buttons=[
            dict(label="All Types", method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": "All Types"}])
        ] + [
            dict(label=et, method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": f"Entity Type: {et}"}])
            for et in entity_types
        ],
        direction="down",
        showactive=True,
        x=0.5, y=1.1
    )
]

# ─── Final Graph ────────────────────────────────────────────────
fig = go.Figure(data=edge_traces + [node_trace],
                layout=go.Layout(
                    title="Interactive Knowledge Graph",
                    hovermode='closest',
                    updatemenus=updatemenus,
                    showlegend=True,
                    margin=dict(l=20, r=20, t=40, b=20)
                ))

fig.show()

# %% [markdown]
# # using Pyvis and ede bundleing and other tehcniques

# %%
# from pyvis.network import Network
# import networkx as nx
# import pandas as pd

# # Create the graph
# G = nx.Graph()

# # Add weighted edges to graph
# for _, row in edges_df.iterrows():
#     G.add_edge(
#         row['source'], 
#         row['target'], 
#         sentiment=row['sentiment'], 
#         relationship=row['relationship'], 
#         url=row['url'], 
#         date=str(row['date'])  # make sure it's a string
#     )

# # Degree centrality for sizing
# deg_cent = nx.degree_centrality(G)

# # Get entity types from ents_long
# entity_type_map = ents_long.drop_duplicates('entity').set_index('entity')['entity_type'].to_dict()

# # Color map by entity type
# type_colors = {
#     "people": "#ffd700",  # yellow
#     "organizations": "#ff7f0e",  # orange
#     "locations": "#9467bd",  # purple
#     "political_events": "#7f7f7f",  # gray
#     "political_parties": "#2ca02c",  # green
#     "institutions": "#1f77b4",  # blue
#     "unknown": "#d62728",  # red
# }

# # Create PyVis network
# net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", notebook=True)
# net.barnes_hut()

# # Add nodes
# for node in G.nodes():
#     entity_type = entity_type_map.get(node, "unknown")
#     color = type_colors.get(entity_type, "#d3d3d3")
#     size = 10 + deg_cent.get(node, 0) * 100  # scale up central nodes
#     label = node if size > 20 else ""  # hide labels for small nodes

#     net.add_node(
#         n_id=node,
#         label=label,
#         title=f"{node} ({entity_type})",
#         color=color,
#         size=size
#     )

# # Add edges with sentiment color
# sentiment_colors = {
#     "FRIENDLY": "green",
#     "HOSTILE": "red",
#     "NEUTRAL": "gray"
# }

# for u, v, d in G.edges(data=True):
#     color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
#     label = d.get('relationship', '')
#     title = f"{u} {label} {v}<br>Sentiment: {d.get('sentiment')}<br>Date: {d.get('date')}"

#     net.add_edge(u, v, color=color, title=title, value=1)

# # Generate and show the HTML
# net.show("knowledge_graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# knowledge_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="knowledge_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from pyvis.network import Network
import networkx as nx
import pandas as pd
from IPython.display import IFrame, display
import ipywidgets as widgets
import os 

# Create a local directory for the output
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# Base variables
selected_sentiment = widgets.Dropdown(
    options=["All"] + sorted(edges_df["sentiment"].dropna().unique().tolist()),
    description='Sentiment:'
)

selected_relationship = widgets.Dropdown(
    options=["All"] + sorted(edges_df["relationship"].dropna().unique().tolist()),
    description='Relation:'
)

date_range = widgets.SelectionRangeSlider(
    options=sorted(edges_df["date"].dropna().astype(str).unique().tolist()),
    index=(0, len(edges_df["date"].unique()) - 1),
    description='Date:',
    orientation='horizontal',
    layout={'width': '800px'}
)

# Callback
def generate_filtered_graph(sentiment, relationship, date_range_values):
    filtered_edges = edges_df.copy()
    if sentiment != "All":
        filtered_edges = filtered_edges[filtered_edges["sentiment"] == sentiment]
    if relationship != "All":
        filtered_edges = filtered_edges[filtered_edges["relationship"] == relationship]
    filtered_edges = filtered_edges[
        (filtered_edges["date"] >= date_range_values[0]) &
        (filtered_edges["date"] <= date_range_values[1])
    ]

    G = nx.Graph()
    for _, row in filtered_edges.iterrows():
        G.add_edge(row['source'], row['target'], 
                   sentiment=row['sentiment'], 
                   relationship=row['relationship'], 
                   url=row['url'], 
                   date=str(row['date']))

    deg_cent = nx.degree_centrality(G)
    entity_type_map = ents_long.drop_duplicates('entity').set_index('entity')['entity_type'].to_dict()
    type_colors = {
        "people": "#ffd700",
        "organizations": "#ff7f0e",
        "locations": "#9467bd",
        "political_events": "#7f7f7f",
        "political_parties": "#2ca02c",
        "institutions": "#1f77b4",
        "unknown": "#d62728",
    }
    sentiment_colors = {
        "FRIENDLY": "green",
        "HOSTILE": "red",
        "NEUTRAL": "gray"
    }

    # Create the network
    net = Network(
        height="750px",
        width="100%",
        bgcolor="#222222",
        font_color="white",
        notebook=True
    )
    net.barnes_hut()

    # Add nodes
    for node in G.nodes():
        entity_type = entity_type_map.get(node, "unknown")
        color = type_colors.get(entity_type, "#d3d3d3")
        size = 10 + deg_cent.get(node, 0) * 100
        label = node if size > 20 else ""
        net.add_node(
            n_id=node, 
            label=label,
            title=f"{node} ({entity_type})",
            color=color, 
            size=size
        )

    # Add edges
    for u, v, d in G.edges(data=True):
        color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
        label = d.get('relationship', '')
        title = f"{u} {label} {v}<br>Sentiment: {d.get('sentiment')}<br>Date: {d.get('date')}"
        net.add_edge(u, v, color=color, title=title, value=1)

    # Save and show the graph
    output_file = os.path.join(output_dir, 'filtered_kg.html')
    net.save_graph(output_file)
    
    # Display the graph in a new window
    net.show(output_file)

# Create the UI
ui = widgets.VBox([selected_sentiment, selected_relationship, date_range])

# Link interactivity
widgets.interact(
    generate_filtered_graph,
    sentiment=selected_sentiment,
    relationship=selected_relationship,
    date_range_values=date_range
)

# Display the UI
display(ui)
# Out:
# interactive(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), va…
# VBox(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), value='Al…

# %%
from pyvis.network import Network
import networkx as nx
import pandas as pd
from IPython.display import IFrame, display, HTML
import ipywidgets as widgets
import os 
import webbrowser

# Create a local directory for the output
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# Base variables
selected_sentiment = widgets.Dropdown(
    options=["All"] + sorted(edges_df["sentiment"].dropna().unique().tolist()),
    description='Sentiment:'
)

selected_relationship = widgets.Dropdown(
    options=["All"] + sorted(edges_df["relationship"].dropna().unique().tolist()),
    description='Relation:'
)

date_range = widgets.SelectionRangeSlider(
    options=sorted(edges_df["date"].dropna().astype(str).unique().tolist()),
    index=(0, len(edges_df["date"].unique()) - 1),
    description='Date:',
    orientation='horizontal',
    layout={'width': '800px'}
)

# Callback
def generate_filtered_graph(sentiment, relationship, date_range_values):
    filtered_edges = edges_df.copy()
    if sentiment != "All":
        filtered_edges = filtered_edges[filtered_edges["sentiment"] == sentiment]
    if relationship != "All":
        filtered_edges = filtered_edges[filtered_edges["relationship"] == relationship]
    filtered_edges = filtered_edges[
        (filtered_edges["date"] >= date_range_values[0]) &
        (filtered_edges["date"] <= date_range_values[1])
    ]

    # Create a directed graph instead of undirected
    G = nx.DiGraph()
    for _, row in filtered_edges.iterrows():
        G.add_edge(row['source'], row['target'], 
                   sentiment=row['sentiment'], 
                   relationship=row['relationship'], 
                   url=row['url'], 
                   date=str(row['date']))

    # Calculate both in-degree and out-degree centrality
    in_deg_cent = nx.in_degree_centrality(G)
    out_deg_cent = nx.out_degree_centrality(G)
    deg_cent = nx.degree_centrality(G)  # total degree for node sizing

    entity_type_map = ents_long.drop_duplicates('entity').set_index('entity')['entity_type'].to_dict()
    type_colors = {
        "people": "#ffd700",
        "organizations": "#ff7f0e",
        "locations": "#9467bd",
        "political_events": "#7f7f7f",
        "political_parties": "#2ca02c",
        "institutions": "#1f77b4",
        "unknown": "#d62728",
    }
    sentiment_colors = {
        "FRIENDLY": "green",
        "HOSTILE": "red",
        "NEUTRAL": "gray"
    }

    # Create the network
    net = Network(
        height="750px",
        width="100%",
        bgcolor="#222222",
        font_color="white",
        notebook=True,
        cdn_resources='in_line',
        directed=True  # Enable directed edges
    )
    net.barnes_hut()

    # Add nodes with hover information including in/out degree
    for node in G.nodes():
        entity_type = entity_type_map.get(node, "unknown")
        color = type_colors.get(entity_type, "#d3d3d3")
        size = 10 + deg_cent.get(node, 0) * 100
        label = node if size > 20 else ""
        
        # Create detailed hover text
        hover_text = f"""
        {node} ({entity_type})
        Incoming relationships: {in_deg_cent.get(node, 0):.2f}
        Outgoing relationships: {out_deg_cent.get(node, 0):.2f}
        Total relationships: {deg_cent.get(node, 0):.2f}
        """
        
        net.add_node(
            n_id=node, 
            label=label,
            title=hover_text,
            color=color, 
            size=size
        )

    # Add edges with arrows and detailed information
    for u, v, d in G.edges(data=True):
        color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
        label = d.get('relationship', '')
        title = f"""
        From: {u}
        To: {v}
        Relationship: {label}
        Sentiment: {d.get('sentiment')}
        Date: {d.get('date')}
        """
        net.add_edge(
            u, v, 
            color=color, 
            title=title, 
            value=1,
            arrows='to',  # Add arrows to show direction
            smooth=True   # Make edges curved for better visibility
        )

    # Save the graph
    output_file = os.path.join(output_dir, 'filtered_kg.html')
    net.save_graph(output_file)
    
    # Open in browser
    webbrowser.open('file://' + os.path.abspath(output_file))

# Create the UI
ui = widgets.VBox([selected_sentiment, selected_relationship, date_range])

# Link interactivity
widgets.interact(
    generate_filtered_graph,
    sentiment=selected_sentiment,
    relationship=selected_relationship,
    date_range_values=date_range
)

# Display the UI
display(ui)
# Out:
# interactive(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), va…
# VBox(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), value='Al…

# %%
from graph_visualization import generate_graph

# Run the graph visualization
generate_graph()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
edges_df.to_csv('edges_df.csv')
ents_long.to_csv('ents_long.csv')

# %%
from pyvis.network import Network
import networkx as nx
import pandas as pd
from IPython.display import IFrame, display, HTML
import ipywidgets as widgets
import os 
import webbrowser
from community import community_louvain

# Create output directory
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

def generate_filtered_graph(sentiment="All", relationship="All", date_range_values=None, search_term=""):
    filtered_edges = edges_df.copy()
    
    # Apply filters
    if sentiment != "All":
        filtered_edges = filtered_edges[filtered_edges["sentiment"] == sentiment]
    if relationship != "All":
        filtered_edges = filtered_edges[filtered_edges["relationship"] == relationship]
    if date_range_values:
        filtered_edges = filtered_edges[
            (filtered_edges["date"] >= date_range_values[0]) &
            (filtered_edges["date"] <= date_range_values[1])
        ]

    # Create directed graph
    G = nx.DiGraph()
    for _, row in filtered_edges.iterrows():
        G.add_edge(row['source'], row['target'], 
                   sentiment=row['sentiment'], 
                   relationship=row['relationship'], 
                   url=row['url'], 
                   date=str(row['date']))

    # If search term exists, filter to only show connected nodes
    if search_term:
        # Find all nodes connected to the searched term
        connected_nodes = set()
        for node in G.nodes():
            if search_term.lower() in node.lower():
                connected_nodes.add(node)
                # Add first-degree connections
                connected_nodes.update(G.neighbors(node))
                connected_nodes.update(G.predecessors(node))
        
        # Create subgraph with only connected nodes
        G = G.subgraph(connected_nodes).copy()

    # Calculate centralities
    in_deg_cent = nx.in_degree_centrality(G)
    out_deg_cent = nx.out_degree_centrality(G)
    deg_cent = nx.degree_centrality(G)
    
    # Get top nodes by degree centrality
    top_nodes = sorted(deg_cent.items(), key=lambda x: x[1], reverse=True)[:20]
    top_node_ids = [node for node, _ in top_nodes]

    # Detect communities
    partition = community_louvain.best_partition(G.to_undirected())
    
    # Create the network
    net = Network(
        height="750px",
        width="100%",
        bgcolor="#222222",
        font_color="white",
        notebook=True,
        cdn_resources='in_line',
        directed=True
    )

    # Enhanced physics options
    net.set_options("""
    {
        "physics": {
            "forceAtlas2Based": {
                "gravitationalConstant": -100,
                "centralGravity": 0.01,
                "springLength": 200,
                "springConstant": 0.08,
                "damping": 0.4,
                "avoidOverlap": 1
            },
            "maxVelocity": 10,
            "minVelocity": 0.1,
            "solver": "forceAtlas2Based",
            "stabilization": {
                "enabled": true,
                "iterations": 2000,
                "updateInterval": 50,
                "onlyDynamicEdges": false,
                "fit": true
            }
        },
        "edges": {
            "smooth": {
                "enabled": true,
                "type": "continuous",
                "forceDirection": "none",
                "roundness": 0.5
            },
            "color": {
                "inherit": true
            },
            "width": 1,
            "arrows": {
                "to": {
                    "enabled": true,
                    "scaleFactor": 1.5,
                    "type": "arrow"
                }
            }
        },
        "nodes": {
            "font": {
                "size": 14,
                "face": "arial"
            },
            "scaling": {
                "min": 10,
                "max": 30
            }
        }
    }
    """)

    # Add nodes
    for node in G.nodes():
        entity_type = entity_type_map.get(node, "unknown")
        color = type_colors.get(entity_type, "#d3d3d3")
        size = 10 + deg_cent.get(node, 0) * 100
        
        # Show label for searched node, top nodes, or when zoomed in
        label = node if (node in top_node_ids or 
                        (search_term and search_term.lower() in node.lower())) else ""
        
        # Highlight searched node
        if search_term and search_term.lower() in node.lower():
            color = "#ff0000"
            size *= 1.5
        
        hover_text = f"""
        <div style='font-size: 14px;'>
            <b>{node}</b> ({entity_type})<br>
            Community: {partition.get(node, 0)}<br>
            Incoming relationships: {in_deg_cent.get(node, 0):.2f}<br>
            Outgoing relationships: {out_deg_cent.get(node, 0):.2f}<br>
            Total relationships: {deg_cent.get(node, 0):.2f}
        </div>
        """
        
        net.add_node(
            n_id=node, 
            label=label,
            title=hover_text,
            color=color, 
            size=size,
            group=partition.get(node, 0)
        )

    # Add edges
    for u, v, d in G.edges(data=True):
        color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
        label = d.get('relationship', '')
        title = f"""
        <div style='font-size: 14px;'>
            <b>From:</b> {u}<br>
            <b>To:</b> {v}<br>
            <b>Relationship:</b> {label}<br>
            <b>Sentiment:</b> {d.get('sentiment')}<br>
            <b>Date:</b> {d.get('date')}
        </div>
        """
        net.add_edge(
            u, v, 
            color=color, 
            title=title, 
            value=1,
            smooth=True,
            width=1
        )

    # Add custom HTML with filters and controls
    custom_html = """
    <div style="position: absolute; top: 10px; right: 10px; z-index: 1000; background: rgba(255,255,255,0.9); padding: 10px; border-radius: 5px;">
        <div style="margin-bottom: 10px;">
            <input type="text" id="searchInput" placeholder="Search nodes..." 
                   style="padding: 5px; border-radius: 4px; border: 1px solid #ccc; width: 200px;">
            <button onclick="searchNodes()" 
                    style="padding: 5px 10px; border-radius: 4px; border: 1px solid #ccc; background: #fff;">
                Search
            </button>
        </div>
        <div style="margin-bottom: 10px;">
            <select id="sentimentFilter" onchange="applyFilters()" 
                    style="padding: 5px; border-radius: 4px; border: 1px solid #ccc; width: 200px;">
                <option value="All">All Sentiments</option>
                <option value="FRIENDLY">Friendly</option>
                <option value="HOSTILE">Hostile</option>
                <option value="NEUTRAL">Neutral</option>
            </select>
        </div>
        <div style="margin-bottom: 10px;">
            <select id="relationshipFilter" onchange="applyFilters()" 
                    style="padding: 5px; border-radius: 4px; border: 1px solid #ccc; width: 200px;">
                <option value="All">All Relationships</option>
                <option value="SUPPORTS">Supports</option>
                <option value="OPPOSES">Opposes</option>
                <option value="WORKS_WITH">Works With</option>
                <!-- Add other relationships as needed -->
            </select>
        </div>
        <div style="margin-bottom: 10px;">
            <button onclick="togglePhysics()" 
                    style="padding: 5px 10px; border-radius: 4px; border: 1px solid #ccc; background: #fff;">
                Toggle Physics
            </button>
            <button onclick="resetView()" 
                    style="padding: 5px 10px; border-radius: 4px; border: 1px solid #ccc; background: #fff;">
                Reset View
            </button>
        </div>
    </div>
    <script>
    function searchNodes() {
        var searchTerm = document.getElementById('searchInput').value.toLowerCase();
        if (searchTerm) {
            // Rebuild graph with search term
            window.location.href = '?search=' + searchTerm;
        }
    }

    function applyFilters() {
        var sentiment = document.getElementById('sentimentFilter').value;
        var relationship = document.getElementById('relationshipFilter').value;
        window.location.href = '?sentiment=' + sentiment + '&relationship=' + relationship;
    }
    
    function togglePhysics() {
        var physics = network.getOptions().physics;
        network.setOptions({ physics: { enabled: !physics.enabled } });
    }

    function resetView() {
        network.fit({
            animation: {
                duration: 1000,
                easingFunction: 'easeInOutQuad'
            }
        });
    }

    // Add zoom-based label visibility
    network.on("zoom", function() {
        var zoom = network.getScale();
        var nodes = network.body.data.nodes;
        nodes.forEach(function(node) {
            if (zoom > 1.5) {
                node.label = node.id;
            } else {
                node.label = node.id in topNodes ? node.id : "";
            }
        });
        network.body.data.nodes.update(nodes);
    });
    </script>
    """
    
    # Save and display
    output_file = os.path.join(output_dir, 'filtered_kg.html')
    net.save_graph(output_file)
    
    with open(output_file, 'r') as f:
        content = f.read()
    
    content = content.replace('</body>', f'{custom_html}</body>')
    
    with open(output_file, 'w') as f:
        f.write(content)
    
    webbrowser.open('file://' + os.path.abspath(output_file))

# Initial graph generation
generate_filtered_graph()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# Generate the initial graph
generate_graph()

# Run the Flask app
if __name__ == "__main__":
    app.run(port=5000, debug=True)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#  * Tip: There are .env files present. Install python-dotenv to use them.
#  * Serving Flask app '__main__'
#  * Debug mode: on
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# On macOS, try disabling the 'AirPlay Receiver' service from System Preferences -> General -> AirDrop & Handoff.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/ghadena/Desktop/geopol/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3678: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
from interactive_kg_app import run_app_with_data
run_app_with_data('edges_df.csv', 'ents_long.csv')
# Out:
#  * Tip: There are .env files present. Install python-dotenv to use them.
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
#  * Serving Flask app 'interactive_kg_app'
#  * Debug mode: off
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# On macOS, try disabling the 'AirPlay Receiver' service from System Preferences -> General -> AirDrop & Handoff.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from ne_kg import app
app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from visjs_dashboard.app_enhanced import app
import webbrowser
from threading import Timer
import os

def open_browser():
    webbrowser.open('http://localhost:5757')

if __name__ == "__main__":
    # Get the current working directory
    current_dir = os.getcwd()
    print(f"Current directory: {current_dir}")
    
    # Start the browser after a short delay
    Timer(1.5, open_browser).start()
    
    # Run the app with use_reloader=False to prevent the SystemExit error
    app.run(port=5757, debug=True, use_reloader=False)
# Out:
#  * Tip: There are .env files present. Install python-dotenv to use them.
# Current directory: /Users/ghadena/Desktop/geopol
#  * Serving Flask app 'visjs_dashboard.app_enhanced'
#  * Debug mode: on
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
