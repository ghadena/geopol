# %%
# from extract_entites import main

# main(
#     source_table="int_aa_dev_common_worskapce_catalog.geopol.french_election_text",
#     output_table="int_aa_dev_common_worskapce_catalog.geopol.french_extracted_entities"
# )

# %% [markdown]
# #Testing the entity and sentiment extraction pipeline
# 	•	Developed two Python scripts:
# 	•	✅ One script to save output into a new Delta table
# 	•	✅ Another script to return output as a Pandas DataFrame and save it as a CSV
# 	•	❌ Did not continue with the table-writing script due to lack of table creation/edit permissions
# 	•	✅ The DataFrame version worked perfectly
# 	•	🧪 Ran a test version on 9 rows:
# 	•	One article that appeared unrelated to elections produced no entities or sentiment edges
# 	•	Other outputs looked sound and correct
# 	•	✅ Successfully examined the results and saved them to a CSV
# 	•	⚠️ Faced API rate limit issues, especially with requests per minute
# 	•	⏳ Did not process the full DataFrame because it was too slow due to rate limits
# 	•	✅ Confirmed that the pipeline is working correctly

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from extract_2 import main
df_results = main("int_aa_dev_common_worskapce_catalog.geopol.us_election_text")

# %%
df_results.to_csv("us_entites.csv", index=False)

# %% [markdown]
# # french

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from extract_2 import main
df2 = main("int_aa_dev_common_worskapce_catalog.geopol.french_election_text")

# %%
df2.to_csv("french_entites.csv", index=False)

# %%
#df_results['extracted_entities'][9]

# %%
#df_results['entity_relationships'][9]

# %%
# us_election = spark.table("int_aa_dev_common_worskapce_catalog.geopol.us_election_text").toPandas()

# %%
# import pandas as pd
# merged_df = pd.merge(us_election, df_results, on="url", how="inner")

# %%
# merged_df.head(30)

# %%
# merged_df.iloc[9].text

# %%
#df_results.to_csv("test_output.csv", index=False)

# %% [markdown]
# # extracting us entities and sentiment

# %%
# df_us = main("int_aa_dev_common_worskapce_catalog.geopol.us_election_text")

# %%
# df_us.to_csv("us_extracted.csv", index=False)

# %%
# %fs ls /dbfs/

# %%
# %fs ls /dbfs/tmp/
# %fs ls /dbfs/user/

# %% [markdown]
# # extracting french entities and sentiment

# %%
# df_french = main("int_aa_dev_common_worskapce_catalog.geopol.french_election_text")

# %% [markdown]
# # new

# %%
import pandas as pd
import sys
import os


# Add the project root to the Python path
sys.path.append(os.path.abspath('..'))

import os
from lib.extract_with_llm import main

# %%
df_f = pd.read_parquet('/Users/ghadena/Desktop/geopol/data/raw/french_election_texts.parquet')

# %%
df_f.head()
# Out:
#                                                  url  \
# 0                         https://www.lemonde.fr/en/
# 1           https://www.lemonde.fr/en/international/
# 2                  https://www.lemonde.fr/en/france/
# 3           https://www.lemonde.fr/en/global-issues/
# 4  https://www.lemonde.fr/en/about-us/article/202...
#
#                       datetime language  \
# 0  2025-05-17T00:00:00.0000000       en
# 1  2025-05-18T00:00:00.0000000       en
# 2  2025-05-16T00:00:00.0000000       en
# 3  2025-05-14T00:00:00.0000000       en
# 4  2025-02-14T00:00:00.0000000       en
#
#                                          description  \
# 0  France's leading newspaper brings you the late...
# 1  In Depth Subscribers only Trump and Gulf monar...
# 2  Op-Ed Subscribers only 'The choices government...
# 3  News Blockbuster trial of music mogul Sean 'Di...
# 4  F or the past two and a half years, Le Monde, ...
#
#                                         article_text
# ...

# %%
df_f.iloc[25].article_text
# Out:
# ''

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2195 entries, 0 to 2194
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           2195 non-null   object
#  1   datetime      2195 non-null   object
#  2   language      2195 non-null   object
#  3   description   2195 non-null   object
#  4   article_text  2195 non-null   object
# dtypes: object(5)
# memory usage: 85.9+ KB

# %%
# Count of non-empty articles (ignores empty strings and NaNs)
non_empty_count = df_f['article_text'].astype(str).str.strip().replace('', pd.NA).dropna().shape[0]

# Count of articles with more than 50 words
over_50_words_count = df_f['article_text'].astype(str).apply(lambda x: len(x.split()) > 50).sum()

print(f"Non-empty articles: {non_empty_count}")
print(f"Articles with more than 50 words: {over_50_words_count}")
# Out:
# Non-empty articles: 1187
# Articles with more than 50 words: 1034

# %%
df_f.language.value_counts()
# Out:
# language
# en    1641
# fr     547
# ar       3
# es       2
# de       1
# vi       1
# Name: count, dtype: int64

# %%
# Filter articles with more than 50 words
long_articles = df_f[df_f['article_text'].astype(str).apply(lambda x: len(x.split()) > 50)]

# Get language distribution
language_distribution = long_articles['language'].value_counts()

print(language_distribution)
# Out:
# language
# en    573
# fr    460
# vi      1
# Name: count, dtype: int64

# %%
df_g = pd.read_parquet('/Users/ghadena/Desktop/geopol/data/raw/urls.parquet')

# %%
df_g.head()
# Out:
#                                                  url  \
# 0      https://www.spiegel.de/international/germany/
# 1      https://www.spiegel.de/thema/morningbriefing/
# 2  https://www.spiegel.de/politik/deutschland/new...
# 3  https://www.spiegel.de/politik/deutschland/new...
# 4  https://www.spiegel.de/politik/deutschland/uni...
#
#                       datetime language  \
# 0  2024-01-10T22:54:46.0000000       en
# 1  2025-04-17T00:00:00.0000000       de
# 2  2025-04-13T00:00:00.0000000       de
# 3  2025-02-17T00:00:00.0000000       de
# 4                                    de
#
#                                          description  \
# 0  Deutschlands führende Nachrichtenseite. Alles ...
# 1  Italiens Regierungschefin soll in Washington d...
# 2  Das Programm der Koalition überzeugt nicht. Um...
# 3  Das erste Treffen zwischen der russischen und ...
# 4  Union und SPD haben sich auf einen Koalitionsv...
#
#                                         article_text
# ...

# %%
df_g.shape
# Out:
# (2059, 5)

# %%
# Count of non-empty articles (ignores empty strings and NaNs)
non_empty_count = df_g['article_text'].astype(str).str.strip().replace('', pd.NA).dropna().shape[0]

# Count of articles with more than 50 words
over_50_words_count = df_g['article_text'].astype(str).apply(lambda x: len(x.split()) > 50).sum()

print(f"Non-empty articles: {non_empty_count}")
print(f"Articles with more than 50 words: {over_50_words_count}")
# Out:
# Non-empty articles: 1695
# Articles with more than 50 words: 1480

# %%
# Filter articles with more than 50 words
long_articles = df_g[df_g['article_text'].astype(str).apply(lambda x: len(x.split()) > 50)]

# Get language distribution
language_distribution = long_articles['language'].value_counts()

print(language_distribution)
# Out:
# language
# de    870
# en    603
# fr      5
# vi      1
# nl      1
# Name: count, dtype: int64

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = df_f.sample(20)

# %%
df.head(20)
# Out:
#                                                     url  \
# 643   https://www.bfmtv.com/societe/au-chateau-de-ch...
# 1467  https://www.reuters.com/technology/litmus-test...
# 1761        https://www.politico.eu/tag/irish-politics/
# 1839  https://www.politico.eu/article/ukraine-plead-...
# 158   https://www.lemonde.fr/en/economy/article/2025...
# 2163  https://www.france24.com/en/live-news/20250416...
# 1371  https://www.reuters.com/business/energy/back-r...
# 2014  https://www.euronews.com/2025/04/08/global-exe...
# 1957  https://www.euronews.com/2025/03/15/uk-to-hold...
# 739   https://www.rfi.fr/en/international/20241214-f...
# 1787  https://www.politico.eu/article/romania-presid...
# 435   https://www.liberation.fr/politique/selon-rima...
# 195   https://www.lefigaro.fr/conjoncture/droits-de-...
# 1624  https://apnews.com/video/dicaprio-and-tarantin...
# 295   https://www.lefigaro.fr/politique/braquages-te...
# 802   https://www.rfi.fr/en/france/20240922-meet-the...
# ...

# %%
df.to_csv('df_test.csv')

# %% [markdown]
# # test

# %%
import pandas as pd
import sys
import os


# Add the project root to the Python path
sys.path.append(os.path.abspath('..'))

import os
from lib.extract_with_llm import main

# %%
#DESC_COLUMN = "description"
df_results = main('df_test.csv')
# Out:
# 📥 Loading data...
# 📁 Created backup folder: backups
# ...
# 100%|██████████| 20/20 [00:51<00:00,  2.56s/it]
# 💾 Final results saved to backups/gemini_results_backup_20250519_0027_final.csv
# ✅ Finished all rows. Returning 20 results as DataFrame.

# %%
df_results.head(20)
# Out:
#                                                   url lang  \
# 0   https://www.bfmtv.com/societe/au-chateau-de-ch...   fr
# 1   https://www.reuters.com/technology/litmus-test...   en
# 2         https://www.politico.eu/tag/irish-politics/   en
# 3   https://www.politico.eu/article/ukraine-plead-...   en
# 4   https://www.lemonde.fr/en/economy/article/2025...   en
# 5   https://www.france24.com/en/live-news/20250416...   en
# 6   https://www.reuters.com/business/energy/back-r...   en
# 7   https://www.euronews.com/2025/04/08/global-exe...   en
# 8   https://www.euronews.com/2025/03/15/uk-to-hold...   en
# 9   https://www.rfi.fr/en/international/20241214-f...   en
# 10  https://www.politico.eu/article/romania-presid...   en
# 11  https://www.liberation.fr/politique/selon-rima...   fr
# 12  https://www.lefigaro.fr/conjoncture/droits-de-...   fr
# 13  https://apnews.com/video/dicaprio-and-tarantin...   en
# 14  https://www.lefigaro.fr/politique/braquages-te...   fr
# ...

# %%
df_results.iloc[19].entity_relationships
# Out:
# [{'source': 'SNCF Voyageurs',
#   'target': 'Alstom',
#   'relationship': 'accuses',
#   'sentiment': 'HOSTILE'},
#  {'source': 'Alstom',
#   'target': 'SNCF Voyageurs',
#   'relationship': 'partners with',
#   'sentiment': 'NEUTRAL'},
#  {'source': 'Île-de-France Mobilités (IDFM)',
#   'target': 'RER D',
#   'relationship': 'supports',
#   'sentiment': 'NEUTRAL'},
#  {'source': 'Île-de-France Mobilités (IDFM)',
#   'target': 'RER E',
#   'relationship': 'supports',
#   'sentiment': 'NEUTRAL'}]

# %%
df = pd.read_csv("df_test.csv")
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0         643  https://www.bfmtv.com/societe/au-chateau-de-ch...
# 1        1467  https://www.reuters.com/technology/litmus-test...
# 2        1761        https://www.politico.eu/tag/irish-politics/
# 3        1839  https://www.politico.eu/article/ukraine-plead-...
# 4         158  https://www.lemonde.fr/en/economy/article/2025...
#
#                       datetime language  \
# 0  2025-05-18T00:00:00.0000000       fr
# 1  2025-04-17T00:00:00.0000000       en
# 2  2024-12-02T21:20:00.0000000       en
# 3  2025-01-09T16:48:00.0000000       en
# 4  2025-04-10T00:00:00.0000000       en
#
#                                          description  \
# 0  VIDÉO - Au château de Chantilly, les plantes c...
# 1  Taiwan's TSMC on Thursday lifted some share pr...
# 2  Latest politics and policy news on Irish polit...
# 3  Thursday was no different, as the U.S., German...
# 4  The government had forecast annual growth of 0...
#
# ...

# %% [markdown]
# # french e

# %%
results_e = main('/Users/ghadena/Desktop/geopol/data/raw/french_election_texts.parquet')
# Out:
# 📥 Loading data...
# 📁 Backup folder already exists: backups
# 🔁 Resuming. Skipping 20 already-processed rows.
#   9%|▉         | 199/2167 [07:15<1:37:05,  2.96s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0036.csv
#  18%|█▊        | 399/2167 [17:22<1:24:05,  2.85s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0046.csv
#  28%|██▊       | 599/2167 [26:12<1:25:51,  3.29s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0055.csv
#  37%|███▋      | 799/2167 [34:00<49:04,  2.15s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0102.csv
#  46%|████▌     | 999/2167 [41:52<42:20,  2.18s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0110.csv
#  55%|█████▌    | 1199/2167 [52:06<57:58,  3.59s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0120.csv
#  65%|██████▍   | 1399/2167 [1:02:05<24:51,  1.94s/it]
# 💾 Saved backup to backups/gemini_results_backup_20250519_0130.csv
# ...

# %%
results_e.to_csv('french_entities_extracted.csv')

# %% [markdown]
# # german e

# %%
results_g =  main('/Users/ghadena/Desktop/geopol/data/raw/urls.parquet')
# Out:
# 📥 Loading data...
# 📁 Backup folder already exists: backups
# 🔁 Resuming. Skipping 3737 already-processed rows.
#   2%|▏         | 4/244 [00:12<13:29,  3.37s/it]
# [JSON ERROR] row 4 (https://www.euronews.com/green/2025/04/08/world-surpasses-40-clean-electricity-with-europe-leading-as-a-solar-superpower): Illegal trailing comma before end of array: line 104 column 6 (char 2112)
#   2%|▏         | 6/244 [00:21<16:09,  4.07s/it]
# [ERROR] row 6 (https://www.euronews.com/2025/04/20/iran-and-us-start-second-round-of-nuclear-talks-in-rome): 500 Internal error encountered.
#   3%|▎         | 7/244 [00:23<14:10,  3.59s/it]
# [ERROR] row 7 (https://www.euronews.com/my-europe/2025/03/21/brussels-confirms-rearm-europe-rebrand-after-backlash-from-italy-and-spain): 500 Internal error encountered.
#   4%|▍         | 10/244 [00:34<13:56,  3.58s/it]
# ...

# %%
results_g.to_csv('german_entities_extracted.csv')

# %%
import pandas as pd
import glob
import os

# Set the folder where the CSVs are stored
folder_path = '/Users/ghadena/Desktop/geopol/notebooks/backups'  # ← update this if needed

# Match all relevant CSV files
csv_files = glob.glob(os.path.join(folder_path, 'gemini_results_backup_*.csv'))

# Concatenate them
df_combined = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# Save the combined result
output_path = os.path.join(folder_path, 'gemini_results_master.csv')
df_combined.to_csv(output_path, index=False)

print(f"Saved combined CSV to {output_path}")
# Out:
# Saved combined CSV to /Users/ghadena/Desktop/geopol/notebooks/backups/gemini_results_master.csv

# %%
df_combined.shape
# Out:
# (3787, 5)

# %%
df = pd.read_csv("gemini_results_master.csv")

# %%
df.shape
# Out:
# (4031, 5)

# %%
df1 = pd.read_parquet('/Users/ghadena/Desktop/geopol/data/raw/urls.parquet')
print(df1.shape)
df2 = pd.read_parquet('/Users/ghadena/Desktop/geopol/data/raw/french_election_texts.parquet')
df2.shape
# Out:
# (2059, 5)
# (2195, 5)

# %%
df1.columns
# Out:
# Index(['url', 'datetime', 'language', 'description', 'article_text'], dtype='object')

# %%
df2.language.value_counts()
# Out:
# language
# en    1641
# fr     547
# ar       3
# es       2
# de       1
# vi       1
# Name: count, dtype: int64

# %%
2059 + 2195
4254 - (4031 - 50 - 23)

# -23 for langauges 
#296 are missing
# Out:
# 296

# %%
df3 = pd.read_csv("backups/gemini_results_backup_20250519_1320_final.csv")

# %%
df3.shape
# Out:
# (44, 5)

# %%
duplicate_count = df.duplicated(subset='url').sum()
print(f"Exact duplicate rows: {duplicate_count}")
# Out:
# Exact duplicate rows: 50

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#                                                     url lang  \
# 1044  https://www.france24.com/en/live-news/20250415...   en
# 1046  https://www.france24.com/en/video/20250406-fra...   en
# 1048  https://www.france24.com/en/live-news/20250518...   en
# 1060  https://www.france24.com/en/live-news/20250518...   en
# 1063  https://www.france24.com/en/france/20250331-i-...   en
# 1064  https://www.france24.com/en/tv-shows/down-to-e...   en
# 1066  https://www.france24.com/en/live-news/20250418...   en
# 1067  https://www.france24.com/en/live-news/20250413...   en
# 1071  https://www.france24.com/en/live-news/20250420...   en
# 1072  https://france24.com/en/archives/middle-east/2...   en
# 1074  https://www.france24.com/en/live-news/20250418...   en
# 1079  https://www.france24.com/en/europe/20250423-wh...   en
# 1082  https://www.france24.com/en/video/20250417-geo...   en
# 1089  https://www.france24.com/en/video/20250518-vot...   en
# ...

# %%
duplicate_urls_full = df[df.duplicated(subset='url', keep=False)]
duplicate_urls_full
# Out:
#                                                     url lang  \
# 39    https://www.france24.com/en/live-news/20250512...   en
# 43    https://www.france24.com/en/france/20250515-ma...   en
# 45    https://www.france24.com/en/live-news/20250516...   en
# 47    https://www.france24.com/en/europe/20250322-te...   en
# 84    https://www.france24.com/en/live-news/20250518...   en
# ...                                                 ...  ...
# 3124  https://www.bfmtv.com/grand-lille/replay-emiss...   fr
# 3125  https://www.bfmtv.com/lyon/replay-emissions/bo...   fr
# 3159  https://www.bfmtv.com/grand-lille/sport/ligue-...   fr
# 3176  https://www.bfmtv.com/international/europe/ukr...   fr
# 3177  https://www.bfmtv.com/replay-emissions/affaire...   fr
#
#                                      extracted_entities  \
# 39    {'people': [], 'institutions': ['France'], 'po...
# 43    {'people': ['Emmanuel Macron', 'Leo XIV'], 'in...
# 45    {'people': [], 'institutions': ['UN', 'court']...
# ...

# %%
# Step 1: Get all rows that are part of a duplicated URL group
dupes = df[df.duplicated(subset='url', keep=False)].copy()

# Step 2: Sort them by URL to make duplicates appear together
dupes_sorted = dupes.sort_values(by='url')

# Optional: Reset index for clean display
dupes_sorted.reset_index(drop=True, inplace=True)

# Show result
dupes_sorted.head()
# Out:
#                                                  url lang  \
# 0  https://france24.com/en/archives/middle-east/2...   en
# 1  https://france24.com/en/archives/middle-east/2...   en
# 2  https://www.bfmtv.com/grand-lille/replay-emiss...   fr
# 3  https://www.bfmtv.com/grand-lille/replay-emiss...   fr
# 4  https://www.bfmtv.com/grand-lille/sport/ligue-...   fr
#
#                                   extracted_entities entity_relationships  \
# 0  {'people': [], 'institutions': [], 'political_...                   []
# 1  {'people': [], 'institutions': [], 'political_...                   []
# 2  {'people': [], 'institutions': [], 'political_...                   []
# 3  {'people': [], 'institutions': [], 'political_...                   []
# 4  {'people': ['Rémy Canella'], 'institutions': [...                   []
#
#   relevant_to_german_or_french_elections
# 0                                  False
# 1                                  False
# 2                                  False
# ...

# %%
df_no_dupes = df.drop_duplicates(subset='url', keep='first').reset_index(drop=True)

# %%
df_no_dupes.shape
# Out:
# (3981, 5)

# %%
df.shape
# Out:
# (4031, 5)

# %%
us_e = pd.read_csv("/Users/ghadena/Desktop/geopol/data/raw/us_entites.csv")

# %%
df_full = pd.concat([df_no_dupes, us_e], ignore_index=True)

# %%
df_full.shape
# Out:
# (6265, 5)

# %%
# Step 1: Get all rows that are part of a duplicated URL group
dupes = df_full[df_full.duplicated(subset='url', keep=False)].copy()

# Step 2: Sort them by URL to make duplicates appear together
dupes_sorted = dupes.sort_values(by='url')

# Optional: Reset index for clean display
dupes_sorted.reset_index(drop=True, inplace=True)

# Show result
dupes_sorted.head()
# Out:
#                                                  url lang  \
# 0  https://www.aljazeera.com/news/2024/10/1/irans...  NaN
# 1  https://www.aljazeera.com/news/2024/10/1/irans...   en
# 2  https://www.aljazeera.com/news/2024/10/26/isra...  NaN
# 3  https://www.aljazeera.com/news/2024/10/26/isra...   en
# 4  https://www.aljazeera.com/news/2024/9/24/israe...  NaN
#
#                                   extracted_entities  \
# 0  {'people': ['Hassan Nasrallah', 'Abbas Nilforo...
# 1  {'people': ['Hassan Nasrallah', 'Abbas Nilforo...
# 2  {'people': ['Benjamin Netanyahu', 'Yoav Gallan...
# 3  {'people': ['Benjamin Netanyahu', 'Yoav Gallan...
# 4  {'people': [], 'institutions': ['Ministry of P...
#
#                                 entity_relationships  \
# 0  [{'source': 'Israel', 'target': 'Iran', 'relat...
# 1  [{'source': 'Israel', 'target': 'United States...
# 2  [{'source': 'Israel', 'target': 'Iran', 'relat...
# 3  [{'source': 'Israel', 'target': 'Iran', 'relat...
# ...

# %%
dupes_sorted.shape
# Out:
# (30, 5)

# %%
df_full_no_dupes = df_full.drop_duplicates(subset='url', keep='first').reset_index(drop=True)

# %%
df_full_no_dupes.shape
# Out:
# (6250, 5)

# %%
df_full_no_dupes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6250 entries, 0 to 6249
# Data columns (total 5 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   url                                     6250 non-null   object
#  1   lang                                    3981 non-null   object
#  2   extracted_entities                      6250 non-null   object
#  3   entity_relationships                    6250 non-null   object
#  4   relevant_to_german_or_french_elections  3527 non-null   object
# dtypes: object(5)
# memory usage: 244.3+ KB

# %%
df_full_no_dupes.to_csv("entites_n_relationships.csv")

# %%
redo2 = main("redo2.csv")
# Out:
# 📥 Loading data...
# 📁 Backup folder already exists: backups
# 🔁 Resuming. Skipping 47 already-processed rows.
# ...
#   3%|▎         | 16/512 [00:31<15:37,  1.89s/it]
# [RATE LIMIT] row 16 (https://www.reuters.com/markets/currencies/why-is-euro-falling-could-it-hit-1-2024-11-13/): 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash-8b"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# ...

# %%
redo2
# Out:
#                                                   url lang  \
# 0   https://www.nytimes.com/2024/09/12/us/politics...   en
# 1   https://www.nytimes.com/live/2024/09/09/us/har...   en
# 2   https://www.nytimes.com/2024/09/11/us/politics...   en
# 3                       https://www.nytimes.com/video   en
# 4   https://www.nytimes.com/2024/09/09/learning/sh...   en
# 5   https://www.nytimes.com/live/2024/09/12/us/har...   en
# 6   https://www.nytimes.com/2024/09/07/world/europ...   en
# 7   https://www.nytimes.com/2024/09/06/us/politics...   en
# 8   https://www.nytimes.com/2024/09/11/technology/...   en
# 9   https://www.nytimes.com/2024/09/11/us/politics...   en
# 10  https://www.nytimes.com/2024/09/05/business/ec...   en
# 11  https://www.nytimes.com/2024/09/11/us/politics...   en
# 12  https://www.nytimes.com/2024/09/12/technology/...   en
# 13  https://www.nytimes.com/2024/09/06/technology/...   en
# 14  https://www.nytimes.com/2024/09/07/us/politics...   en
# ...

# %%
redo.iloc[22].extracted_entities
# Out:
# {'people': [],
#  'institutions': ['Icom'],
#  'political_events': [],
#  'political_parties': [],
#  'locations': []}

# %%
redo.drop(columns = 'relevant_to_german_or_french_elections')
# Out:
#                                                   url lang  \
# 0   https://www.nytimes.com/2024/09/12/us/politics...   en
# 1   https://www.nytimes.com/live/2024/09/09/us/har...   en
# 2   https://www.nytimes.com/2024/09/11/us/politics...   en
# 3                       https://www.nytimes.com/video   en
# 4   https://www.nytimes.com/2024/09/09/learning/sh...   en
# 5   https://www.nytimes.com/live/2024/09/12/us/har...   en
# 6   https://www.nytimes.com/2024/09/07/world/europ...   en
# 7   https://www.nytimes.com/2024/09/06/us/politics...   en
# 8   https://www.nytimes.com/2024/09/11/technology/...   en
# 9   https://www.nytimes.com/2024/09/11/us/politics...   en
# 10  https://www.nytimes.com/2024/09/05/business/ec...   en
# 11  https://www.nytimes.com/2024/09/11/us/politics...   en
# 12  https://www.nytimes.com/2024/09/12/technology/...   en
# 13  https://www.nytimes.com/2024/09/06/technology/...   en
# 14  https://www.nytimes.com/2024/09/07/us/politics...   en
# ...

# %%
df_full2 = pd.concat([df_full_no_dupes, redo], ignore_index=True)
df_full2.to_csv("entites_n_relationships.csv")

# %%
texts
# Out:
#       Unnamed: 0                                                url  \
# 0            0.0  https://www.nytimes.com/2024/09/12/us/politics...
# 1            1.0  https://www.nytimes.com/live/2024/09/09/us/har...
# 2            2.0  https://www.nytimes.com/2024/09/11/us/politics...
# 3            3.0                      https://www.nytimes.com/video
# 4            4.0  https://www.nytimes.com/2024/09/09/learning/sh...
# ...          ...                                                ...
# 6582         NaN  https://www.france24.com/en/live-news/20250420...
# 6583         NaN  https://www.france24.com/en/live-news/20250411...
# 6584         NaN  https://www.france24.com/en/tv-shows/business/...
# 6585         NaN  https://www.france24.com/en/tv-shows/down-to-e...
# 6586         NaN  https://www.france24.com/en/live-news/20250416...
#
#                          datetime language  \
# 0                      2024-09-12       en
# 1                      2024-09-09       en
# ...

# %%
texts.is_relevant.value_counts(normalize=True)
# Out:
# is_relevant
# 0    0.821051
# 1    0.178949
# Name: proportion, dtype: Float64
