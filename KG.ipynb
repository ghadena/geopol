# %% [markdown]
# # set up

# %%
import pandas as pd 
df1 = pd.read_csv('df_featurized_us_french_no_entities.csv')

# %%
# Load both CSVs
csv1 = pd.read_csv("gemini_results_master.csv")
#csv2 = pd.read_csv("gemini_results_master2.csv")

# Concatenate them row-wise
combined_df = pd.concat([csv1], ignore_index=True)

# Optional: then merge with another df (if needed)
df = pd.merge(df1, combined_df, on="url", how="inner")

# %%
df.shape
# Out:
# (2289, 26)

# %%
df.columns
# Out:
# Index(['url', 'datetime', 'language', 'description', 'relevance_description',
#        'text', 'relevance_text', 'is_us_election', 'is_french_election',
#        'is_german_election', 'publisher', 'text_length', 'date', 'news_org',
#        'day_of_week', 'month', 'is_weekend', 'time_published',
#        'days_until_us_election', 'days_until_french_election', 'word_count',
#        'verb_count', 'mentions_election_keywords', 'article_type',
#        'extracted_entities', 'entity_relationships'],
#       dtype='object')

# %%
df.relevance_text.value_counts()
df = df.loc[df.relevance_text == 1]

# %%
df["entity_relationships"].apply(type).value_counts()
# Out:
# entity_relationships
# <class 'str'>    607
# Name: count, dtype: int64

# %%
# import ast

# def parse_relationships(x):
#     if isinstance(x, str) and x.strip().startswith("["):
#         try:
#             parsed = ast.literal_eval(x)
#             return parsed if isinstance(parsed, list) else []
#         except Exception:
#             return []
#     return []

# df["entity_relationships"] = df["entity_relationships"].apply(parse_relationships)

import ast

def parse(val, expected_type):
    if isinstance(val, str) and val.strip().startswith(("[" if expected_type == list else "{")):
        try:
            parsed = ast.literal_eval(val)
            return parsed if isinstance(parsed, expected_type) else expected_type()
        except Exception:
            return expected_type()
    return val if isinstance(val, expected_type) else expected_type()

# Parse both columns at once
df["entity_relationships"] = df["entity_relationships"].apply(lambda x: parse(x, list))
df["extracted_entities"] = df["extracted_entities"].apply(lambda x: parse(x, dict))

# %%
df
# Out:
#                                                     url    datetime language  \
# 1     https://www.nytimes.com/live/2024/09/09/us/har...  2024-09-09       en
# 2     https://www.nytimes.com/2024/09/11/us/politics...  2024-09-11       en
# 4     https://www.nytimes.com/live/2024/09/12/us/har...  2024-09-12       en
# 6     https://www.nytimes.com/2024/09/06/us/politics...  2024-09-06       en
# 8     https://www.nytimes.com/2024/09/11/us/politics...  2024-09-11       en
# ...                                                 ...         ...      ...
# 2216  https://www.politico.eu/article/ban-polls-uk-e...  2024-11-20       en
# 2218  https://www.politico.eu/article/angela-merkel-...  2024-11-20       en
# 2220  https://www.politico.eu/article/keir-starmer-l...  2024-11-22       en
# 2266  https://www.politico.eu/newsletter/politico-lo...  2024-11-21       en
# 2270  https://www.euronews.com/2024/11/19/the-result...  2024-11-19       en
#
#                                             description  \
# 1     As Donald J. Trump and Kamala Harris prepare f...
# 2     Within the first five minutes, Ms. Harris look...
# 4     Vice President Kamala Harris is said to have r...
# 6     The event will be Mr. Trump’s seventh time tak...
# 8     But since he left office, after lies of widesp...
# ...                                                 ...
# 2216  Ban the polls: UK election strategists slam ‘i...
# 2218  Merkel eviscerates ‘emotional’ Trump in upcomi...
# 2220  After voting, Starmer arrived in the office an...
# 2266  QUICK HITS. WIPA CYMRU LAUNCH: Women in Public...
# 2270  Water Matters. Europe's water is under increas...
#
#       relevance_description  \
# 1                       1.0
# 2                       1.0
# 4                       1.0
# 6                       1.0
# 8                       1.0
# ...                     ...
# 2216                    NaN
# 2218                    NaN
# 2220                    NaN
# 2266                    NaN
# 2270                    NaN
#
#                                                    text  relevance_text  \
# 1     Donald J. Trump’s history of being physically ...             1.0
# 2     Ms. Harris strode across the room to deliver t...             1.0
# 4     “We want to move forward together, and it just...             1.0
# 6     For eight years, Donald J. Trump has singularl...             1.0
# 8     For most of the 90-minute debate between forme...             1.0
# ...                                                 ...             ...
# 2216  Some industry professionals agree that politic...             1.0
# 2218  “He judged everything from the perspective of ...             1.0
# 2220  After voting, Starmer arrived in the office an...             1.0
# 2266  Presented by Meta By JOHN JOHNSTON Tips, gossi...             1.0
# 2270  By Balázs Orbán, political director for Hungar...             1.0
#
#       is_us_election  is_french_election  is_german_election  ... is_weekend  \
# 1                  1                   0                   0  ...      False
# 2                  1                   0                   0  ...      False
# 4                  1                   0                   0  ...      False
# 6                  1                   0                   0  ...      False
# 8                  1                   0                   0  ...      False
# ...              ...                 ...                 ...  ...        ...
# 2216               1                   0                   0  ...      False
# 2218               1                   0                   0  ...      False
# 2220               1                   0                   0  ...      False
# 2266               1                   0                   0  ...      False
# 2270               1                   0                   0  ...      False
#
#       time_published days_until_us_election days_until_french_election  \
# 1           00:00:00                     57                        -64
# 2           00:00:00                     55                        -66
# 4           00:00:00                     54                        -67
# 6           00:00:00                     60                        -61
# 8           00:00:00                     55                        -66
# ...              ...                    ...                        ...
# 2216        00:00:00                    -15                       -136
# 2218        00:00:00                    -15                       -136
# 2220        00:00:00                    -17                       -138
# 2266        00:00:00                    -16                       -137
# 2270        00:00:00                    -14                       -135
#
#      word_count  verb_count  mentions_election_keywords article_type  \
# 1          2588         360                        True    interview
# 2           214          37                        True        other
# 4          1211         176                        True    interview
# 6           168          15                        True        other
# 8           204          36                        True        other
# ...         ...         ...                         ...          ...
# 2216        279          31                        True    interview
# 2218        272          36                       False        other
# 2220        245          32                        True        other
# 2266       2059         268                        True     analysis
# 2270       1349         151                        True        other
#
#                                      extracted_entities  \
# 1     {'people': ['Donald J. Trump', 'Kamala Harris'...
# 2     {'people': ['Kamala Harris', 'Mr. Trump', 'Dav...
# 4     {'people': ['Rob Rue', 'Donald J. Trump', 'JD ...
# 6     {'people': ['Donald J. Trump', 'Kamala Harris'...
# 8     {'people': ['Donald J. Trump', 'Kamala Harris'...
# ...                                                 ...
# 2216  {'people': ['Donald Trump', 'Rishi Sunak', 'Bo...
# 2218  {'people': ['Trump', 'Merkel', 'Pope Francis',...
# 2220  {'people': ['Starmer', 'Sue Gray', 'Matthew Do...
# 2266  {'people': ['JOHN JOHNSTON', 'Ed Bearryman', '...
# 2270  {'people': ['Balázs Orbán', 'Viktor Orbán', 'D...
#
#                                    entity_relationships
# 1     [{'source': 'Donald J. Trump', 'target': 'wome...
# 2     [{'source': 'Kamala Harris', 'target': 'Mr. Tr...
# 4     [{'source': 'Rob Rue', 'target': 'Springfield'...
# 6     [{'source': 'Donald J. Trump', 'target': 'Kama...
# 8     [{'source': 'Donald J. Trump', 'target': 'Kama...
# ...                                                 ...
# 2216  [{'source': 'Rishi Sunak', 'target': 'Conserva...
# 2218  [{'source': 'Merkel', 'target': 'Trump', 'rela...
# 2220  [{'source': 'Starmer', 'target': 'Sue Gray', '...
# 2266  [{'source': 'Meta', 'target': 'Instagram', 're...
# 2270  [{'source': 'Balázs Orbán', 'target': 'Viktor ...
#
# [607 rows x 26 columns]

# %%
df_graph = df.loc[
    df["entity_relationships"].apply(lambda x: isinstance(x, list) and len(x) > 0) &
    df["extracted_entities"].apply(lambda x: isinstance(x, dict) and len(x) > 0),
    ["url", "date", "entity_relationships", "extracted_entities"]
].copy()

# %%
df_graph.shape
# Out:
# (556, 4)

# %%
df_graph = df_graph.dropna(subset=["entity_relationships", "extracted_entities"])
df_graph = df_graph.drop_duplicates(subset=["url", "date"])
df_graph.shape
# Out:
# (556, 4)

# %%
records = []

for _, row in df_graph.iterrows():
    url = row["url"]
    date = row["date"]
    relationships = row["entity_relationships"]

    if isinstance(relationships, list):
        for rel in relationships:
            if all(k in rel for k in ["source", "target", "relationship", "sentiment"]):
                records.append({
                    "source": rel["source"],
                    "target": rel["target"],
                    "relationship": rel["relationship"],
                    "sentiment": rel["sentiment"],
                    "url": url,
                    "date": date
                })

edges_df = pd.DataFrame(records)
print(f"✅ Created edges_df with {len(edges_df)} rows.")
# Out:
# ✅ Created edges_df with 4349 rows.

# %%
print(edges_df["relationship"].value_counts(normalize = True))
print(edges_df["sentiment"].value_counts(normalize = True))
# Out:
# relationship
# supports                          0.280294
# opposes                           0.223730
# criticizes                        0.202345
# partners with                     0.091745
# accuses                           0.045298
#                                     ...
# secures                           0.000230
# will meet                         0.000230
# gathers information on            0.000230
# interviewed                       0.000230
# was keen to get her opinion on    0.000230
# Name: proportion, Length: 99, dtype: float64
# sentiment
# NEUTRAL     0.516441
# HOSTILE     0.359163
# FRIENDLY    0.124396
# Name: proportion, dtype: float64

# %%
ents = []

for _, row in df_graph.iterrows():
    url = row["url"]
    date = row["date"]
    entities = row["extracted_entities"]

    if not isinstance(entities, dict) or not entities:
        continue

    for ent_type, names in entities.items():
        if not isinstance(names, list):
            continue
        for name in names:
            ents.append({
                "url": url,
                "date": date,
                "entity": name,
                "entity_type": ent_type
            })

ents_long = pd.DataFrame(ents)
print(f"✅ Created ents_long with {len(ents_long)} rows.")
# Out:
# ✅ Created ents_long with 15409 rows.

# %%
ents_long.columns
# Out:
# Index(['url', 'date', 'entity', 'entity_type'], dtype='object')

# %% [markdown]
# # graph

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import community.community_louvain as community_louvain  
#import community as community_louvain# pip install python-louvain
import numpy as np
from scipy.spatial import ConvexHull            # pip install scipy

# ─── 1. ASSUME edges_df & ents_long EXIST ───────────────────────────────────────
# edges_df columns: source, target, url, date (datetime), sentiment, source_type
# ents_long columns: url, date, entity, entity_type

# If your date column is still string, uncomment:
# edges_df['date'] = pd.to_datetime(edges_df['date'])

# ─── 2. BUILD WEIGHTED GRAPH FOR METRICS & CLUSTERING ────────────────────────────
# We'll ignore direction & sentiment here—just weight by co‐occurrence counts.
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _,r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# ─── 3. COMPUTE CENTRALITIES & COMMUNITIES ──────────────────────────────────────
deg_cent  = nx.degree_centrality(G)
pr        = nx.pagerank(G)
betw_cent = nx.betweenness_centrality(G, normalized=True)
partition = community_louvain.best_partition(G)

# ─── 4. LAYOUT & HULLS ───────────────────────────────────────────────────────────
pos = nx.spring_layout(G, k=0.15, iterations=20)

# Build convex‑hull shapes for each community
hull_shapes = []
for comm in set(partition.values()):
    members = [n for n,p in partition.items() if p==comm]
    if len(members) < 3: 
        continue
    pts = np.array([pos[n] for n in members])
    hull = ConvexHull(pts)
    path = "M " + " L ".join(f"{pts[v,0]},{pts[v,1]}" for v in hull.vertices) + " Z"
    hull_shapes.append(dict(
        type="path", path=path,
        fillcolor="rgba(200,200,200,0.15)", line=dict(width=0)
    ))

# ─── 5. SELECTIVE LABELS ─────────────────────────────────────────────────────────
# Top 10% by degree get fixed labels
deg_vals = np.array(list(deg_cent.values()))
thresh = np.percentile(deg_vals, 90)
label_nodes = {n for n,v in deg_cent.items() if v >= thresh}

# ─── 6. BUILD TRACES ─────────────────────────────────────────────────────────────
# 6A) Edge traces: one per sentiment + an “All”
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
edge_traces = []
color_map = {"positive":"green","negative":"red","neutral":"gray"}

for s in ["All"] + sentiments:
    xs, ys = [], []
    for u,v,d in G.edges(data=True):
        # pick “dominant” sentiment on that edge
        se = edges_df[
            (edges_df.source==u)&(edges_df.target==v)
        ]['sentiment'].mode()
        sent = se.iloc[0] if not se.empty else "neutral"
        if s!="All" and sent!=s:
            continue
        x0,y0 = pos[u]; x1,y1 = pos[v]
        xs += [x0,x1,None]; ys += [y0,y1,None]
    edge_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="lines",
            line=dict(color=color_map.get(s,"#888"), width=1),
            hoverinfo="none",
            visible=(s=="All"),
            name=(s if s!="All" else "All Sentiments")
        )
    )

# 6B) Node traces: one per entity type + an “All”
types = sorted(ents_long['entity_type'].unique().tolist())
type_colors = {"people":"blue","organizations":"orange","locations":"green","unknown":"gray"}

node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, cdata = [], [], [], [], []
    for n in G.nodes():
        et = ents_long.loc[ents_long.entity==n, "entity_type"]
        et0 = et.iloc[0] if not et.empty else "unknown"
        if t!="All" and et0!=t: 
            continue
        x,y = pos[n]
        xs.append(x); ys.append(y)
        txt.append(n if n in label_nodes else "")
        col.append(type_colors.get(et0,"gray"))
        cdata.append([et0, deg_cent[n], pr[n]])
    node_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="markers+text",
            text=txt, textposition="top center",
            marker=dict(size=10, color=col),
            customdata=cdata,
            hovertemplate=(
                "<b>%{text}</b><br>"
                "Type: %{customdata[0]}<br>"
                "Degree: %{customdata[1]:.3f}<br>"
                "PageRank: %{customdata[2]:.4f}<extra></extra>"
            ),
            visible=(t=="All"),
            name=(t if t!="All" else "All Types")
        )
    )

# ─── 7. ASSEMBLE FIGURE ──────────────────────────────────────────────────────────
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="Knowledge Graph Explorer",
        shapes=hull_shapes,
        hovermode="closest",
        legend=dict(itemsizing="constant"),
        margin=dict(l=20,r=20,b=20,t=40)
    )
)

# ─── 8. UPDATEMENUS FOR FILTERS ─────────────────────────────────────────────────
# Sentiment dropdown (single-select)
fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(label="All Sentiments",
                     method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title":"All Sentiments"}]),
                *[
                    dict(label=s.title(),
                         method="update",
                         args=[{"visible":[i==(idx+1) for i in range(len(edge_traces))] + [True]*len(node_traces)},
                               {"title":f"Sentiment: {s.title()}"}])
                    for idx,s in enumerate(sentiments)
                ]
            ],
            direction="down", x=0, y=1.15, showactive=True
        ),
        # Entity‑type dropdown
        dict(
            buttons=[
                dict(label="All Types",
                     method="update",
                     args=[{"visible":[True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title":"All Entity Types"}]),
                *[
                    dict(label=t.title(),
                         method="update",
                         args=[{"visible":[True]*len(edge_traces) + 
                                    [i==(idx+1) for i in range(len(node_traces))]},
                               {"title":f"Entity Type: {t.title()}"}])
                    for idx,t in enumerate(types)
                ]
            ],
            direction="down", x=0.25, y=1.15, showactive=True
        )
    ]
)

fig.show()

# ─── 9. PRINT TOP 5 BROKERS BY BETWEENNESS ───────────────────────────────────────
metrics = pd.DataFrame({
    "entity":       list(deg_cent.keys()),
    "degree":       list(deg_cent.values()),
    "pagerank":     [pr[n] for n in G.nodes()],
    "betweenness":  [betw_cent[n] for n in G.nodes()]
})
print("\nTop 5 brokers by betweenness:")
display(metrics.sort_values("betweenness", ascending=False).head(5))
# Out:
# Top 5 brokers by betweenness:
#             entity    degree  pagerank  betweenness
# 9     Donald Trump  0.413928  0.151125     0.598204
# 21   Kamala Harris  0.125348  0.044922     0.118534
# 1            Trump  0.090808  0.022917     0.079799
# 363      Elon Musk  0.028969  0.009920     0.038611
# 117      Joe Biden  0.055153  0.019651     0.033670

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import community.community_louvain as community_louvain
import numpy as np
from scipy.spatial import ConvexHull

# --- 1. Prepare data ---
ew = edges_df.groupby(['source', 'target']).size().reset_index(name='weight')
G = nx.Graph()
for _, r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# Optional: Filter nodes with low degree
G = G.subgraph([n for n, d in G.degree() if d > 2]).copy()

# --- 2. Compute graph metrics ---
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
betw_cent = nx.betweenness_centrality(G, normalized=True)
partition = community_louvain.best_partition(G)

# --- 3. Layout and community hulls ---
pos = nx.spring_layout(G, k=0.4, iterations=50)

hull_shapes = []
for comm in set(partition.values()):
    members = [n for n, p in partition.items() if p == comm]
    if len(members) < 3:
        continue
    pts = np.array([pos[n] for n in members])
    hull = ConvexHull(pts)
    path = "M " + " L ".join(f"{pts[v,0]},{pts[v,1]}" for v in hull.vertices) + " Z"
    hull_shapes.append(dict(
        type="path", path=path,
        fillcolor="rgba(200,200,200,0.15)", line=dict(width=0)
    ))

# --- 4. Label only most important nodes ---
thresh = np.percentile(list(deg_cent.values()), 97)
label_nodes = {n for n, v in deg_cent.items() if v >= thresh}

# --- 5A. Edge traces ---
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
edge_traces = []
color_map = {"positive": "green", "negative": "red", "neutral": "gray"}

for s in ["All"] + sentiments:
    xs, ys = [], []
    for u, v, d in G.edges(data=True):
        se = edges_df[
            (edges_df.source == u) & (edges_df.target == v)
        ]['sentiment'].mode()
        sent = se.iloc[0] if not se.empty else "neutral"
        if s != "All" and sent != s:
            continue
        x0, y0 = pos[u]; x1, y1 = pos[v]
        xs += [x0, x1, None]; ys += [y0, y1, None]
    edge_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="lines",
            line=dict(color=color_map.get(s, "#888"), width=1),
            hoverinfo="none",
            visible=(s == "All"),
            name=(s if s != "All" else "All Sentiments")
        )
    )

# --- 5B. Node traces ---
types = sorted(ents_long['entity_type'].unique().tolist())
type_colors = {"people": "blue", "organizations": "orange", "locations": "green", "unknown": "gray"}

node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, cdata = [], [], [], [], []
    for n in G.nodes():
        et = ents_long.loc[ents_long.entity == n, "entity_type"]
        et0 = et.iloc[0] if not et.empty else "unknown"
        if t != "All" and et0 != t:
            continue
        x, y = pos[n]
        xs.append(x); ys.append(y)
        txt.append(n if n in label_nodes else "")
        col.append(type_colors.get(et0, "gray"))
        cdata.append([et0, deg_cent[n], pr[n]])
    node_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="markers+text",
            text=txt, textposition="top center",
            marker=dict(size=6, color=col),
            customdata=cdata,
            hovertemplate=(
                "<b>%{text}</b><br>"
                "Type: %{customdata[0]}<br>"
                "Degree: %{customdata[1]:.3f}<br>"
                "PageRank: %{customdata[2]:.4f}<extra></extra>"
            ),
            visible=(t == "All"),
            name=(t if t != "All" else "All Types")
        )
    )

# --- 6. Assemble and show figure ---
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="Knowledge Graph Explorer",
        shapes=hull_shapes,
        hovermode="closest",
        legend=dict(itemsizing="constant"),
        margin=dict(l=20, r=20, b=20, t=40)
    )
)

fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(label="All Sentiments",
                     method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Sentiments"}]),
                *[
                    dict(label=s.title(),
                         method="update",
                         args=[{"visible": [i == (idx + 1) for i in range(len(edge_traces))] + [True]*len(node_traces)},
                               {"title": f"Sentiment: {s.title()}"}])
                    for idx, s in enumerate(sentiments)
                ]
            ],
            direction="down", x=0, y=1.15, showactive=True
        ),
        dict(
            buttons=[
                dict(label="All Types",
                     method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Entity Types"}]),
                *[
                    dict(label=t.title(),
                         method="update",
                         args=[{"visible": [True]*len(edge_traces) + 
                                    [i == (idx + 1) for i in range(len(node_traces))]},
                               {"title": f"Entity Type: {t.title()}"}])
                    for idx, t in enumerate(types)
                ]
            ],
            direction="down", x=0.25, y=1.15, showactive=True
        )
    ]
)

fig.show()

# --- 7. Print top brokers ---
metrics = pd.DataFrame({
    "entity": list(deg_cent.keys()),
    "degree": list(deg_cent.values()),
    "pagerank": [pr[n] for n in G.nodes()],
    "betweenness": [betw_cent[n] for n in G.nodes()]
})
print("\nTop 5 brokers by betweenness:")
display(metrics.sort_values("betweenness", ascending=False).head(5))
# Out:
# Top 5 brokers by betweenness:
#             entity    degree  pagerank  betweenness
# 282   Donald Trump  0.707602  0.170101     0.661879
# 89   Kamala Harris  0.321637  0.066263     0.107267
# 201          Trump  0.277778  0.033769     0.094263
# 147      Joe Biden  0.225146  0.037244     0.037754
# 181      Elon Musk  0.076023  0.013338     0.027518

# %% [markdown]
# ## cleaning the edges_df
# dealing with entity resolutions, duplicates, conflicting sentiment and relationships
# - using langchian to explain the conflicts and resolve entities

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def normalize_title(name):
    return re.sub(r"\b(Mr|Ms|Mrs|Dr|Prof|President|Chancellor|Prime Minister)\.?\s+", "", name).strip()


# 1. Extract all unique entity names
unique_entities = pd.Series(pd.concat([edges_df["source"], edges_df["target"], ents_long["entity"]])).dropna().unique().tolist()
unique_entities = [normalize_title(n) for n in unique_entities]

# 2. Load model & generate embeddings
#model = SentenceTransformer("all-MiniLM-L6-v2")
model = SentenceTransformer("all-roberta-large-v1")
embeddings = model.encode(unique_entities)

# 3. Compute cosine similarity
cos_sim = cosine_similarity(embeddings)

# 4. Group similar entities (threshold ~0.88 is good for names)
threshold = 0.88
visited = set()
clusters = {}

for i, name in enumerate(unique_entities):
    if name in visited:
        continue
    cluster = [name]
    for j in range(i + 1, len(unique_entities)):
        if cos_sim[i][j] > threshold:
            cluster.append(unique_entities[j])
            visited.add(unique_entities[j])
    clusters[name] = cluster
    visited.update(cluster)

manual_resolutions = {
    "Zelenskyy": "Volodymyr Zelensky",
    "Vladimir Zelensky": "Volodymyr Zelensky",
    "Donald J. Trump": "Donald Trump",
    "Donald J Trump": "Donald Trump",
    "Donald Trump": "Donald Trump",
    "Trump": "Donald Trump",
    "Biden": "Joe Biden",
    "Musk": "Elon Musk",
    "Harris": "Kamala Harris",
    "House Republicans": "Republican Party",
    "Republicans": "Republican Party",
    "House Democrats": "Democratic Party",
    "Democrats": "Democratic Party",

    # Kennedy corrections
    "Robert F. Kennedy Jr.": "Robert F. Kennedy Jr.",
    "Robert F Kennedy Jr": "Robert F. Kennedy Jr.",
    "Robert Kennedy Jr": "Robert F. Kennedy Jr.",
    "Robert F. Kennedy, Jr.": "Robert F. Kennedy Jr.",
    "Robert F. Kennedy": "Robert F. Kennedy",  # keep Sr separate

    "John F. Kennedy": "John F. Kennedy",
    "John F Kennedy": "John F. Kennedy",
}

# 5. Create resolution map
resolution_map = {alias: canon for canon, aliases in clusters.items() for alias in aliases}
resolution_map.update(manual_resolutions)
resolution_map
# Out:
# {'Donald J. Trump': 'Donald Trump',
#  'Donald Trump': 'Donald Trump',
#  'Donald J Trump': 'Donald Trump',
#  'Karoline Leavitt': 'Karoline Leavitt',
#  'Hillary Clinton': 'Hillary Clinton',
#  'Hilary Clinton': 'Hillary Clinton',
#  'Carly Fiorina': 'Carly Fiorina',
#  'Kamala Harris': 'Kamala Harris',
#  'Trump': 'Donald Trump',
#  'Rob Rue': 'Rob Rue',
#  'JD Vance': 'JD Vance',
#  'Nathan Clark': 'Nathan Clark',
#  'Ted Cruz': 'Ted Cruz',
#  'Elon Musk': 'Elon Musk',
#  'Mike DeWine': 'Mike DeWine',
#  'Vilés Dorsainvil': 'Vilés Dorsainvil',
#  'Luke Schroeder': 'Luke Schroeder',
#  'National Justice Party': 'National Justice Party',
#  'The Post Millennial': 'The Post Millennial',
#  'Blaze Media': 'Blaze Media',
#  'Biden': 'Joe Biden',
#  'Charlie Kirk': 'Charlie Kirk',
#  'Harris': 'Kamala Harris',
#  'Joe Biden': 'Joe Biden',
#  'Joseph R. Biden Jr.': 'Joe Biden',
#  'Joseph R Biden Jr.': 'Joe Biden',
#  'Mitt Romney': 'Mitt Romney',
#  'Bill Clinton': 'Bill Clinton',
#  'Taylor Swift': 'Taylor Swift',
#  'Robert F. Kennedy Jr.': 'Robert F. Kennedy Jr.',
#  'John Kennedy': 'Robert F. Kennedy Jr.',
#  'John F. Kennedy': 'John F. Kennedy',
#  'Robert F Kennedy Jr': 'Robert F. Kennedy Jr.',
#  'John F Kennedy': 'John F. Kennedy',
#  'Robert Kennedy Jr': 'Robert F. Kennedy Jr.',
#  'Robert F. Kennedy, Jr.': 'Robert F. Kennedy Jr.',
#  'Robert F. Kennedy': 'Robert F. Kennedy',
#  'Robert Kennedy Sr': 'Robert F. Kennedy Jr.',
#  'Brian Nelson': 'Brian Nelson',
#  'Brian Hughes': 'Brian Hughes',
#  'Republicans': 'Republican Party',
#  'Trump campaign': 'Trump campaign',
#  'Tulsi Gabbard': 'Tulsi Gabbard',
#  'Gabbard': 'Tulsi Gabbard',
#  'Anthony Scaramucci': 'Anthony Scaramucci',
#  'Olivia Troye': 'Olivia Troye',
#  'Reshma Saujani': 'Reshma Saujani',
#  'Mike Coffman': 'Mike Coffman',
#  'Aurora': 'Aurora',
#  'Danilo': 'Danilo',
#  'Óscar Naranjo': 'Óscar Naranjo',
#  'Dave Perry': 'Dave Perry',
#  'Donald Harris': 'Donald Harris',
#  'David Muir': 'David Muir',
#  'John Kirby': 'John Kirby',
#  'Ron DeSantis': 'Ron DeSantis',
#  'DeSantis': 'Ron DeSantis',
#  'Gov. Ron DeSantis': 'Ron DeSantis',
#  'RT': 'RT',
#  'Tenet Media': 'Tenet Media',
#  'Tim Pool': 'Tim Pool',
#  'Dave Rubin': 'Dave Rubin',
#  'David Rubin': 'James Rubin',
#  'Mitch McConnell': 'Mitch McConnell',
#  'Tayler Hansen': 'Tayler Hansen',
#  'Jeffrey Clark': 'Jeffrey Clark',
#  'Mike Davis': 'Mike Davis',
#  'Gene Hamilton': 'Gene Hamilton',
#  'Elizabeth Warren': 'Elizabeth Warren',
#  'Katie Britt': 'Katie Britt',
#  'Republican': 'Republican',
#  'Marjorie Taylor Greene': 'Marjorie Taylor Greene',
#  'Marjorie Taylor Green': 'Marjorie Taylor Greene',
#  'Viktor Orbán': 'Viktor Orbán',
#  'Viktor Orban': 'Viktor Orbán',
#  'Vladimir Putin': 'Vladimir Putin',
#  'Vladimir V. Putin': 'Vladimir Putin',
#  'Yusef Salaam': 'Yusef Salaam',
#  'Raymond Santana': 'Raymond Santana',
#  'Kevin Richardson': 'Kevin Richardson',
#  'Antron Brown': 'Antron Brown',
#  'Korey Wise': 'Korey Wise',
#  'Russia': 'Russia',
#  'Kostiantyn Kalashnikov': 'Kostiantyn Kalashnikov',
#  'Konstantin Kalashnikov': 'Kostiantyn Kalashnikov',
#  'Elena Afanasyeva': 'Elena Afanasyeva',
#  'Merrick Garland': 'Merrick Garland',
#  'Lauren Chen': 'Lauren Chen',
#  'Natasha Chen': 'Lauren Chen',
#  'Liam Donovan': 'Liam Donovan',
#  'NPR': 'NPR',
#  'NPR News': 'NPR',
#  'Democrats': 'Democratic Party',
#  'Project 2025': 'Project 2025',
#  'Laura Loomer': 'Laura Loomer',
#  'Lindsey Graham': 'Lindsey Graham',
#  'Thom Tillis': 'Thom Tillis',
#  'Glenda Bailey': 'Glenda Bailey',
#  'Republican Party': 'Republican Party',
#  'Republican party': 'Republican Party',
#  'Williams': 'Williams',
#  'Ossoff': 'Ossoff',
#  'Jon Ossoff': 'Ossoff',
#  'Anderson': 'Anderson',
#  'Federal Reserve': 'Federal Reserve',
#  'US Federal Reserve': 'Federal Reserve',
#  'U.S. Federal Reserve': 'Federal Reserve',
#  'Jerome Powell': 'Jerome Powell',
#  'Adam Green': 'Adam Green',
#  'Jeremy Petersen': 'Jeremy Petersen',
#  'Putin': 'Putin',
#  'John Kerry': 'John Kerry',
#  'John F. Kerry': 'John Kerry',
#  'US': 'US',
#  'United States': 'US',
#  'U.S.': 'US',
#  'USA': 'US',
#  'Dick Cheney': 'Dick Cheney',
#  'Barack Obama': 'Barack Obama',
#  'Obama': 'Barack Obama',
#  'Lourene': 'Lourene',
#  'Lindy Criddle': 'Lindy Criddle',
#  'Theresa Locklear': 'Theresa Locklear',
#  'Katherine Tai': 'Katherine Tai',
#  'Wang Wenbin': 'Wang Wenbin',
#  'Jimmy Carter': 'Jimmy Carter',
#  'Department of Education': 'Department of Education',
#  'U.S. Department of Education': 'Department of Education',
#  'Dept. of Education': 'Department of Education',
#  'Education Department': 'Department of Education',
#  'Department for Education': 'Department of Education',
#  'US Department of Education (DOE)': 'Department of Education',
#  'The Commonwealth Fund': 'The Commonwealth Fund',
#  'Commonwealth Fund': 'The Commonwealth Fund',
#  'Australia': 'Australia',
#  'Netherlands': 'Netherlands',
#  'Joseph Betancourt': 'Joseph Betancourt',
#  'David Blumenthal': 'David Blumenthal',
#  'Georges Benjamin': 'Georges Benjamin',
#  'Ryan Wesley Routh': 'Ryan Wesley Routh',
#  'Ryan Routh': 'Ryan Wesley Routh',
#  'International Brotherhood of Teamsters': 'International Brotherhood of Teamsters',
#  'Sean O’Brien': 'Sean O’Brien',
#  "Sean O'Brien": 'Sean O’Brien',
#  'James “Curb” Curbeam': 'James “Curb” Curbeam',
#  'Tim Walz': 'Tim Walz',
#  'Justice Department': 'Justice Department',
#  'US Department of Justice': 'Justice Department',
#  'Department of Justice': 'Justice Department',
#  'U.S. Department of Justice': 'Justice Department',
#  'Departments of Justice': 'Justice Department',
#  'US Justice Department': 'Justice Department',
#  'Robert Mueller': 'Robert Mueller',
#  'Ben Shapiro': 'Ben Shapiro',
#  'Bob Shrum': 'Bob Shrum',
#  'Tad Devine': 'Tad Devine',
#  'William Frey': 'William Frey',
#  'Ben Wikler': 'Ben Wikler',
#  'Pete Giangreco': 'Pete Giangreco',
#  'Gene Ulm': 'Gene Ulm',
#  'Branden Snyder': 'Branden Snyder',
#  'Dante Chinni': 'Dante Chinni',
#  'Patrick Ruffini': 'Patrick Ruffini',
#  'Geoff Garin': 'Geoff Garin',
#  'Jay Powell': 'Jay Powell',
#  'Republican National Committee': 'Republican National Committee',
#  'League of United Latin American Citizens (LULAC)': 'League of United Latin American Citizens (LULAC)',
#  'League of United Latin American Citizens': 'League of United Latin American Citizens (LULAC)',
#  'Juan Proaño': 'Juan Proaño',
#  'Hakeem Jeffries': 'Hakeem Jeffries',
#  'Steve Witkoff': 'Steve Witkoff',
#  'Steven Witkoff': 'Steve Witkoff',
#  'Gary Gensler': 'Gary Gensler',
#  'World Liberty Financial': 'World Liberty Financial',
#  'Al Gore': 'Al Gore',
#  'James P. Hoffa': 'James P. Hoffa',
#  'Mike Johnson': 'Mike Johnson',
#  'Mike Rogers': 'Mike Rogers',
#  'Chuck Schumer': 'Chuck Schumer',
#  'Tom Cole': 'Tom Cole',
#  'Thomas Cole': 'Tom Cole',
#  'Rosa DeLauro': 'Rosa DeLauro',
#  'Marc Short': 'Marc Short',
#  'STEVE INSKEEP': 'STEVE INSKEEP',
#  'Susanne Craig': 'Susanne Craig',
#  'Russ Buettner': 'Russ Buettner',
#  'Fred Trump': 'Fred Trump',
#  'The New York Times': 'The New York Times',
#  'New York Times': 'The New York Times',
#  'Colin Clarke': 'Colin Clarke',
#  'Gary LaFree': 'Gary LaFree',
#  'Björn Höcke': 'Björn Höcke',
#  'Alternative for Germany': 'Alternative for Germany',
#  'Zelenskyy': 'Volodymyr Zelensky',
#  'Zelensky': 'Zelenskyy',
#  'Keir Starmer': 'Keir Starmer',
#  'Labour': 'Labour',
#  'Tories': 'Tories',
#  'Ed Davey': 'Ed Davey',
#  'John Swinney': 'John Swinney',
#  'Anas Sarwar': 'Anas Sarwar',
#  'John Healey': 'John Healey',
#  'David Lammy': 'David Lammy',
#  'Kemi Badenoch': 'Kemi Badenoch',
#  'Robert Jenrick': 'Robert Jenrick',
#  'James Cleverly': 'James Cleverly',
#  'John Major': 'John Major',
#  'Lisa Nandy': 'Lisa Nandy',
#  'Peter Mandelson': 'Peter Mandelson',
#  'Tom Tugendhat': 'Tom Tugendhat',
#  'Jess Phillips': 'Jess Phillips',
#  'Vladimir Kara-Murza': 'Vladimir Kara-Murza',
#  'Ursula von der Leyen': 'Ursula von der Leyen',
#  'Janez Janša': 'Janez Janša',
#  'Daniel Freund': 'Daniel Freund',
#  'Kyriakos Mitsotakis': 'Kyriakos Mitsotakis',
#  'Olaf Scholz': 'Olaf Scholz',
#  'Nuno Melo': 'Nuno Melo',
#  'Neil M. Gorsuch': 'Neil M. Gorsuch',
#  'Neil Gorsuch': 'Neil M. Gorsuch',
#  'Simon Rosenberg': 'Simon Rosenberg',
#  'Marelee Ernestberg': 'Marelee Ernestberg',
#  'New York attorney general’s office': 'New York attorney general’s office',
#  'Arthur Engoron': 'Arthur Engoron',
#  'Donald Trump Jr.': 'Donald Trump Jr.',
#  'Donald Trump Jr': 'Donald Trump Jr.',
#  'Eric Trump': 'Eric Trump',
#  'Letitia James': 'Letitia James',
#  'John Sauer': 'John Sauer',
#  'Volodymyr Zelensky': 'Volodymyr Zelensky',
#  'Volodymyr Zelenskyy': 'Volodymyr Zelensky',
#  'Volodymr Zelenskyy': 'Volodymyr Zelensky',
#  'Volodymyr Zelenskiy': 'Volodymyr Zelensky',
#  'Volodymyr Zelynsky': 'Volodymyr Zelensky',
#  'Chris Murphy': 'Chris Murphy',
#  'James Lankford': 'James Lankford',
#  'ICE': 'ICE',
#  'P.J. Lechleitner': 'P.J. Lechleitner',
#  'Tony Gonzales': 'Tony Gonzales',
#  'Jeff Horwitt': 'Jeff Horwitt',
#  'Bill McInturff': 'Bill McInturff',
#  'Karine Jean-Pierre': 'Karine Jean-Pierre',
#  'Adams': 'Adams',
#  'Diane Hendricks': 'Diane Hendricks',
#  'Howard Lutnick': 'Howard Lutnick',
#  'Paul Singer': 'Paul Singer',
#  'Annette Caldwell Simmons': 'Annette Caldwell Simmons',
#  'Warren Stephens': 'Warren Stephens',
#  'Dustin Moskovitz': 'Dustin Moskovitz',
#  'Reed Hastings': 'Reed Hastings',
#  'Jeff Lawson': 'Jeff Lawson',
#  'Erica Lawson': 'Erica Lawson',
#  'Jeff Yass': 'Jeff Yass',
#  'Richard Uihlein': 'Richard Uihlein',
#  'Amos Hostetter Jr.': 'Amos Hostetter Jr.',
#  'Jared Golden': 'Jared Golden',
#  'Rand Paul': 'Rand Paul',
#  'Hasan Piker': 'Hasan Piker',
#  'Cenk Uygar': 'Cenk Uygar',
#  'Matthew D. Taylor': 'Matthew D. Taylor',
#  'Paula White-Cain': 'Paula White-Cain',
#  'evangelicals': 'evangelicals',
#  'Steve Bannon': 'Steve Bannon',
#  'Doug Mastriano': 'Doug Mastriano',
#  'Wes Allen': 'Wes Allen',
#  'Antony Blinken': 'Antony Blinken',
#  'Anthony Blinken': 'Antony Blinken',
#  'Nina Jankowicz': 'Nina Jankowicz',
#  'Liz Wahl': 'Liz Wahl',
#  'Margarita Simonyan': 'Margarita Simonyan',
#  'James Rubin': 'James Rubin',
#  'Iran': 'Iran',
#  'Johnson': 'Johnson',
#  'Chip Roy': 'Chip Roy',
#  'Camille': 'Camille',
#  'Wild Mother': 'Wild Mother',
#  'Frans Timmermans': 'Frans Timmermans',
#  'Margrethe Vestager': 'Margrethe Vestager',
#  'Sadiq Khan': 'Sadiq Khan',
#  'Bruno Retailleau': 'Bruno Retailleau',
#  'Gérald Darmanin': 'Gérald Darmanin',
#  'Albin Kurti': 'Albin Kurti',
#  'Recep Tayyip Erdoğan': 'Recep Tayyip Erdoğan',
#  'Recep Tayyip Erdogan': 'Recep Tayyip Erdoğan',
#  'Musk': 'Elon Musk',
#  'Meloni': 'Meloni',
#  'Josep Borrell': 'Josep Borrell',
#  'EU': 'EU',
#  'China': 'China',
#  'Steven Cheung': 'Steven Cheung',
#  'Lincoln Project': 'Lincoln Project',
#  'The Lincoln Project': 'Lincoln Project',
#  'Sean': 'Sean',
#  'Democratic Party': 'Democratic Party',
#  'Democratic party': 'Democratic Party',
#  'Democatic Party': 'Democratic Party',
#  'Democratic political parties': 'Democratic Party',
#  'Eric Adams': 'Eric Adams',
#  'Andreessen': 'Andreessen',
#  'Andreessen/Horowitz': 'Andreessen/Horowitz',
#  'Jared Bernstein': 'Jared Bernstein',
#  'Michelle Bowman': 'Michelle Bowman',
#  'John Deere': 'John Deere',
#  'Mark Cuban': 'Mark Cuban',
#  'Joe Manchin': 'Joe Manchin',
#  'Joe Manchin III': 'Joe Manchin',
#  'Kristen Clarke': 'Kristen Clarke',
#  'Dick Durbin': 'Dick Durbin',
#  'Marco Rubio': 'Marco Rubio',
#  'Rubio': 'Marco Rubio',
#  'Teresa Smith': 'Teresa Smith',
#  'Bob Ward': 'Bob Ward',
#  'Seth Schuster': 'Seth Schuster',
#  'Phil Martin': 'Phil Martin',
#  'Dick Edgecombe': 'Dick Edgecombe',
#  'Gary Allen': 'Gary Allen',
#  'ILA': 'ILA',
#  'David Wessel': 'David Wessel',
#  'Andrés Manuel López Obrador': 'Andrés Manuel López Obrador',
#  'Emmanuel Macron': 'Emmanuel Macron',
#  'Adam Schiff': 'Adam Schiff',
#  'Ian Sams': 'Ian Sams',
#  'George W. Bush': 'George W. Bush',
#  'George H.W. Bush': 'George W. Bush',
#  'George W Bush': 'George W. Bush',
#  'Lloyd Austin': 'Lloyd Austin',
#  'Bob Woodward': 'Bob Woodward',
#  'Eric Schmitt': 'Eric Schmitt',
#  'Meghan McCain': 'Meghan McCain',
#  'Howard Gleckman': 'Howard Gleckman',
#  'House Republicans': 'Republican Party',
#  'House Democrats': 'Democratic Party',
#  'House GOP': 'House Republicans',
#  'John Fetterman': 'John Fetterman',
#  'Ruth Ben-Ghiat': 'Ruth Ben-Ghiat',
#  'Bernie Sanders': 'Bernie Sanders',
#  'Laura Cruz Acosta': 'Laura Cruz Acosta',
#  'Erin Hut': 'Erin Hut',
#  'Allison Franz': 'Allison Franz',
#  'Nancy Sorensen': 'Nancy Sorensen',
#  'Ana Pereira': 'Ana Pereira',
#  'Rob Lee': 'Rob Lee',
#  'America PAC': 'America PAC',
#  'OpenSecrets': 'OpenSecrets',
#  'Sylvia Albert': 'Sylvia Albert',
#  'Frank LaRose': 'Frank LaRose',
#  'Alice Clapman': 'Alice Clapman',
#  'FEMA': 'FEMA',
#  'Jared Polis': 'Jared Polis',
#  'Ben Feeney': 'Ben Feeney',
#  'Logan Paul': 'Logan Paul',
#  'Nelk Boys': 'Nelk Boys',
#  'Jasleen Singh': 'Jasleen Singh',
#  'Ann Wagner': 'Ann Wagner',
#  'Republicans Overseas': 'Republicans Overseas',
#  'Farage': 'Farage',
#  'John F. Kelly': 'John F. Kelly',
#  'John Kelly': 'John F. Kelly',
#  'Al Sharpton': 'Al Sharpton',
#  'Ian Bassin': 'Ian Bassin',
#  'Calley Means': 'Calley Means',
#  'Ryan Lizza': 'Ryan Lizza',
#  'Olivia Nuzzi': 'Olivia Nuzzi',
#  'Josh Shapiro': 'Josh Shapiro',
#  'Derek Muller': 'Derek Muller',
#  'David Becker': 'David Becker',
#  'Rick Hasen': 'Rick Hasen',
#  'Richard Hasen': 'Rick Hasen',
#  'Jocelyn Benson': 'Jocelyn Benson',
#  'Mark Milley': 'Mark Milley',
#  'Mark A. Milley': 'Mark Milley',
#  'Jim Mattis': 'Jim Mattis',
#  'Stanley McChrystal': 'Stanley McChrystal',
#  'Bill McRaven': 'Bill McRaven',
#  'Mike Mullen': 'Mike Mullen',
#  'Keith Kellogg': 'Keith Kellogg',
#  'Adam Hersh': 'Adam Hersh',
#  'Joseph Costello': 'Joseph Costello',
#  'Alan Deardorff': 'Alan Deardorff',
#  'Aquilino Gonell': 'Aquilino Gonell',
#  'Amy Berman Jackson': 'Amy Berman Jackson',
#  'Royce Lamberth': 'Royce Lamberth',
#  'Ronald Reagan': 'Ronald Reagan',
#  'Reagan': 'Ronald Reagan',
#  'Hallie Jackson': 'Hallie Jackson',
#  'Ann Scheidler': 'Ann Scheidler',
#  'Paul Whelan': 'Paul Whelan',
#  'David Whelan': 'Paul Whelan',
#  'Anna Manasco': 'Anna Manasco',
#  'Glenn Youngkin': 'Glenn Youngkin',
#  'Daron Acemoglu': 'Daron Acemoglu',
#  'Acemoglu': 'Daron Acemoglu',
#  'James Robinson': 'James Robinson',
#  'Robinson': 'Robinson',
#  'Mike Lee': 'Mike Lee',
#  'Amy Kremer': 'Amy Kremer',
#  'Renée DiResta': 'Renée DiResta',
#  'Renee DiResta': 'Renée DiResta',
#  'Eddie Perez': 'Eddie Perez',
#  'Tom Bowman': 'Tom Bowman',
#  'Carrie Johnson': 'Carrie Johnson',
#  'Frank McKenzie': 'Frank McKenzie',
#  'Senate Leadership Fund': 'Senate Leadership Fund',
#  'Sherrod Brown': 'Sherrod Brown',
#  'Kelley Robinson': 'Kelley Robinson',
#  'Nancy Pelosi': 'Nancy Pelosi',
#  'Pelosi': 'Nancy Pelosi',
#  'Kristi Noem': 'Kristi Noem',
#  'Mike Pence': 'Mike Pence',
#  'Jack Smith': 'Jack Smith',
#  'David Owen': 'David Owen',
#  'Angela Merkel': 'Angela Merkel',
#  'Merkel': 'Angela Merkel',
#  'Boris Johnson': 'Boris Johnson',
#  'Xi Jinping': 'Xi Jinping',
#  'Liz Cheney': 'Liz Cheney',
#  'Michael Cohen': 'Michael Cohen',
#  'Katherine Yon Ebright': 'Katherine Yon Ebright',
#  'James Madison': 'James Madison',
#  'Woodrow Wilson': 'Woodrow Wilson',
#  'Franklin Roosevelt': 'Franklin Roosevelt',
#  'Franklin D. Roosevelt': 'Franklin Roosevelt',
#  'Theodore Roosevelt': 'Franklin Roosevelt',
#  'Teddy Roosevelt': 'Franklin Roosevelt',
#  'Franklin D Roosevelt': 'Franklin Roosevelt',
#  'Harry Truman': 'Harry Truman',
#  'Ilya Somin': 'Ilya Somin',
#  'George “Tyrus” Murdoch': 'George “Tyrus” Murdoch',
#  'US government': 'US government',
#  'U.S. government': 'US government',
#  'Nelson Mandela': 'Nelson Mandela',
#  'Meta': 'Meta',
#  'Byron Donalds': 'Byron Donalds',
#  'Douglas Holtz-Eakin': 'Douglas Holtz-Eakin',
#  'Gregory Marlyn Galindez-Trias': 'Gregory Marlyn Galindez-Trias',
#  'Moises Alejandro Condollo-Urbaneja': 'Moises Alejandro Condollo-Urbaneja',
#  'Danielle Jurinsky': 'Danielle Jurinsky',
#  'Greg Abbott': 'Greg Abbott',
#  'Susan Ford Bales': 'Susan Ford Bales',
#  'Michelle Obama': 'Michelle Obama',
#  'Centre for New Liberalism': 'Centre for New Liberalism',
#  'Center for New Liberalism': 'Centre for New Liberalism',
#  'Ruth Cadbury': 'Ruth Cadbury',
#  'Joachim Nagel': 'Joachim Nagel',
#  'Jens Spahn': 'Jens Spahn',
#  'Friedrich Merz': 'Friedrich Merz',
#  'Germany': 'Germany',
#  'Brennan Center for Justice': 'Brennan Center for Justice',
#  'Cato Institute': 'Cato Institute',
#  'Paxton': 'Paxton',
#  'Marine Le Pen': 'Marine Le Pen',
#  'Jeff Bezos': 'Jeff Bezos',
#  'Eugene Meyer': 'Eugene Meyer',
#  'Dave Limp': 'Dave Limp',
#  'Abby Phillip': 'Abby Phillip',
#  'Scott Jennings': 'Scott Jennings',
#  'Jim Sciutto': 'Jim Sciutto',
#  'Bakari Sellers': 'Bakari Sellers',
#  'Joe Lockhart': 'Joe Lockhart',
#  'David Axelrod': 'David Axelrod',
#  'Ben Ferguson': 'Ben Ferguson',
#  'Timothy Mellon': 'Timothy Mellon',
#  'Miriam Adelson': 'Miriam Adelson',
#  'Kenneth Griffin': 'Kenneth Griffin',
#  'Michael Bloomberg': 'Michael Bloomberg',
#  'Mike Bloomberg': 'Michael Bloomberg',
#  'Stephen Schwarzman': 'Stephen Schwarzman',
#  'Future Forward USA Action': 'Future Forward USA Action',
#  'Majority Forward': 'Majority Forward',
#  'Empower Parents PAC': 'Empower Parents PAC',
#  'Fund for Policy Reform': 'Fund for Policy Reform',
#  'One Nation': 'One Nation',
#  'AH Capital Management': 'AH Capital Management',
#  'Marc Andreesen': 'Marc Andreesen',
#  'Ben Horowitz': 'Ben Horowitz',
#  'House Majority Forward': 'House Majority Forward',
#  'Koch Industries': 'Koch Industries',
#  'Charles Koch': 'Charles Koch',
#  'David Koch': 'Charles Koch',
#  'Kenneth Koch': 'Ed Koch',
#  'Facebook': 'Facebook',
#  'Uline': 'Uline',
#  'Tesla': 'Tesla',
#  'Las Vegas Sands': 'Las Vegas Sands',
#  'Citadel': 'Citadel',
#  'Elliott Management': 'Elliott Management',
#  'Blackstone': 'Blackstone',
#  'economists': 'economists',
#  'Joseph Stiglitz': 'Joseph Stiglitz',
#  'Erica York': 'Erica York',
#  'Brian Riedl': 'Brian Riedl',
#  'Alyssa Farah Griffin': 'Alyssa Farah Griffin',
#  'Portland Police Bureau': 'Portland Police Bureau',
#  'Washington': 'Washington',
#  'Clark County Auditor’s office': 'Clark County Auditor’s office',
#  'Clark County Auditor': 'Clark County Auditor’s office',
#  'Washington Secretary of State': 'Washington Secretary of State',
#  'Marie Gluesenkamp Perez': 'Marie Gluesenkamp Perez',
#  'Steve Hobbs': 'Steve Hobbs',
#  'Stephanie Grisham': 'Stephanie Grisham',
#  'Miles Taylor': 'Miles Taylor',
#  'Jay Campbell': 'Jay Campbell',
#  'Micah Roberts': 'Micah Roberts',
#  'Department of Homeland Security': 'Department of Homeland Security',
#  'Homeland Security Department': 'Department of Homeland Security',
#  'US Department of Homeland Security': 'Department of Homeland Security',
#  'Office of Homeland Security': 'Department of Homeland Security',
#  'Frank Figliuzzi': 'Frank Figliuzzi',
#  'Ammon Blair': 'Ammon Blair',
#  'Joe Rogan': 'Joe Rogan',
#  'Chris Kempczinski': 'Chris Kempczinski',
#  'Democratic': 'Democratic',
#  'Democrat': 'Democratic',
#  'Alex Pfeiffer': 'Alex Pfeiffer',
#  'Mayra Guillén': 'Mayra Guillén',
#  'Natalie Khawam': 'Natalie Khawam',
#  'Joaquin Castro': 'Joaquin Castro',
#  'Domingo Garcia': 'Domingo Garcia',
#  'Sylvia Garcia': 'Sylvia Garcia',
#  'Sharon Yamato': 'Sharon Yamato',
#  'Gladys Sicknick': 'Gladys Sicknick',
#  'Erin Smith': 'Erin Smith',
#  'Tony Hinchcliffe': 'Tony Hinchcliffe',
#  'David Rem': 'David Rem',
#  'Stephen Miller': 'Stephen Miller',
#  'Grant Cardone': 'Grant Cardone',
#  'Tucker Carlson': 'Tucker Carlson',
#  'Danielle Kurtzleben': 'Danielle Kurtzleben',
#  'Alexandria Ocasio-Cortez': 'Alexandria Ocasio-Cortez',
#  'Rick Scott': 'Rick Scott',
#  'Carlos Gimenez': 'Carlos Gimenez',
#  'Bad Bunny': 'Bad Bunny',
#  'Jennifer Lopez': 'Jennifer Lopez',
#  'Ricky Martin': 'Ricky Martin',
#  'Maria Elvira Salazar': 'Maria Elvira Salazar',
#  'Patricia Tolliver Giles': 'Patricia Tolliver Giles',
#  'Anna Dorman': 'Anna Dorman',
#  'Nadra Wilson': 'Nadra Wilson',
#  'James Orr': 'James Orr',
#  'Joe Kent': 'Joe Kent',
#  'Max Read': 'Max Read',
#  'Brian Kemp': 'Brian Kemp',
#  'Brian Robinson': 'Brian Robinson',
#  'Katie Harbath': 'Katie Harbath',
#  'Rupert Murdoch': 'Rupert Murdoch',
#  'Washington Post': 'Washington Post',
#  'The Washington Post': 'Washington Post',
#  'Robert Kagan': 'Robert Kagan',
#  'Martin Baron': 'Martin Baron',
#  'Washington Post Guild': 'Washington Post Guild',
#  'The Washington Post Guild': 'Washington Post Guild',
#  'Will Lewis': 'Will Lewis',
#  'Patrick Soon-Shiong': 'Patrick Soon-Shiong',
#  'Elise Stefanik': 'Elise Stefanik',
#  'Nick LaLota': 'Nick LaLota',
#  "Anthony D'Esposito": "Anthony D'Esposito",
#  'Mike Lawler': 'Mike Lawler',
#  'Adolf Hitler': 'Adolf Hitler',
#  'Hitler': 'Adolf Hitler',
#  'Jessica Rosenworcel': 'Jessica Rosenworcel',
#  'Joseph Kahn': 'Joseph Kahn',
#  'Labour Party': 'Labour Party',
#  'U.K. Labour Party': 'Labour Party',
#  'Sofia Patel': 'Sofia Patel',
#  'Australian Labor Party': 'Australian Labor Party',
#  'Dana Bash': 'Dana Bash',
#  'Angel M Cintron': 'Angel M Cintron',
#  'El Nuevo Dia': 'El Nuevo Dia',
#  'Zoraida Buxo': 'Zoraida Buxo',
#  'Daniella Alvarez': 'Daniella Alvarez',
#  'Danielle Alvarez': 'Daniella Alvarez',
#  'Steve Herman': 'Steve Herman',
#  'Tom Herman': 'Steve Herman',
#  'Jen O’Malley Dillon': 'Jen O’Malley Dillon',
#  "Jen O'Malley Dillon": 'Jen O’Malley Dillon',
#  'Eran Etzion': 'Eran Etzion',
#  'Arianna Podestà': 'Arianna Podestà',
#  'Jean-Noël Barrot': 'Jean-Noël Barrot',
#  'Nandy': 'Nandy',
#  'Primas': 'Primas',
#  'France': 'France',
#  'Sam Blewett': 'Sam Blewett',
#  'Google': 'Google',
#  'Rachel Reeves': 'Rachel Reeves',
#  'Jeremy Hunt': 'Jeremy Hunt',
#  'Diane Abbott': 'Diane Abbott',
#  'Bell Ribeiro-Addy': 'Bell Ribeiro-Addy',
#  'Clive Lewis': 'Clive Lewis',
#  'Mike Amesbury': 'Mike Amesbury',
#  'Salome Zourabichvili': 'Salome Zourabichvili',
#  'Benjamin Netanyahu': 'Benjamin Netanyahu',
#  'Janet Yellen': 'Janet Yellen',
#  'Karim Khan': 'Karim Khan',
#  'Nigel Farage': 'Nigel Farage',
#  'Starmer': 'Starmer',
#  'Suzanne Lynch': 'Suzanne Lynch',
#  'Kristalina Georgieva': 'Kristalina Georgieva',
#  'Ajay Banga': 'Ajay Banga',
#  'John Mbadi': 'John Mbadi',
#  'Kamau Thugge': 'Kamau Thugge',
#  'Howard Lutnik': 'Howard Lutnik',
#  'Rachel': 'Rachel',
#  'Jasper': 'Jasper',
#  'Jamie Dimon': 'Jamie Dimon',
#  'Jayati Ghosh': 'Jayati Ghosh',
#  'Yvette Cooper': 'Yvette Cooper',
#  'Morgan McSweeney': 'Morgan McSweeney',
#  'Matthew Doyle': 'Matthew Doyle',
#  'Alex Cole-Hamilton': 'Alex Cole-Hamilton',
#  'Steve Reed': 'Steve Reed',
#  'Wes Streeting': 'Wes Streeting',
#  'André Sapir': 'André Sapir',
#  'Zach Meyers': 'Zach Meyers',
#  'European Commission': 'European Commission',
#  'Goldman Sachs': 'Goldman Sachs',
#  'ECB': 'ECB',
#  'election': 'election',
#  'elections': 'election',
#  'Election': 'election',
#  'Sean Hannity': 'Sean Hannity',
#  'Eric Hovde': 'Eric Hovde',
#  'Theresa Vescio': 'Theresa Vescio',
#  'Nathaniel Schermerhorn': 'Nathaniel Schermerhorn',
#  'Israel': 'Israel',
#  'Bob Casey': 'Bob Casey',
#  'Bernie Moreno': 'Bernie Moreno',
#  'Teamsters': 'Teamsters',
#  'Kennedy': 'Kennedy',
#  'Utah': 'Utah',
#  'Julia Roberts': 'Julia Roberts',
#  'Jesse Watters': 'Jesse Watters',
#  'Kamala': 'Kamala',
#  'Ann Selzer': 'Ann Selzer',
#  'J Ann Selzer': 'Ann Selzer',
#  'June': 'June',
#  'Kevin Roberts': 'Kevin Roberts',
#  'Juan Merchan': 'Juan Merchan',
#  'Aileen Cannon': 'Aileen Cannon',
#  'Fani Willis': 'Fani Willis',
#  'Blair Bowie': 'Blair Bowie',
#  'Cory Booker': 'Cory Booker',
#  'CBS': 'CBS',
#  'Charles Tobin': 'Charles Tobin',
#  'Larry Krasner': 'Larry Krasner',
#  'John McCain': 'John McCain',
#  'McCain': 'John McCain',
#  'Adam Kinzinger': 'Adam Kinzinger',
#  'Fox News': 'Fox News',
#  'Fox News Media': 'Fox News',
#  'Ashley Allison': 'Ashley Allison',
#  'Charli XCX': 'Charli XCX',
#  'Annette Corsino': 'Annette Corsino',
#  'US Environmental Protection Agency': 'US Environmental Protection Agency',
#  'Environmental Protection Agency': 'US Environmental Protection Agency',
#  'U.S. Environmental Protection Agency': 'US Environmental Protection Agency',
#  'Edward Chen': 'Edward Chen',
#  'CDC': 'CDC',
#  'American Dental Association': 'American Dental Association',
#  'NBC News': 'NBC News',
#  'ABC News': 'NBC News',
#  'MSNBC': 'CNBC',
#  'CBS News': 'NBC News',
#  'NBC NEWS': 'NBC News',
#  'Regino Cruz': 'Regino Cruz',
#  'Carlos Odio': 'Carlos Odio',
#  'Artemio Muniz': 'Artemio Muniz',
#  'Kalman Nunez': 'Kalman Nunez',
#  'Fernando Rivera': 'Fernando Rivera',
#  'Danny Martinez': 'Danny Martinez',
#  'Daniel Martinez': 'Daniel Medina',
#  'Yahaira Rodríguez': 'Yahaira Rodríguez',
#  'Christianea Valentine': 'Christianea Valentine',
#  'Vianca Rodriguez': 'Vianca Rodriguez',
#  'Peter Welch': 'Peter Welch',
#  'Adam Jentleson': 'Adam Jentleson',
#  'Wade Randlett': 'Wade Randlett',
#  'Bob Elliott': 'Bob Elliott',
#  'Steve Sosnick': 'Steve Sosnick',
#  'Joyce Vance': 'Joyce Vance',
#  'Kyra Bolden': 'Kyra Bolden',
#  "Patrick O'Grady": "Patrick O'Grady",
#  'Kimberly Thomas': 'Kimberly Thomas',
#  'Andrew Fink': 'Andrew Fink',
#  'Elissa Slotkin': 'Elissa Slotkin',
#  'Gretchen Whitmer': 'Gretchen Whitmer',
#  'Jacky Rosen': 'Jacky Rosen',
#  'Sam Brown': 'Sam Brown',
#  'Mary Peltola': 'Mary Peltola',
#  'Mark Begich': 'Mark Begich',
#  'National Election Pool (NEP)': 'National Election Pool (NEP)',
#  'Isaac Herzog': 'Isaac Herzog',
#  'Basem Naim': 'Basem Naim',
#  'Mohammed Al Hasany': 'Mohammed Al Hasany',
#  'Leonid Slutsky': 'Leonid Slutsky',
#  'Fyodor Lukyanov': 'Fyodor Lukyanov',
#  'Mark Rutte': 'Mark Rutte',
#  'Mao Ning': 'Mao Ning',
#  'Yoon Suk Yeol': 'Yoon Suk Yeol',
#  'Yoon Suk-yeol': 'Yoon Suk Yeol',
#  'Yoshimasa Hayashi': 'Yoshimasa Hayashi',
#  'Claudia Sheinbaum': 'Claudia Sheinbaum',
#  'Justin Trudeau': 'Justin Trudeau',
#  'Kelly Craft': 'Kelly Craft',
#  'Javier Milei': 'Javier Milei',
#  'Jair Bolsonaro': 'Jair Bolsonaro',
#  'Eduardo Bolsonaro': 'Jair Bolsonaro',
#  'Luiz Inácio Lula da Silva': 'Luiz Inácio Lula da Silva',
#  'Luiz Inacio Lula da Silva': 'Luiz Inácio Lula da Silva',
#  'Cyril Ramaphosa': 'Cyril Ramaphosa',
#  'Bola Tinubu': 'Bola Tinubu',
#  'Mohammed Shia al-Sudani': 'Mohammed Shia al-Sudani',
#  'Abdul Latif Rashid': 'Abdul Latif Rashid',
#  'Brian Blase': 'Brian Blase',
#  'Theo Merkel': 'Theo Merkel',
#  'Leslie Dach': 'Leslie Dach',
#  'Larry Levitt': 'Larry Levitt',
#  'BJ Martino': 'BJ Martino',
#  'Robert Welch': 'Robert Welch',
#  'Matthew Dallek': 'Matthew Dallek',
#  'G. Edward Griffin': 'G. Edward Griffin',
#  'John Birch Society': 'John Birch Society',
#  'James Edward Meehan': 'James Edward Meehan',
#  'Martin Luther King Jr.': 'Martin Luther King Jr.',
#  'Fred Rogers': 'Fred Rogers',
#  'Earl Warren': 'Earl Warren',
#  'Barry Goldwater': 'Barry Goldwater',
#  'William Buckley': 'William Buckley',
#  'Nelson Rockefeller': 'Nelson Rockefeller',
#  'Alex Jones': 'Alex Jones',
#  'Jackson Katz': 'Jackson Katz',
#  'Elora Mukherjee': 'Elora Mukherjee',
#  'Andrea Flores': 'Andrea Flores',
#  'Bruna Sollod': 'Bruna Sollod',
#  'Greg Casar': 'Greg Casar',
#  'Sollod': 'Sollod',
#  "Biden's campaign": "Biden's campaign",
#  'FF PAC': 'FF PAC',
#  'MAGA Inc.': 'MAGA Inc.',
#  'Harris campaign': 'Harris campaign',
#  'Alison LaCroix': 'Alison LaCroix',
#  'Gouverneur Morris': 'Gouverneur Morris',
#  'Jesse Wegman': 'Jesse Wegman',
#  'Richard Nixon': 'Richard Nixon',
#  'Richard M. Nixon': 'Richard Nixon',
#  'Nixon': 'Richard Nixon',
#  'Birch Bayh': 'Birch Bayh',
#  'Alex Keyssar': 'Alex Keyssar',
#  'Vernon Jordan': 'Vernon Jordan',
#  'Akhil Reed Amar': 'Akhil Reed Amar',
#  'Electoral College': 'Electoral College',
#  'National Popular Vote Interstate Compact': 'National Popular Vote Interstate Compact',
#  'Heritage Foundation': 'Heritage Foundation',
#  'Cook Political Report': 'Cook Political Report',
#  'Shawn Fain': 'Shawn Fain',
#  'Kathy Magner': 'Kathy Magner',
#  'Roy Cooper': 'Roy Cooper',
#  'Jarad': 'Jarad',
#  'Hilal': 'Hilal',
#  'Malaka': 'Malaka',
#  'Fayyad': 'Fayyad',
#  'Timothy Ash': 'Timothy Ash',
#  'Narendra Modi': 'Narendra Modi',
#  'Israel Katz': 'Israel Katz',
#  'Sheikh Tamim bin Hamad Al Thani': 'Sheikh Tamim bin Hamad Al Thani',
#  'Abdel Fattah el-Sisi': 'Abdel Fattah el-Sisi',
#  'Mahmoud Abbas': 'Mahmoud Abbas',
#  'Abdul Qahar Balkhi': 'Abdul Qahar Balkhi',
#  'Lai Ching-te': 'Lai Ching-te',
#  'Dmitry Medvedev': 'Dmitry Medvedev',
#  'Charles Michel': 'Charles Michel',
#  'Antonio Guterres': 'Antonio Guterres',
#  'Yvan Gil': 'Yvan Gil',
#  'Anthony Albanese': 'Anthony Albanese',
#  'Salman': 'Salman',
#  'Abdullah II': 'Abdullah II',
#  'Shigeru Ishiba': 'Shigeru Ishiba',
#  'Pedro Sanchez Sanchez': 'Pedro Sanchez Sanchez',
#  'Shehbaz Sharif': 'Shehbaz Sharif',
#  'Giorgia Meloni': 'Giorgia Meloni',
#  'Abiy Ahmed': 'Abiy Ahmed',
#  'William Ruto': 'William Ruto',
#  'Paul Kagame': 'Paul Kagame',
#  'Dick Schoof': 'Dick Schoof',
#  'Karl Nehammer': 'Karl Nehammer',
#  'Ulf Kristersson': 'Ulf Kristersson',
#  'Jonas Gahr Store': 'Jonas Gahr Store',
#  'Mette Frederiksen': 'Mette Frederiksen',
#  'Petr Fiala': 'Petr Fiala',
#  'Marcel Ciolacu': 'Marcel Ciolacu',
#  'Nayib Bukele': 'Nayib Bukele',
#  'Hun Manet': 'Hun Manet',
#  'Jose Raul Mulino': 'Jose Raul Mulino',
#  'Ferdinand Marcos Jr': 'Ferdinand Marcos Jr',
#  'Kassym-Jomart Tokayev': 'Kassym-Jomart Tokayev',
#  'Shavkat Mirziyoyev': 'Shavkat Mirziyoyev',
#  'Rina Shah': 'Rina Shah',
#  'Erica Frantz': 'Erica Frantz',
#  'Samraa Luqman': 'Samraa Luqman',
#  'Bill Bazzi': 'Bill Bazzi',
#  'Hassan Hussein Abdullah': 'Hassan Hussein Abdullah',
#  'Fawzi Mohamad': 'Fawzi Mohamad',
#  'Sami Khaldi': 'Sami Khaldi',
#  'Amer Ghalib': 'Amer Ghalib',
#  'Layla Elabed': 'Layla Elabed',
#  'Ali Aljahmi': 'Ali Aljahmi',
#  'Abdullah Hammoud': 'Abdullah Hammoud',
#  'Michael Adams': 'Michael Adams',
#  'Michelle Henry': 'Michelle Henry',
#  'Joanna Lydgate': 'Joanna Lydgate',
#  'Homer Simpson': 'Homer Simpson',
#  'SpaceX': 'SpaceX',
#  'Supreme Court': 'Supreme Court',
#  'U.S. Supreme Court': 'Supreme Court',
#  'US Supreme Court': 'Supreme Court',
#  'United States Supreme Court': 'Supreme Court',
#  'Oprah Winfrey': 'Oprah Winfrey',
#  'Luis Fonsi': 'Luis Fonsi',
#  'Laura Ingraham': 'Laura Ingraham',
#  'LeBron James': 'LeBron James',
#  'The Chicks': 'The Chicks',
#  'Dmitry Peskov': 'Dmitry Peskov',
#  'Alexey Malinin': 'Alexey Malinin',
#  'Ilya Gambashidze': 'Ilya Gambashidze',
#  'Ilya Budraitskis': 'Ilya Budraitskis',
#  'Anya B': 'Anya B',
#  'Jill Stein': 'Jill Stein',
#  'Ritchie Torres': 'Ritchie Torres',
#  'Amer Zahr': 'Amer Zahr',
#  'Robert S McCaw': 'Robert S McCaw',
#  'Yousef Munayyer': 'Yousef Munayyer',
#  'Robert Fico': 'Robert Fico',
#  'Radek Sikorski': 'Radek Sikorski',
#  'Benjamin Haddad': 'Benjamin Haddad',
#  'Georgian Dream': 'Georgian Dream',
#  'HarrisX': 'HarrisX',
#  'United States administration': 'United States administration',
#  'Orbán': 'Orbán',
#  'Alan Bates': 'Alan Bates',
#  'Šefčovič': 'Šefčovič',
#  'Brando Benifei': 'Brando Benifei',
#  'Campaign for Freedom': 'Campaign for Freedom',
#  'Kallum Pickering': 'Kallum Pickering',
#  'European Greens': 'European Greens',
#  'German Greens': 'European Greens',
#  'Pete Hoekstra': 'Pete Hoekstra',
#  'Jared Kushner': 'Jared Kushner',
#  'European Central Bank (ECB)': 'European Central Bank (ECB)',
#  'European Central Bank': 'European Central Bank (ECB)',
#  'Italy': 'Italy',
#  'Spain': 'Spain',
#  'Marko Mihkelson': 'Marko Mihkelson',
#  'Dick Zandee': 'Dick Zandee',
#  'NATO': 'NATO',
#  'Nato': 'NATO',
#  'Pressman': 'Pressman',
#  'Orban': 'Orban',
#  'Rachel Cleetus': 'Rachel Cleetus',
#  'Dan Lashof': 'Dan Lashof',
#  'Christiana Figueres': 'Christiana Figueres',
#  'Laurence Tubiana': 'Laurence Tubiana',
#  'Mélanie Vogel': 'Mélanie Vogel',
#  'Thomas Waitz': 'Thomas Waitz',
#  "Dan O'Brien": "Dan O'Brien",
#  'Noah Foley-Beining': 'Noah Foley-Beining',
#  'Michael Waltz': 'Michael Waltz',
#  'Democracy Forward': 'Democracy Forward',
#  'Marc Elias': 'Marc Elias',
#  'Ron Klain': 'Ron Klain',
#  'Clay Travis': 'Clay Travis',
#  'Dan Pfeiffer': 'Dan Pfeiffer',
#  'Andrew Yang': 'Andrew Yang',
#  'Lis Smith': 'Lis Smith',
#  'Jason Miller': 'Jason Miller',
#  'Tim Miller': 'Tim Miller',
#  'Donna Brazile': 'Donna Brazile',
#  'Mark R. Warner': 'Mark R. Warner',
#  'Tim Kaine': 'Tim Kaine',
#  'Tammy Baldwin': 'Tammy Baldwin',
#  'Mike Huckabee': 'Mike Huckabee',
#  'Lyndon B. Johnson': 'Lyndon B. Johnson',
#  'Tom Homan': 'Tom Homan',
#  'Jim Jordan': 'Jim Jordan',
#  'John Thune': 'John Thune',
#  'John Cornyn': 'John Cornyn',
#  'Greg Gutfeld': 'Greg Gutfeld',
#  'Kerry Kennedy': 'Kerry Kennedy',
#  'Erin Burnett': 'Erin Burnett',
#  'Barron Trump': 'Barron Trump',
#  'Barron': 'Barron Trump',
#  'William Barr': 'William Barr',
#  'Bill Barr': 'William Barr',
#  'Yasmin Cader': 'Yasmin Cader',
#  'Ruth Friedman': 'Ruth Friedman',
#  'Chuck Grassley': 'Chuck Grassley',
#  'Senate': 'Senate',
#  'U.S. Senate': 'Senate',
#  'Josh Riley': 'Josh Riley',
#  'Josh Stein': 'Josh Stein',
#  'Abigail Spanberger': 'Abigail Spanberger',
#  'Kash Patel': 'Kash Patel',
#  'Gina Haspel': 'Gina Haspel',
#  'Kathy Hochul': 'Kathy Hochul',
#  'Kirsten Gillibrand': 'Kirsten Gillibrand',
#  'Riley': 'Riley',
#  'John Malcolm': 'John Malcolm',
#  'Brianne Gorod': 'Brianne Gorod',
#  'Amy Coney Barrett': 'Amy Coney Barrett',
#  'Alex Aronson': 'Alex Aronson',
#  'Omar Jadwat': 'Omar Jadwat',
#  'Mark Krikorian': 'Mark Krikorian',
#  'Ken Cuccinelli': 'Ken Cuccinelli',
#  'Mark Zaid': 'Mark Zaid',
#  'Larry Pfeiffer': 'Larry Pfeiffer',
#  'Michael Fanone': 'Michael Fanone',
#  'John Bolton': 'John Bolton',
#  'Jared Moskowitz': 'Jared Moskowitz',
#  'Katie O’Connor': 'Katie O’Connor',
#  'Matthew Kacsmaryk': 'Matthew Kacsmaryk',
#  'Amy Friedrich-Karnik': 'Amy Friedrich-Karnik',
#  'Wendy Parmet': 'Wendy Parmet',
#  'Guttmacher Institute': 'Guttmacher Institute',
#  'Larry Norden': 'Larry Norden',
#  'Brad Raffensperger': 'Brad Raffensperger',
#  'Office of the Director of National Intelligence': 'Office of the Director of National Intelligence',
#  'Office of the Director of National Intelligence (ODNI)': 'Office of the Director of National Intelligence',
#  'Robert Califf': 'Robert Califf',
#  'Pete Hegseth': 'Pete Hegseth',
#  'Tammy Duckworth': 'Tammy Duckworth',
#  'Allison Jaslow': 'Allison Jaslow',
#  'Dan Goldman': 'Dan Goldman',
#  '22nd Amendment': '22nd Amendment',
#  'Lee Zeldin': 'Lee Zeldin',
#  'Brian Murray': 'Brian Murray',
#  'Della Volpe': 'Della Volpe',
#  'Kirk': 'Kirk',
#  'Paul Clark': 'Paul Clark',
#  'Humphreys': 'Humphreys',
#  'Vivek Ramaswamy': 'Vivek Ramaswamy',
#  'Ramaswamy': 'Ramaswamy',
#  'Lee Miringoff': 'Lee Miringoff',
#  'Paul Begala': 'Paul Begala',
#  'Adrianne Shropshire': 'Adrianne Shropshire',
#  'Waleed Shahid': 'Waleed Shahid',
#  'Phil Klay': 'Phil Klay',
#  'Matt Gaetz': 'Matt Gaetz',
#  'Doug Burgum': 'Doug Burgum',
#  'William Perry Pendley': 'William Perry Pendley',
#  'Ryan Zinke': 'Ryan Zinke',
#  'David Bernhardt': 'David Bernhardt',
#  'Jon Miller': 'Jon Miller',
#  'ZEINAB CHAMI': 'ZEINAB CHAMI',
#  'Faye Nemer': 'Faye Nemer',
#  'Jumana Judeh': 'Jumana Judeh',
#  'Yahya Basha': 'Yahya Basha',
#  'Keith Humphreys': 'Keith Humphreys',
#  'Deanne Criswell': 'Deanne Criswell',
#  'Adam Smith': 'Adam Smith',
#  'Roger Wicker': 'Roger Wicker',
#  'Todd Blanche': 'Todd Blanche',
#  'Emil Bove': 'Emil Bove',
#  'Dean John Sauer': 'Dean John Sauer',
#  'Andrew Wakefield': 'Andrew Wakefield',
#  'X': 'X',
#  'Mohammed bin Salman': 'Mohammed bin Salman',
#  'Ahmed Aboul Gheit': 'Ahmed Aboul Gheit',
#  'Najib Mikati': 'Najib Mikati',
#  'Mohammad Reza Aref': 'Mohammad Reza Aref',
#  'Ukraine': 'Ukraine',
#  'Jeffrey Sachs': 'Jeffrey Sachs',
#  'Jordan Bardella': 'Jordan Bardella',
#  'Mauvis Ledford': 'Mauvis Ledford',
#  'Roderick Melvin Johnson': 'Roderick Melvin Johnson',
#  'Bezalel Smotrich': 'Bezalel Smotrich',
#  'European Union': 'European Union',
#  'Andrii Sybiha': 'Andrii Sybiha',
#  'Hungary': 'Hungary',
#  'Cynthia Cox': 'Cynthia Cox',
#  'Michael J Petrilli': 'Michael J Petrilli',
#  'Elana Redfield': 'Elana Redfield',
#  'Greta Thunberg': 'Greta Thunberg',
#  'John Podesta': 'John Podesta',
#  'Elnur Soltanov': 'Elnur Soltanov',
#  'ByteDance': 'ByteDance',
#  'David Greene': 'David Greene',
#  'Adolphus Belk': 'Adolphus Belk',
#  'The Heritage Foundation': 'The Heritage Foundation',
#  'Yoweri Museveni': 'Yoweri Museveni',
#  'Emmerson Mnangagwa': 'Emmerson Mnangagwa',
#  'Samuel Oyewole': 'Samuel Oyewole',
#  'Patrick Bond': 'Patrick Bond',
#  'Christopher Isike': 'Christopher Isike',
#  'South Africa': 'South Africa',
#  'Nathalie Loiseau': 'Nathalie Loiseau',
#  'Marie-Agnes Strack-Zimmermann': 'Marie-Agnes Strack-Zimmermann',
#  'Marek Magierowski': 'Marek Magierowski',
#  'PiS': 'PiS',
#  'Andrzej Duda': 'Andrzej Duda',
#  'Javier Carbonell': 'Javier Carbonell',
#  'Sophie Pornschlegel': 'Sophie Pornschlegel',
#  'Matteo Salvini': 'Matteo Salvini',
#  ...}

# %%
import pandas as pd
from collections import defaultdict

# Step 1: Invert the resolution map to get clusters
inverse_clusters = defaultdict(list)
for alias, canonical in resolution_map.items():
    inverse_clusters[canonical].append(alias)

# Step 2: Convert to DataFrame
cluster_df = pd.DataFrame([
    {"canonical": canon, "aliases": aliases, "number_of_names_in_cluster": len(aliases)}
    for canon, aliases in inverse_clusters.items()
])

# Step 3: Filter for clusters with >1 name
cluster_df_filtered = cluster_df[cluster_df["number_of_names_in_cluster"] > 1]
cluster_df_filtered = cluster_df_filtered.sort_values("number_of_names_in_cluster", ascending=False)

# Step 4: Summary table of cluster sizes
summary = cluster_df_filtered["number_of_names_in_cluster"].value_counts().sort_index().reset_index()
summary.columns = ["number_of_names_in_cluster", "number_of_clusters"]

# %%
summary
# Out:
#    number_of_names_in_cluster  number_of_clusters
# 0                           2                 297
# 1                           3                  42
# 2                           4                  15
# 3                           5                   6
# 4                           6                   5
# 5                           7                   2
# 6                           8                   1
# 7                          10                   1

# %%
cluster_df_filtered
# Out:
#                        canonical  \
# 1189  2024 Presidential Election
# 1745                 war in Gaza
# 143           Volodymyr Zelensky
# 1187               2024 election
# 93       Department of Education
# ...                          ...
# 1282        PRESERVE AMERICA PAC
# 1266            Aurora, Colorado
# 1248                   campaigns
# 1245           Trump Corporation
# 5505      House Ethics Committee
#
#                                                 aliases  \
# 1189  [2024 US election, 2024 United States election...
# 1745  [war in Gaza, war against Hamas, Israel-Gaza w...
# 143   [Zelenskyy, Volodymyr Zelensky, Volodymyr Zele...
# 1187  [2024 election, 2024 campaign, 2024 presidenti...
# 93    [Department of Education, U.S. Department of E...
# ...                                                 ...
# 1282                [PRESERVE AMERICA PAC, AMERICA PAC]
# 1266                  [Aurora, Colorado, Aurora, Colo.]
# 1248                              [campaigns, campaign]
# 1245            [Trump Corporation, Trump Organization]
# 5505  [House Ethics Committee, U.S. House Committee ...
#
#       number_of_names_in_cluster
# 1189                          10
# 1745                           8
# 143                            7
# 1187                           7
# 93                             6
# ...                          ...
# 1282                           2
# 1266                           2
# 1248                           2
# 1245                           2
# 5505                           2
#
# [369 rows x 3 columns]

# %%
# 6. Apply to edges_df
edges_df["source"] = edges_df["source"].map(lambda x: resolution_map.get(x, x))
edges_df["target"] = edges_df["target"].map(lambda x: resolution_map.get(x, x))

# 7. Apply to ents_long
ents_long["entity"] = ents_long["entity"].map(lambda x: resolution_map.get(x, x))

# 8. Optional: Remove duplicates
edges_df.drop_duplicates(inplace=True)
ents_long.drop_duplicates(subset=["url", "entity"], inplace=True)

# 9. Print resolution summary
print(f"🔁 Resolved {len(unique_entities)} entities into {len(clusters)} canonical names.")
# Out:
# 🔁 Resolved 6157 entities into 5651 canonical names.

# %% [markdown]
# dropped duplicates, na and self loops

# %%
edges_df = edges_df[edges_df["source"] != edges_df["target"]]
edges_df.dropna(subset=["source", "target"], inplace=True)

# %% [markdown]
# # fuzzy search
# tried that but decided this semantic sentence transformers were better - with manual override for edge cases
# alternative - facebook's blink model

# %% [markdown]
# # redo graph

# %%
import pandas as pd
import networkx as nx
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
from community import community_louvain
from scipy.spatial import ConvexHull

# Ensure date column is datetime
edges_df['date'] = pd.to_datetime(edges_df['date'])

# Build graph
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _, r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# Centrality & communities
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
betw_cent = nx.betweenness_centrality(G, normalized=True)
partition = community_louvain.best_partition(G)
pos = nx.spring_layout(G, k=0.15, iterations=20)

# Convex hulls for clusters
hull_shapes = []
for comm in set(partition.values()):
    members = [n for n, p in partition.items() if p == comm]
    if len(members) < 3:
        continue
    pts = np.array([pos[n] for n in members])
    hull = ConvexHull(pts)
    path = "M " + " L ".join(f"{pts[v,0]},{pts[v,1]}" for v in hull.vertices) + " Z"
    hull_shapes.append(dict(type="path", path=path, fillcolor="rgba(200,200,200,0.15)", line=dict(width=0)))

# Selective node labels
deg_vals = np.array(list(deg_cent.values()))
thresh = np.percentile(deg_vals, 90)
label_nodes = {n for n, v in deg_cent.items() if v >= thresh}

# Build edge traces by relationship
relationship_types = sorted(edges_df['relationship'].dropna().unique())
edge_traces = []
rel_colors = {r: c for r, c in zip(relationship_types, px.colors.qualitative.Bold)}

for rel in relationship_types:
    xs, ys = [], []
    for _, row in edges_df[edges_df['relationship'] == rel].iterrows():
        if row.source in pos and row.target in pos:
            x0, y0 = pos[row.source]
            x1, y1 = pos[row.target]
            xs += [x0, x1, None]
            ys += [y0, y1, None]
    edge_traces.append(go.Scatter(
        x=xs, y=ys, mode="lines",
        line=dict(color=rel_colors.get(rel, "gray"), width=1),
        name=rel,
        hoverinfo="none",
        visible=True
    ))

# Node traces by type
type_colors = {"people": "blue", "institutions": "orange", "locations": "green", "political_events": "purple", "political_parties": "red", "unknown": "gray"}
entity_types = sorted(ents_long['entity_type'].unique())
node_traces = []

for t in entity_types:
    xs, ys, txt, col, cdata = [], [], [], [], []
    for node in G.nodes():
        et = ents_long[ents_long.entity == node]["entity_type"]
        et = et.iloc[0] if not et.empty else "unknown"
        if et != t:
            continue
        x, y = pos[node]
        xs.append(x); ys.append(y)
        txt.append(node if node in label_nodes else "")
        col.append(type_colors.get(et, "gray"))
        cdata.append([et, deg_cent[node], pr[node]])
    node_traces.append(go.Scatter(
        x=xs, y=ys, mode="markers+text",
        text=txt, textposition="top center",
        marker=dict(size=10, color=col),
        customdata=cdata,
        hovertemplate="<b>%{text}</b><br>Type: %{customdata[0]}<br>Degree: %{customdata[1]:.3f}<br>PageRank: %{customdata[2]:.4f}<extra></extra>",
        visible=True,
        name=t
    ))

# Build slider frames by date
dates = sorted(edges_df['date'].dt.date.unique())
frames = []

for d in dates:
    day_edges = edges_df[edges_df['date'].dt.date == d]
    day_trace = []
    for rel in relationship_types:
        xs, ys = [], []
        for _, row in day_edges[day_edges['relationship'] == rel].iterrows():
            if row.source in pos and row.target in pos:
                x0, y0 = pos[row.source]
                x1, y1 = pos[row.target]
                xs += [x0, x1, None]
                ys += [y0, y1, None]
        day_trace.append(go.Scatter(x=xs, y=ys, mode="lines", line=dict(color=rel_colors.get(rel, "gray"), width=1), name=rel, hoverinfo="none"))
    frames.append(go.Frame(data=day_trace + node_traces, name=str(d)))

# Create figure
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="📅 Knowledge Graph Explorer",
        shapes=hull_shapes,
        hovermode="closest",
        margin=dict(l=20, r=20, t=40, b=20),
        updatemenus=[
            dict(type="buttons", showactive=False, x=0, y=1.15,
                 buttons=[
                     dict(label="▶️ Play", method="animate", args=[None]),
                     dict(label="⏸ Pause", method="animate", args=[[None], {"frame": {"duration": 0}, "mode": "immediate"}])
                 ])
        ],
        sliders=[dict(
            active=0,
            steps=[dict(method="animate", label=str(d), args=[[str(d)], {"frame": {"duration": 0, "redraw": True}, "mode": "immediate"}]) for d in dates],
            x=0.1, y=0, len=0.9
        )]
    ),
    frames=frames
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import numpy as np

# Build weighted graph (assumes edges_df exists with 'source', 'target', 'sentiment', 'relationship')
G = nx.Graph()
for _, row in edges_df.iterrows():
    G.add_edge(row['source'], row['target'], sentiment=row['sentiment'], relationship=row['relationship'], date=row['date'])

# Compute centrality scores
pos = nx.spring_layout(G, k=0.15, iterations=20)
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)

# Normalize node sizes
node_sizes = {n: 10 + 30 * deg_cent[n] for n in G.nodes()}

# Build edge traces
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
edge_traces = []
color_map = {"positive": "green", "negative": "red", "neutral": "gray"}

for s in ["All"] + sentiments:
    xs, ys = [], []
    for u, v, d in G.edges(data=True):
        sent = d.get('sentiment', 'neutral')
        if s != "All" and sent != s:
            continue
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        xs += [x0, x1, None]
        ys += [y0, y1, None]
    edge_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="lines",
            line=dict(color=color_map.get(s, "#888"), width=1),
            hoverinfo="none",
            visible=(s == "All"),
            name=(s if s != "All" else "All Sentiments")
        )
    )

# Create ents_long mapping if not already filtered
entity_types = ents_long.drop_duplicates("entity")[["entity", "entity_type"]].set_index("entity").to_dict()['entity_type']
type_colors = {"people": "blue", "organizations": "orange", "locations": "green", "unknown": "gray"}

# Build node traces
types = sorted(set(entity_types.values()))
node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, size, cdata = [], [], [], [], [], []
    for n in G.nodes():
        et0 = entity_types.get(n, "unknown")
        if t != "All" and et0 != t:
            continue
        x, y = pos[n]
        xs.append(x)
        ys.append(y)
        txt.append(n)
        col.append(type_colors.get(et0, "gray"))
        size.append(node_sizes[n])
        cdata.append([et0, deg_cent[n], pr[n]])
    node_traces.append(
        go.Scatter(
            x=xs, y=ys, mode="markers+text",
            text=txt, textposition="top center",
            marker=dict(size=size, color=col),
            customdata=cdata,
            hovertemplate=(
                "<b>%{text}</b><br>Type: %{customdata[0]}<br>Degree: %{customdata[1]:.3f}<br>PageRank: %{customdata[2]:.4f}<extra></extra>"
            ),
            visible=(t == "All"),
            name=(t if t != "All" else "All Types")
        )
    )

# Assemble figure
fig = go.Figure(
    data=edge_traces + node_traces,
    layout=go.Layout(
        title="Knowledge Graph Explorer",
        hovermode="closest",
        legend=dict(itemsizing="constant"),
        margin=dict(l=20, r=20, b=20, t=40)
    )
)

# Add dropdown filters
fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(label="All Sentiments", method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Sentiments"}])
            ] + [
                dict(label=s.title(), method="update",
                     args=[{"visible": [i == (idx+1) for i in range(len(edge_traces))] + [True]*len(node_traces)},
                           {"title": f"Sentiment: {s.title()}"}])
                for idx, s in enumerate(sentiments)
            ],
            direction="down", x=0, y=1.15, showactive=True
        ),
        dict(
            buttons=[
                dict(label="All Types", method="update",
                     args=[{"visible": [True]*len(edge_traces) + [True]*len(node_traces)},
                           {"title": "All Entity Types"}])
            ] + [
                dict(label=t.title(), method="update",
                     args=[{"visible": [True]*len(edge_traces) + [i == (idx+1) for i in range(len(node_traces))]},
                           {"title": f"Entity Type: {t.title()}"}])
                for idx, t in enumerate(types)
            ],
            direction="down", x=0.25, y=1.15, showactive=True
        )
    ]
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler

# --- PREP WORK ---
# Create graph and compute centrality
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _,r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

# Metrics and community
deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
pos = nx.spring_layout(G, k=0.15)

# --- NORMALIZE DEGREE CENTRALITY FOR SCALING NODE SIZES ---
scaler = MinMaxScaler(feature_range=(10, 30))
deg_values = scaler.fit_transform(pd.DataFrame(deg_cent.values()))
node_sizes = {n: deg_values[i][0] for i, n in enumerate(deg_cent)}

# --- BUILD FILTERABLE GRAPH ---
sentiments = sorted(edges_df['sentiment'].dropna().unique())
relationships = sorted(edges_df['relationship'].dropna().unique())
types = ents_long['entity_type'].dropna().unique().tolist()

# Edge traces with sentiment and relationship metadata
edge_traces = []
for s in sentiments:
    for rel in relationships:
        xs, ys, texts = [], [], []
        for _, row in edges_df[(edges_df.sentiment==s)&(edges_df.relationship==rel)].iterrows():
            u, v = row['source'], row['target']
            if u not in pos or v not in pos: continue
            x0,y0 = pos[u]; x1,y1 = pos[v]
            xs += [x0,x1,None]; ys += [y0,y1,None]
            texts.append(f"{u} {rel} {v}<br>Sentiment: {s}")
        edge_traces.append(go.Scatter(
            x=xs, y=ys, mode='lines', line=dict(width=1, color='gray'),
            hoverinfo='text', text=texts,
            name=f"{s} / {rel}", visible=(s=='NEUTRAL' and rel==relationships[0])
        ))

# Node traces
color_map = {'people':'gold', 'institutions':'orange', 'locations':'orchid',
             'political_events':'gray', 'political_parties':'lightgray'}
node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, size, custom = [], [], [], [], [], []
    for n in G.nodes():
        match = ents_long.loc[ents_long.entity==n, 'entity_type']
        et = match.iloc[0] if not match.empty else 'unknown'
        if t!='All' and et!=t: continue
        x,y = pos[n]
        xs.append(x); ys.append(y); txt.append(n)
        col.append(color_map.get(et, 'lightgray'))
        size.append(node_sizes.get(n, 10))
        custom.append(f"{n} ({et})")
    node_traces.append(go.Scatter(
        x=xs, y=ys, mode='markers+text', textposition='top center',
        text=txt, marker=dict(size=size, color=col, line=dict(width=0.5, color='black')),
        hovertext=custom, hoverinfo='text', visible=(t=='All'), name=t
    ))

# --- BUILD FIGURE ---
fig = go.Figure(data=edge_traces + node_traces)

# Sentiment / relationship dropdown
fig.update_layout(updatemenus=[
    dict(buttons=[
        dict(label='All', method='update', args=[
            {'visible': [True]*len(edge_traces) + [True]*len(node_traces)},
            {'title': 'All relationships'}]),
        *[dict(label=f"{s} / {r}", method='update', args=[
            {'visible': [i==idx for i in range(len(edge_traces))] + [True]*len(node_traces)},
            {'title': f"{s} / {r}"}])
          for idx, (s, r) in enumerate([(s,r) for s in sentiments for r in relationships])]
    ], x=0, y=1.15),
    dict(buttons=[
        dict(label='All Types', method='update', args=[
            {'visible': [True]*len(edge_traces) + [i==0 for i in range(len(node_traces))]},
            {'title': 'All Entity Types'}]),
        *[dict(label=t, method='update', args=[
            {'visible': [True]*len(edge_traces) + [i==(idx+1) for i in range(len(node_traces))]},
            {'title': f"Type: {t}"}]) for idx, t in enumerate(types)]
    ], x=0.3, y=1.15)
])

fig.update_layout(
    title="📊 Filterable Political Knowledge Graph",
    margin=dict(l=20,r=20,b=20,t=50),
    hovermode='closest',
    showlegend=True
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler

# --- PREP WORK ---
ew = edges_df.groupby(['source','target']).size().reset_index(name='weight')
G = nx.Graph()
for _,r in ew.iterrows():
    G.add_edge(r.source, r.target, weight=r.weight)

deg_cent = nx.degree_centrality(G)
pr = nx.pagerank(G)
pos = nx.spring_layout(G, k=0.15)

scaler = MinMaxScaler(feature_range=(10, 30))
deg_values = scaler.fit_transform(pd.DataFrame(deg_cent.values()))
node_sizes = {n: deg_values[i][0] for i, n in enumerate(deg_cent)}

sentiments = sorted(edges_df['sentiment'].dropna().unique())
relationships = sorted(edges_df['relationship'].dropna().unique())
types = ents_long['entity_type'].dropna().unique().tolist()

edge_traces = []
for s in sentiments:
    for rel in relationships:
        xs, ys, texts = [], [], []
        for _, row in edges_df[(edges_df.sentiment==s)&(edges_df.relationship==rel)].iterrows():
            u, v = row['source'], row['target']
            if u not in pos or v not in pos: continue
            x0,y0 = pos[u]; x1,y1 = pos[v]
            xs += [x0,x1,None]; ys += [y0,y1,None]
            texts.append(f"{u} {rel} {v}<br>Sentiment: {s}")
        edge_traces.append(go.Scatter(
            x=xs, y=ys, mode='lines', line=dict(width=1, color='gray'),
            hoverinfo='text', text=texts,
            name=f"{s} / {rel}", visible=(s=='NEUTRAL' and rel==relationships[0])
        ))

color_map = {'people':'gold', 'institutions':'orange', 'locations':'orchid',
             'political_events':'gray', 'political_parties':'lightgray'}
node_traces = []
for t in ["All"] + types:
    xs, ys, txt, col, size, custom = [], [], [], [], [], []
    for n in G.nodes():
        match = ents_long.loc[ents_long.entity==n, 'entity_type']
        et = match.iloc[0] if not match.empty else 'unknown'
        if t!='All' and et!=t: continue
        x,y = pos[n]
        xs.append(x); ys.append(y); txt.append(n)
        col.append(color_map.get(et, 'lightgray'))
        size.append(node_sizes.get(n, 10))
        custom.append(f"{n} ({et})")
    node_traces.append(go.Scatter(
        x=xs, y=ys, mode='markers+text', textposition='top center',
        text=txt, marker=dict(size=size, color=col, line=dict(width=0.5, color='black')),
        hovertext=custom, hoverinfo='text', visible=(t=='All'), name=t
    ))

fig = go.Figure(data=edge_traces + node_traces)

# Separate sentiment and relationship dropdowns
fig.update_layout(updatemenus=[
    dict(
        buttons=[dict(label='All Sentiments', method='update', args=[
            {'visible': [True]*len(edge_traces) + [True]*len(node_traces)},
            {'title': 'All Sentiments'}
        ])] + [
            dict(label=s, method='update', args=[
                {'visible': [s in trace.name for trace in edge_traces] + [True]*len(node_traces)},
                {'title': f"Sentiment: {s}"}
            ]) for s in sentiments
        ],
        direction='down', x=0, y=1.15
    ),
    dict(
        buttons=[dict(label='All Relationships', method='update', args=[
            {'visible': [True]*len(edge_traces) + [True]*len(node_traces)},
            {'title': 'All Relationships'}
        ])] + [
            dict(label=r, method='update', args=[
                {'visible': [r in trace.name for trace in edge_traces] + [True]*len(node_traces)},
                {'title': f"Relationship: {r}"}
            ]) for r in relationships
        ],
        direction='down', x=0.25, y=1.15
    ),
    dict(
        buttons=[
            dict(label='All Types', method='update', args=[
                {'visible': [True]*len(edge_traces) + [i==0 for i in range(len(node_traces))]},
                {'title': 'All Entity Types'}]),
            *[dict(label=t, method='update', args=[
                {'visible': [True]*len(edge_traces) + [i==(idx+1) for i in range(len(node_traces))]},
                {'title': f"Type: {t}"}]) for idx, t in enumerate(types)]
        ],
        direction='down', x=0.5, y=1.15
    )
])

# Search box placeholder
fig.update_layout(
    title="\U0001F4CA Interactive Political Knowledge Graph",
    margin=dict(l=20,r=20,b=20,t=60),
    hovermode='closest',
    showlegend=True,
    annotations=[
        dict(text="Search functionality for a person/node can be implemented in Dash for full interactivity.",
             showarrow=False, x=0.5, y=-0.15, xref='paper', yref='paper', align='center')
    ]
)

fig.show()

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import numpy as np

# Assume edges_df and ents_long already exist
# edges_df columns: source, target, relationship, sentiment, date, url
# ents_long columns: url, date, entity, entity_type

# ─── Graph Construction ─────────────────────────────────────────
G = nx.Graph()
for _, row in edges_df.iterrows():
    G.add_edge(row['source'], row['target'], 
               relationship=row['relationship'], 
               sentiment=row['sentiment'], 
               date=row['date'])

# ─── Centralities and Layout ───────────────────────────────────
degree_centrality = nx.degree_centrality(G)
pos = nx.spring_layout(G, k=0.15, iterations=50)

# ─── Node Trace Construction ───────────────────────────────────
node_trace = go.Scatter(
    x=[], y=[],
    text=[],
    textposition="top center",
    mode='markers',
    hoverinfo='text',
    marker=dict(size=[], color=[], sizemode='diameter', sizeref=0.05, showscale=False),
)

# Entity type color map
entity_colors = {
    "people": "yellow",
    "institutions": "orange",
    "locations": "violet",
    "political_events": "gray",
    "political_parties": "lightblue",
    "unknown": "lightgray"
}

for node in G.nodes():
    x, y = pos[node]
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    deg = degree_centrality.get(node, 0)
    label = node if deg >= 0.01 else ""  # only label high-centrality nodes
    node_trace['text'] += tuple([node])
    node_type = ents_long.loc[ents_long.entity == node, "entity_type"].values
    color = entity_colors.get(node_type[0], "lightgray") if len(node_type) else "lightgray"
    node_trace['marker']['color'] += tuple([color])
    node_trace['marker']['size'] += tuple([10 + 30 * deg])

# ─── Edge Traces by Sentiment ───────────────────────────────────
sentiments = sorted(edges_df['sentiment'].dropna().unique().tolist())
sentiment_colors = {
    "FRIENDLY": "green",
    "HOSTILE": "red",
    "NEUTRAL": "gray"
}

edge_traces = []
for sentiment in sentiments:
    edge_x = []
    edge_y = []
    for u, v, d in G.edges(data=True):
        if d.get("sentiment") != sentiment:
            continue
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_x += [x0, x1, None]
        edge_y += [y0, y1, None]
    edge_traces.append(go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color=sentiment_colors.get(sentiment, "#888")),
        hoverinfo='none',
        mode='lines',
        name=sentiment
    ))

# ─── Dropdown Filters ───────────────────────────────────────────
# Unique relationships
relationships = sorted(edges_df['relationship'].dropna().unique().tolist())
entity_types = sorted(ents_long['entity_type'].dropna().unique().tolist())

updatemenus = [
    dict(
        buttons=[
            dict(label="All Sentiments", method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": "All Sentiments"}])
        ] + [
            dict(label=s, method="update",
                 args=[{"visible": [i==j for i in range(len(edge_traces))] + [True]},
                       {"title": f"Sentiment: {s}"}])
            for j, s in enumerate(sentiments)
        ],
        direction="down",
        showactive=True,
        x=0.1, y=1.1
    ),
    dict(
        buttons=[
            dict(label="All Relationships", method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": "All Relationships"}])
        ] + [
            dict(label=r, method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": f"Relationship: {r}"}])
            for r in relationships
        ],
        direction="down",
        showactive=True,
        x=0.3, y=1.1
    ),
    dict(
        buttons=[
            dict(label="All Types", method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": "All Types"}])
        ] + [
            dict(label=et, method="update",
                 args=[{"visible": [True]*len(edge_traces) + [True]},
                       {"title": f"Entity Type: {et}"}])
            for et in entity_types
        ],
        direction="down",
        showactive=True,
        x=0.5, y=1.1
    )
]

# ─── Final Graph ────────────────────────────────────────────────
fig = go.Figure(data=edge_traces + [node_trace],
                layout=go.Layout(
                    title="Interactive Knowledge Graph",
                    hovermode='closest',
                    updatemenus=updatemenus,
                    showlegend=True,
                    margin=dict(l=20, r=20, t=40, b=20)
                ))

fig.show()

# %% [markdown]
# # using Pyvis and ede bundleing and other tehcniques

# %%
# from pyvis.network import Network
# import networkx as nx
# import pandas as pd

# # Create the graph
# G = nx.Graph()

# # Add weighted edges to graph
# for _, row in edges_df.iterrows():
#     G.add_edge(
#         row['source'], 
#         row['target'], 
#         sentiment=row['sentiment'], 
#         relationship=row['relationship'], 
#         url=row['url'], 
#         date=str(row['date'])  # make sure it's a string
#     )

# # Degree centrality for sizing
# deg_cent = nx.degree_centrality(G)

# # Get entity types from ents_long
# entity_type_map = ents_long.drop_duplicates('entity').set_index('entity')['entity_type'].to_dict()

# # Color map by entity type
# type_colors = {
#     "people": "#ffd700",  # yellow
#     "organizations": "#ff7f0e",  # orange
#     "locations": "#9467bd",  # purple
#     "political_events": "#7f7f7f",  # gray
#     "political_parties": "#2ca02c",  # green
#     "institutions": "#1f77b4",  # blue
#     "unknown": "#d62728",  # red
# }

# # Create PyVis network
# net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", notebook=True)
# net.barnes_hut()

# # Add nodes
# for node in G.nodes():
#     entity_type = entity_type_map.get(node, "unknown")
#     color = type_colors.get(entity_type, "#d3d3d3")
#     size = 10 + deg_cent.get(node, 0) * 100  # scale up central nodes
#     label = node if size > 20 else ""  # hide labels for small nodes

#     net.add_node(
#         n_id=node,
#         label=label,
#         title=f"{node} ({entity_type})",
#         color=color,
#         size=size
#     )

# # Add edges with sentiment color
# sentiment_colors = {
#     "FRIENDLY": "green",
#     "HOSTILE": "red",
#     "NEUTRAL": "gray"
# }

# for u, v, d in G.edges(data=True):
#     color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
#     label = d.get('relationship', '')
#     title = f"{u} {label} {v}<br>Sentiment: {d.get('sentiment')}<br>Date: {d.get('date')}"

#     net.add_edge(u, v, color=color, title=title, value=1)

# # Generate and show the HTML
# net.show("knowledge_graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# knowledge_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="knowledge_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from pyvis.network import Network
import networkx as nx
import pandas as pd
from IPython.display import IFrame, display
import ipywidgets as widgets
import os 

# Create a local directory for the output
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# Base variables
selected_sentiment = widgets.Dropdown(
    options=["All"] + sorted(edges_df["sentiment"].dropna().unique().tolist()),
    description='Sentiment:'
)

selected_relationship = widgets.Dropdown(
    options=["All"] + sorted(edges_df["relationship"].dropna().unique().tolist()),
    description='Relation:'
)

date_range = widgets.SelectionRangeSlider(
    options=sorted(edges_df["date"].dropna().astype(str).unique().tolist()),
    index=(0, len(edges_df["date"].unique()) - 1),
    description='Date:',
    orientation='horizontal',
    layout={'width': '800px'}
)

# Callback
def generate_filtered_graph(sentiment, relationship, date_range_values):
    filtered_edges = edges_df.copy()
    if sentiment != "All":
        filtered_edges = filtered_edges[filtered_edges["sentiment"] == sentiment]
    if relationship != "All":
        filtered_edges = filtered_edges[filtered_edges["relationship"] == relationship]
    filtered_edges = filtered_edges[
        (filtered_edges["date"] >= date_range_values[0]) &
        (filtered_edges["date"] <= date_range_values[1])
    ]

    G = nx.Graph()
    for _, row in filtered_edges.iterrows():
        G.add_edge(row['source'], row['target'], 
                   sentiment=row['sentiment'], 
                   relationship=row['relationship'], 
                   url=row['url'], 
                   date=str(row['date']))

    deg_cent = nx.degree_centrality(G)
    entity_type_map = ents_long.drop_duplicates('entity').set_index('entity')['entity_type'].to_dict()
    type_colors = {
        "people": "#ffd700",
        "organizations": "#ff7f0e",
        "locations": "#9467bd",
        "political_events": "#7f7f7f",
        "political_parties": "#2ca02c",
        "institutions": "#1f77b4",
        "unknown": "#d62728",
    }
    sentiment_colors = {
        "FRIENDLY": "green",
        "HOSTILE": "red",
        "NEUTRAL": "gray"
    }

    # Create the network
    net = Network(
        height="750px",
        width="100%",
        bgcolor="#222222",
        font_color="white",
        notebook=True
    )
    net.barnes_hut()

    # Add nodes
    for node in G.nodes():
        entity_type = entity_type_map.get(node, "unknown")
        color = type_colors.get(entity_type, "#d3d3d3")
        size = 10 + deg_cent.get(node, 0) * 100
        label = node if size > 20 else ""
        net.add_node(
            n_id=node, 
            label=label,
            title=f"{node} ({entity_type})",
            color=color, 
            size=size
        )

    # Add edges
    for u, v, d in G.edges(data=True):
        color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
        label = d.get('relationship', '')
        title = f"{u} {label} {v}<br>Sentiment: {d.get('sentiment')}<br>Date: {d.get('date')}"
        net.add_edge(u, v, color=color, title=title, value=1)

    # Save and show the graph
    output_file = os.path.join(output_dir, 'filtered_kg.html')
    net.save_graph(output_file)
    
    # Display the graph in a new window
    net.show(output_file)

# Create the UI
ui = widgets.VBox([selected_sentiment, selected_relationship, date_range])

# Link interactivity
widgets.interact(
    generate_filtered_graph,
    sentiment=selected_sentiment,
    relationship=selected_relationship,
    date_range_values=date_range
)

# Display the UI
display(ui)
# Out:
# interactive(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), va…
# VBox(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), value='Al…

# %%
from pyvis.network import Network
import networkx as nx
import pandas as pd
from IPython.display import IFrame, display, HTML
import ipywidgets as widgets
import os 
import webbrowser

# Create a local directory for the output
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# Base variables
selected_sentiment = widgets.Dropdown(
    options=["All"] + sorted(edges_df["sentiment"].dropna().unique().tolist()),
    description='Sentiment:'
)

selected_relationship = widgets.Dropdown(
    options=["All"] + sorted(edges_df["relationship"].dropna().unique().tolist()),
    description='Relation:'
)

date_range = widgets.SelectionRangeSlider(
    options=sorted(edges_df["date"].dropna().astype(str).unique().tolist()),
    index=(0, len(edges_df["date"].unique()) - 1),
    description='Date:',
    orientation='horizontal',
    layout={'width': '800px'}
)

# Callback
def generate_filtered_graph(sentiment, relationship, date_range_values):
    filtered_edges = edges_df.copy()
    if sentiment != "All":
        filtered_edges = filtered_edges[filtered_edges["sentiment"] == sentiment]
    if relationship != "All":
        filtered_edges = filtered_edges[filtered_edges["relationship"] == relationship]
    filtered_edges = filtered_edges[
        (filtered_edges["date"] >= date_range_values[0]) &
        (filtered_edges["date"] <= date_range_values[1])
    ]

    # Create a directed graph instead of undirected
    G = nx.DiGraph()
    for _, row in filtered_edges.iterrows():
        G.add_edge(row['source'], row['target'], 
                   sentiment=row['sentiment'], 
                   relationship=row['relationship'], 
                   url=row['url'], 
                   date=str(row['date']))

    # Calculate both in-degree and out-degree centrality
    in_deg_cent = nx.in_degree_centrality(G)
    out_deg_cent = nx.out_degree_centrality(G)
    deg_cent = nx.degree_centrality(G)  # total degree for node sizing

    entity_type_map = ents_long.drop_duplicates('entity').set_index('entity')['entity_type'].to_dict()
    type_colors = {
        "people": "#ffd700",
        "organizations": "#ff7f0e",
        "locations": "#9467bd",
        "political_events": "#7f7f7f",
        "political_parties": "#2ca02c",
        "institutions": "#1f77b4",
        "unknown": "#d62728",
    }
    sentiment_colors = {
        "FRIENDLY": "green",
        "HOSTILE": "red",
        "NEUTRAL": "gray"
    }

    # Create the network
    net = Network(
        height="750px",
        width="100%",
        bgcolor="#222222",
        font_color="white",
        notebook=True,
        cdn_resources='in_line',
        directed=True  # Enable directed edges
    )
    net.barnes_hut()

    # Add nodes with hover information including in/out degree
    for node in G.nodes():
        entity_type = entity_type_map.get(node, "unknown")
        color = type_colors.get(entity_type, "#d3d3d3")
        size = 10 + deg_cent.get(node, 0) * 100
        label = node if size > 20 else ""
        
        # Create detailed hover text
        hover_text = f"""
        {node} ({entity_type})
        Incoming relationships: {in_deg_cent.get(node, 0):.2f}
        Outgoing relationships: {out_deg_cent.get(node, 0):.2f}
        Total relationships: {deg_cent.get(node, 0):.2f}
        """
        
        net.add_node(
            n_id=node, 
            label=label,
            title=hover_text,
            color=color, 
            size=size
        )

    # Add edges with arrows and detailed information
    for u, v, d in G.edges(data=True):
        color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
        label = d.get('relationship', '')
        title = f"""
        From: {u}
        To: {v}
        Relationship: {label}
        Sentiment: {d.get('sentiment')}
        Date: {d.get('date')}
        """
        net.add_edge(
            u, v, 
            color=color, 
            title=title, 
            value=1,
            arrows='to',  # Add arrows to show direction
            smooth=True   # Make edges curved for better visibility
        )

    # Save the graph
    output_file = os.path.join(output_dir, 'filtered_kg.html')
    net.save_graph(output_file)
    
    # Open in browser
    webbrowser.open('file://' + os.path.abspath(output_file))

# Create the UI
ui = widgets.VBox([selected_sentiment, selected_relationship, date_range])

# Link interactivity
widgets.interact(
    generate_filtered_graph,
    sentiment=selected_sentiment,
    relationship=selected_relationship,
    date_range_values=date_range
)

# Display the UI
display(ui)
# Out:
# interactive(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), va…
# VBox(children=(Dropdown(description='Sentiment:', options=('All', 'FRIENDLY', 'HOSTILE', 'NEUTRAL'), value='Al…

# %%
from graph_visualization import generate_graph

# Run the graph visualization
generate_graph()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
edges_df.to_csv('edges_df.csv')
ents_long.to_csv('ents_long.csv')

# %%
from pyvis.network import Network
import networkx as nx
import pandas as pd
from IPython.display import IFrame, display, HTML
import ipywidgets as widgets
import os 
import webbrowser
from community import community_louvain

# Create output directory
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

def generate_filtered_graph(sentiment="All", relationship="All", date_range_values=None, search_term=""):
    filtered_edges = edges_df.copy()
    
    # Apply filters
    if sentiment != "All":
        filtered_edges = filtered_edges[filtered_edges["sentiment"] == sentiment]
    if relationship != "All":
        filtered_edges = filtered_edges[filtered_edges["relationship"] == relationship]
    if date_range_values:
        filtered_edges = filtered_edges[
            (filtered_edges["date"] >= date_range_values[0]) &
            (filtered_edges["date"] <= date_range_values[1])
        ]

    # Create directed graph
    G = nx.DiGraph()
    for _, row in filtered_edges.iterrows():
        G.add_edge(row['source'], row['target'], 
                   sentiment=row['sentiment'], 
                   relationship=row['relationship'], 
                   url=row['url'], 
                   date=str(row['date']))

    # If search term exists, filter to only show connected nodes
    if search_term:
        # Find all nodes connected to the searched term
        connected_nodes = set()
        for node in G.nodes():
            if search_term.lower() in node.lower():
                connected_nodes.add(node)
                # Add first-degree connections
                connected_nodes.update(G.neighbors(node))
                connected_nodes.update(G.predecessors(node))
        
        # Create subgraph with only connected nodes
        G = G.subgraph(connected_nodes).copy()

    # Calculate centralities
    in_deg_cent = nx.in_degree_centrality(G)
    out_deg_cent = nx.out_degree_centrality(G)
    deg_cent = nx.degree_centrality(G)
    
    # Get top nodes by degree centrality
    top_nodes = sorted(deg_cent.items(), key=lambda x: x[1], reverse=True)[:20]
    top_node_ids = [node for node, _ in top_nodes]

    # Detect communities
    partition = community_louvain.best_partition(G.to_undirected())
    
    # Create the network
    net = Network(
        height="750px",
        width="100%",
        bgcolor="#222222",
        font_color="white",
        notebook=True,
        cdn_resources='in_line',
        directed=True
    )

    # Enhanced physics options
    net.set_options("""
    {
        "physics": {
            "forceAtlas2Based": {
                "gravitationalConstant": -100,
                "centralGravity": 0.01,
                "springLength": 200,
                "springConstant": 0.08,
                "damping": 0.4,
                "avoidOverlap": 1
            },
            "maxVelocity": 10,
            "minVelocity": 0.1,
            "solver": "forceAtlas2Based",
            "stabilization": {
                "enabled": true,
                "iterations": 2000,
                "updateInterval": 50,
                "onlyDynamicEdges": false,
                "fit": true
            }
        },
        "edges": {
            "smooth": {
                "enabled": true,
                "type": "continuous",
                "forceDirection": "none",
                "roundness": 0.5
            },
            "color": {
                "inherit": true
            },
            "width": 1,
            "arrows": {
                "to": {
                    "enabled": true,
                    "scaleFactor": 1.5,
                    "type": "arrow"
                }
            }
        },
        "nodes": {
            "font": {
                "size": 14,
                "face": "arial"
            },
            "scaling": {
                "min": 10,
                "max": 30
            }
        }
    }
    """)

    # Add nodes
    for node in G.nodes():
        entity_type = entity_type_map.get(node, "unknown")
        color = type_colors.get(entity_type, "#d3d3d3")
        size = 10 + deg_cent.get(node, 0) * 100
        
        # Show label for searched node, top nodes, or when zoomed in
        label = node if (node in top_node_ids or 
                        (search_term and search_term.lower() in node.lower())) else ""
        
        # Highlight searched node
        if search_term and search_term.lower() in node.lower():
            color = "#ff0000"
            size *= 1.5
        
        hover_text = f"""
        <div style='font-size: 14px;'>
            <b>{node}</b> ({entity_type})<br>
            Community: {partition.get(node, 0)}<br>
            Incoming relationships: {in_deg_cent.get(node, 0):.2f}<br>
            Outgoing relationships: {out_deg_cent.get(node, 0):.2f}<br>
            Total relationships: {deg_cent.get(node, 0):.2f}
        </div>
        """
        
        net.add_node(
            n_id=node, 
            label=label,
            title=hover_text,
            color=color, 
            size=size,
            group=partition.get(node, 0)
        )

    # Add edges
    for u, v, d in G.edges(data=True):
        color = sentiment_colors.get(d.get('sentiment', "NEUTRAL"), "gray")
        label = d.get('relationship', '')
        title = f"""
        <div style='font-size: 14px;'>
            <b>From:</b> {u}<br>
            <b>To:</b> {v}<br>
            <b>Relationship:</b> {label}<br>
            <b>Sentiment:</b> {d.get('sentiment')}<br>
            <b>Date:</b> {d.get('date')}
        </div>
        """
        net.add_edge(
            u, v, 
            color=color, 
            title=title, 
            value=1,
            smooth=True,
            width=1
        )

    # Add custom HTML with filters and controls
    custom_html = """
    <div style="position: absolute; top: 10px; right: 10px; z-index: 1000; background: rgba(255,255,255,0.9); padding: 10px; border-radius: 5px;">
        <div style="margin-bottom: 10px;">
            <input type="text" id="searchInput" placeholder="Search nodes..." 
                   style="padding: 5px; border-radius: 4px; border: 1px solid #ccc; width: 200px;">
            <button onclick="searchNodes()" 
                    style="padding: 5px 10px; border-radius: 4px; border: 1px solid #ccc; background: #fff;">
                Search
            </button>
        </div>
        <div style="margin-bottom: 10px;">
            <select id="sentimentFilter" onchange="applyFilters()" 
                    style="padding: 5px; border-radius: 4px; border: 1px solid #ccc; width: 200px;">
                <option value="All">All Sentiments</option>
                <option value="FRIENDLY">Friendly</option>
                <option value="HOSTILE">Hostile</option>
                <option value="NEUTRAL">Neutral</option>
            </select>
        </div>
        <div style="margin-bottom: 10px;">
            <select id="relationshipFilter" onchange="applyFilters()" 
                    style="padding: 5px; border-radius: 4px; border: 1px solid #ccc; width: 200px;">
                <option value="All">All Relationships</option>
                <option value="SUPPORTS">Supports</option>
                <option value="OPPOSES">Opposes</option>
                <option value="WORKS_WITH">Works With</option>
                <!-- Add other relationships as needed -->
            </select>
        </div>
        <div style="margin-bottom: 10px;">
            <button onclick="togglePhysics()" 
                    style="padding: 5px 10px; border-radius: 4px; border: 1px solid #ccc; background: #fff;">
                Toggle Physics
            </button>
            <button onclick="resetView()" 
                    style="padding: 5px 10px; border-radius: 4px; border: 1px solid #ccc; background: #fff;">
                Reset View
            </button>
        </div>
    </div>
    <script>
    function searchNodes() {
        var searchTerm = document.getElementById('searchInput').value.toLowerCase();
        if (searchTerm) {
            // Rebuild graph with search term
            window.location.href = '?search=' + searchTerm;
        }
    }

    function applyFilters() {
        var sentiment = document.getElementById('sentimentFilter').value;
        var relationship = document.getElementById('relationshipFilter').value;
        window.location.href = '?sentiment=' + sentiment + '&relationship=' + relationship;
    }
    
    function togglePhysics() {
        var physics = network.getOptions().physics;
        network.setOptions({ physics: { enabled: !physics.enabled } });
    }

    function resetView() {
        network.fit({
            animation: {
                duration: 1000,
                easingFunction: 'easeInOutQuad'
            }
        });
    }

    // Add zoom-based label visibility
    network.on("zoom", function() {
        var zoom = network.getScale();
        var nodes = network.body.data.nodes;
        nodes.forEach(function(node) {
            if (zoom > 1.5) {
                node.label = node.id;
            } else {
                node.label = node.id in topNodes ? node.id : "";
            }
        });
        network.body.data.nodes.update(nodes);
    });
    </script>
    """
    
    # Save and display
    output_file = os.path.join(output_dir, 'filtered_kg.html')
    net.save_graph(output_file)
    
    with open(output_file, 'r') as f:
        content = f.read()
    
    content = content.replace('</body>', f'{custom_html}</body>')
    
    with open(output_file, 'w') as f:
        f.write(content)
    
    webbrowser.open('file://' + os.path.abspath(output_file))

# Initial graph generation
generate_filtered_graph()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# Generate the initial graph
generate_graph()

# Run the Flask app
if __name__ == "__main__":
    app.run(port=5000, debug=True)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#  * Tip: There are .env files present. Install python-dotenv to use them.
#  * Serving Flask app '__main__'
#  * Debug mode: on
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# On macOS, try disabling the 'AirPlay Receiver' service from System Preferences -> General -> AirDrop & Handoff.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/ghadena/Desktop/geopol/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3678: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
from interactive_kg_app import run_app_with_data
run_app_with_data('edges_df.csv', 'ents_long.csv')
# Out:
#  * Tip: There are .env files present. Install python-dotenv to use them.
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
#  * Serving Flask app 'interactive_kg_app'
#  * Debug mode: off
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# On macOS, try disabling the 'AirPlay Receiver' service from System Preferences -> General -> AirDrop & Handoff.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from ne_kg import app
app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from visjs_dashboard.app import app
import webbrowser
from threading import Timer
import os

def open_browser():
    webbrowser.open('http://localhost:5757')

if __name__ == "__main__":
    # Get the current working directory
    current_dir = os.getcwd()
    print(f"Current directory: {current_dir}")
    
    # Start the browser after a short delay
    Timer(1.5, open_browser).start()
    
    # Run the app with use_reloader=False to prevent the SystemExit error
    app.run(port=5757, debug=True, use_reloader=False)
# Out:
#  * Tip: There are .env files present. Install python-dotenv to use them.
# Current directory: /Users/ghadena/Desktop/geopol
#  * Serving Flask app 'visjs_dashboard.app'
#  * Debug mode: on
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
